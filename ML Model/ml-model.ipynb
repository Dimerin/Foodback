# %% [markdown]
# Parameters Definition

# %%
# ------------------ Folders ------------------

# Dataset
DATASET = "dataset/"

# Raw Data
RAW_DATASET = DATASET + "raw/"

# Upsampled Data (for HR and EDA)
UPSAMPLED_DATASET = DATASET + "upsampled/"

# Splitted Data
SPLITTED_DATASET = DATASET + "splitted/"
# Training and Test Sets
TRAINING_SET = SPLITTED_DATASET + "training_set/"
TEST_SET = SPLITTED_DATASET + "test_set/"

# ---------------------------------------------


# ------------------- Files -------------------

# Raw Data
RAW_EEG = RAW_DATASET + "eeg_data.csv"
RAW_HR = RAW_DATASET + "hr_data.csv"
RAW_EDA = RAW_DATASET + "eda_data.csv"

# Upsampled Data
UPSAMPLED_HR = UPSAMPLED_DATASET + "upsampled_hr_data.csv"
UPSAMPLED_EDA = UPSAMPLED_DATASET + "upsampled_eda_data.csv"


# Training and Test Sets
# EEG
EEG_TRAINING_SET = TRAINING_SET + "eeg_training_set.csv"
EEG_TEST_SET = TEST_SET + "eeg_test_set.csv"
# HR
HR_TRAINING_SET = TRAINING_SET + "hr_training_set.csv"
HR_TEST_SET = TEST_SET + "hr_test_set.csv"
# EDA
EDA_TRAINING_SET = TRAINING_SET + "eda_training_set.csv"
EDA_TEST_SET = TEST_SET + "eda_test_set.csv"

# TensorFlowLite Model
TFLITE_MODEL = "eegnet_preproc.tflite"

# ---------------------------------------------


# ----------------- Constants -----------------

# Epoch Duration in seconds
EPOCH_DURATION = 2

# EEG Channels
EEG_CHANNELS = ['ch1','ch2','ch3','ch4','ch5','ch6']
# EEG Sampling Frequency
EEG_SAMPLING_FREQUENCY = 500 # Hz
# Samples per epoch
EEG_SAMPLES_PER_EPOCH = EPOCH_DURATION * EEG_SAMPLING_FREQUENCY  # 2 seconds at 500 Hz

# Target Sampling Frequency
FS_TARGET  = 125 # Hz

# Wearable sampling frequency
WEARABLE_SAMPLES_PER_EPOCH = EPOCH_DURATION * FS_TARGET  # 2 seconds at 125 Hz

# ---------------------------------------------

# %%
# ------------------- Imports -------------------
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from scipy.signal import firwin
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Lambda, Conv2D, DepthwiseConv2D, SeparableConv2D,
    BatchNormalization, Activation, AveragePooling2D,
    Dropout, Flatten, Dense, Concatenate
)
from tensorflow.keras.constraints import max_norm
# --------------------------------------------------

# %% [markdown]
# Step 1: Upsample data coming from the smartwatch to bring it to 125Hz

# %%
# Utility function to upsample data
def upsample_data(group, target_freq=125, duration_s=10):
    # Calculate start and end timestamps per experiment
    start = group['timestamp'].min()
    end = start + duration_s * 1000
    # Generate target timestamps (125 samples/sec × duration)
    target_times = np.linspace(start, end, target_freq * duration_s)
    # Interpolate 'value' at these timestamps
    values = np.interp(target_times, group['timestamp'], group['value'])
    # Build upsampled DataFrame
    up_df = pd.DataFrame({
        'experiment': group['experiment'].iloc[0],
        'timestamp': target_times.astype(int),
        'value': values,
        'subject': group['subject'].iloc[0],
        'rating': group['rating'].iloc[0]
    })
    # Ensure exactly target_freq*duration_s rows
    return up_df.iloc[:target_freq * duration_s]

# %%
# Heart Rate

# 1. Read the raw CSV (all experiments)
raw_df = pd.read_csv(RAW_HR)

# 2. Upsample each experiment
upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# 3. Export to CSV

# Creating output directory if it doesn't exist
os.makedirs(UPSAMPLED_DATASET, exist_ok=True)

upsampled_df.to_csv(UPSAMPLED_HR, index=False)

print(f"Upsampling complete! Data saved to {UPSAMPLED_HR}.")
# Out:
# Upsampling complete! Data saved to dataset/upsampled/upsampled_hr_data.csv.
# C:\Users\giova\AppData\Local\Temp\ipykernel_20216\2837762272.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# %%
# EDA

# 1. Read the raw CSV (all experiments)
raw_df = pd.read_csv(RAW_EDA)

# 2. Upsample each experiment
upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# 3. Export to CSV

# Creating output directory if it doesn't exist
os.makedirs(UPSAMPLED_DATASET, exist_ok=True)

upsampled_df.to_csv(UPSAMPLED_EDA, index=False)

print(f"Upsampling complete! Data saved to {UPSAMPLED_EDA}.")
# Out:
# C:\Users\giova\AppData\Local\Temp\ipykernel_20216\2060052639.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)
# Upsampling complete! Data saved to dataset/upsampled/upsampled_eda_data.csv.

# %% [markdown]
# Step 2: Split data into training and test sets using an hold-out strategy

# %%
# Load the EEG raw dataset
eeg_df = pd.read_csv(RAW_EEG)

# Load the upsampled heart-rate dataset
hr_df = pd.read_csv(UPSAMPLED_HR)

# Load the Upsampled eda dataset
eda_df = pd.read_csv(UPSAMPLED_EDA)

# Extract unique experiment IDs from the EEG data
experiments = eeg_df['experiment'].unique()

# Split experiments: 80% train, 20% test
train_exps, test_exps = train_test_split(
    experiments,
    test_size=0.2,
    random_state=42
)

# Partition the three datasets by the same experiment split
# EEG splits
eeg_train = eeg_df[eeg_df['experiment'].isin(train_exps)].reset_index(drop=True)
eeg_test  = eeg_df[eeg_df['experiment'].isin(test_exps)].reset_index(drop=True)

# Heart-rate splits
hr_train = hr_df[hr_df['experiment'].isin(train_exps)].reset_index(drop=True)
hr_test  = hr_df[hr_df['experiment'].isin(test_exps)].reset_index(drop=True)

# EDA splits
eda_train = eda_df[eda_df['experiment'].isin(train_exps)].reset_index(drop=True)
eda_test  = eda_df[eda_df['experiment'].isin(test_exps)].reset_index(drop=True)

# Creating the folders if they do not exist
# Create the training set folder
if not os.path.exists(TRAINING_SET):
    os.makedirs(TRAINING_SET)

# Create the test set folder
if not os.path.exists(TEST_SET):
    os.makedirs(TEST_SET)

# Save the splitted files
# EEG
eeg_train.to_csv(EEG_TRAINING_SET, index=False)
eeg_test.to_csv(EEG_TEST_SET, index=False)

# Heart-rate
hr_train.to_csv(HR_TRAINING_SET, index=False)
hr_test.to_csv(HR_TEST_SET, index=False)

# EDA
eda_train.to_csv(EDA_TRAINING_SET, index=False)
eda_test.to_csv(EDA_TEST_SET, index=False)

# Sanity checks
print("Train experiments:", train_exps)
print("Test experiments :", test_exps)
print(f"EEG train rows: {len(eeg_train)}, test rows: {len(eeg_test)}")
print(f"HR train rows: {len(hr_train)}, test rows: {len(hr_test)}")
print(f"EDA train rows: {len(eda_train)}, test rows: {len(eda_test)}")
# Out:
# Train experiments: [ 4  7 25 33 20 18 14 43 16 10 17 38 32 28  1 31 30  6 12 34  2 41 22  3
#  35 24 37 11 23 19 45 21  8 15 29 39]
# Test experiments : [40 26 27 44 36 42  5 13  9]
# EEG train rows: 180000, test rows: 45000
# HR train rows: 45000, test rows: 11250
# EDA train rows: 45000, test rows: 11250

# %% [markdown]
# Step 3: Model definition

# %%
# -------------------- Design FIR filters --------------------
fs_in       = 500                   # incoming sample rate
fs_target   = 125                   # desired rate after decimation
dec_factor  = fs_in // fs_target    # must be 4
numtaps     = 101                   # filter length 

# 1) High-pass (0.5 Hz) for detrend
hp_coeffs   = firwin(numtaps, cutoff=0.5, fs=fs_in, pass_zero=False)
# 2) Band-pass (0.5–50 Hz)
bp_coeffs   = firwin(numtaps, cutoff=[0.5, 50.], fs=fs_in, pass_zero=False)
# 3) Notch (49–51 Hz)
bs_coeffs   = firwin(numtaps, cutoff=[49., 51.], fs=fs_in, pass_zero=True)
# 4) Anti-alias low-pass (≤62.5 Hz)
aa_coeffs   = firwin(numtaps, cutoff=fs_target/2, fs=fs_in)

# -------------------- Helper to apply 1D FIR --------------------
def apply_fir(x, coeffs):
    """ x: (B, Ch, T, 1) → applies 1-D FIR along time via depthwise conv """
    # 1) remove trailing singleton and transpose to NHWC with time in W, channels in C:
    #    (B, Ch, T, 1) → (B, T, Ch)
    x2 = tf.squeeze(x, -1)
    #    (B, T, Ch) → (B, 1, T, Ch)
    x2 = tf.expand_dims(x2, 1)

    # 2) build depthwise kernel of shape (1, filter_len, in_channels=Ch, channel_multiplier=1)
    #    coeffs is (filter_len,), so first reshape to (1, filter_len, 1, 1)
    k = tf.constant(coeffs.reshape(1, -1, 1, 1), tf.float32)
    #    then tile the "in_channels" dimension to match your EEG channels
    n_ch = x2.shape[-1]
    k = tf.tile(k, [1, 1, n_ch, 1])  # now (1, filter_len, Ch, 1)

    # 3) depthwise conv2d → same padding
    y = tf.nn.depthwise_conv2d(
        x2,
        k,
        strides=[1, 1, 1, 1],
        padding='SAME',
        data_format='NHWC'
    )
    # y has shape (B, 1, T, Ch); we want back (B, Ch, T, 1)

    y = tf.squeeze(y, 1)            # → (B, T, Ch)
    y = tf.transpose(y, [0, 2, 1])  # → (B, Ch, T)
    return y[..., tf.newaxis]       # → (B, Ch, T, 1)


# -------------------- Combined model --------------------
def PreprocAndEEGNet(nb_classes,
                     channel_means, channel_stds,  # arrays of shape (8,)
                     eeg_chans=6,
                     fs_in=500,                    # original raw rate for EEG
                     fs_target=125,                # rate after decimation
                     duration_s=2.0,               # length of each input epoch in seconds
                     dropoutRate=0.5,
                     F1=8, D=2, F2=16,
                     norm_rate=0.25):
    # Calculate dynamic shapes
    Samples_in = int(fs_in * duration_s)       # e.g. 1000 samples @ 500 Hz
    Samples    = int(fs_target * duration_s)   # e.g. 250 samples @ 125 Hz
    dec_factor = fs_in // fs_target            # 4
    kernLength = int(0.5 * fs_target)          # half the target rate: 62
    
    # EEG input path
    eeg_in = Input(shape=(eeg_chans, Samples_in, 1), name='eeg_input')

    # 1) High-pass
    x = Lambda(lambda z: apply_fir(z, hp_coeffs), output_shape=lambda input_shape: input_shape, name='hp')(eeg_in)
    # 2) Band-pass
    x = Lambda(lambda z: apply_fir(z, bp_coeffs), output_shape=lambda input_shape: input_shape, name='bp')(x)
    # 3) Notch
    x = Lambda(lambda z: apply_fir(z, bs_coeffs), output_shape=lambda input_shape: input_shape, name='notch')(x)
    # 4) Anti-alias low-pass
    x = Lambda(lambda z: apply_fir(z, aa_coeffs), output_shape=lambda input_shape: input_shape, name='aa')(x)
    # 5) Decimate by slicing every dec_factor-th sample
    x = Lambda(lambda z: z[:, :, ::dec_factor, :], name='decimate')(x)

    # now x has shape (batch, Chans, Samples_in/4, 1) → (batch,6,250,1)

    # HR input path (no filtering, already 125 Hz)
    hr_in = Input(shape=(1, Samples, 1), name='hr_input')

    # EDA input path (no filtering, already 125 Hz)
    eda_in = Input(shape=(1, Samples, 1), name='eda_input')
    
    # 3) Concatenate along channel axis → (B, 8, 250, 1)
    merged = Concatenate(axis=1)([x, hr_in, eda_in])
    Chans = eeg_chans + 2  # now 8
    
    # --- EEGNet layers expects Samples=250 ---
    # Keras Implementation of EEGNet
    # http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    # Normalization
    # we broadcast: (1,8,1,1) → will divide/subtract per-channel
    means = tf.constant(channel_means.reshape(1, -1, 1, 1), dtype=tf.float32)
    stds  = tf.constant(channel_stds .reshape(1, -1, 1, 1), dtype=tf.float32)
    norm  = Lambda(lambda z: (z - means) / stds, name="normalize")(merged)

    # Block 1
    b1 = Conv2D(F1, (1, kernLength), padding='same', use_bias=False)(norm)
    b1 = BatchNormalization()(b1)
    b1 = DepthwiseConv2D((Chans, 1), use_bias=False,
                        depth_multiplier=D,
                        depthwise_constraint=max_norm(1.))(b1)
    b1 = BatchNormalization()(b1)
    b1 = Activation('elu')(b1)
    b1 = AveragePooling2D((1, 4))(b1)
    b1 = Dropout(dropoutRate)(b1)

    # Block 2
    b2 = SeparableConv2D(F2, (1, 16), padding='same', use_bias=False)(b1)
    b2 = BatchNormalization()(b2)
    b2 = Activation('elu')(b2)
    b2 = AveragePooling2D((1, 8))(b2)
    b2 = Dropout(dropoutRate)(b2)
    
    # Classification head
    flat = Flatten(name='flatten')(b2)
    dense= Dense(nb_classes, kernel_constraint=max_norm(norm_rate), name='dense')(flat)
    out  = Activation('softmax', name='softmax')(dense)
        
    return Model(inputs=[eeg_in, hr_in, eda_in], outputs=out, name='EEGNet_with_Preproc')
    

# Example instantiation
model = PreprocAndEEGNet(nb_classes=5, channel_means=np.zeros(8), channel_stds=np.ones(8))

# Compile / train
model.compile('adam', 'sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\giova\miniconda3\envs\MSSS\lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "EEGNet_with_Preproc"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ eeg_input           │ (None, 6, 1000,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hp (Lambda)         │ (None, 6, 1000,   │          0 │ eeg_input[0][0]   │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bp (Lambda)         │ (None, 6, 1000,   │          0 │ hp[0][0]          │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ notch (Lambda)      │ (None, 6, 1000,   │          0 │ bp[0][0]          │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aa (Lambda)         │ (None, 6, 1000,   │          0 │ notch[0][0]       │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decimate (Lambda)   │ (None, 6, 250, 1) │          0 │ aa[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hr_input            │ (None, 1, 250, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eda_input           │ (None, 1, 250, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 250, 1) │          0 │ decimate[0][0],   │
# │ (Concatenate)       │                   │            │ hr_input[0][0],   │
# │                     │                   │            │ eda_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalize (Lambda)  │ (None, 8, 250, 1) │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 250, 8) │        496 │ normalize[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 8, 250, 8) │         32 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 1, 250,    │        128 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 250,    │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1, 250,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 1, 62, 16) │          0 │ activation[0][0]  │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1, 62, 16) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 1, 62, 16) │        512 │ dropout[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 62, 16) │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1, 62, 16) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 1, 7, 16)  │          0 │ activation_1[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1, 7, 16)  │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 112)       │          0 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5)         │        565 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax             │ (None, 5)         │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,861 (7.27 KB)
#  Trainable params: 1,781 (6.96 KB)
#  Non-trainable params: 80 (320.00 B)

# %% [markdown]
# Step 4: Model training and evaluation

# %%
# Utility functions for loading epochs

def load_eeg_epochs(csv_file, channels, packets_per_epoch):
    df = pd.read_csv(csv_file)
    df['epoch_idx'] = (df['sample'] // packets_per_epoch).astype(int)
    X_list, y_list = [], []
    for (_, _, epoch_idx), grp in df.groupby(['experiment','subject','epoch_idx']):
        grp = grp.sort_values('sample')
        data = grp[channels].values.T  # (6, packets_per_epoch)
        X_list.append(data[..., np.newaxis])
        y_list.append(grp['rating'].iloc[0])
    return np.stack(X_list), np.array(y_list)

def load_wearable_epochs(csv_file, samples_per_epoch):
    """
    Load and segment HR or EDA data into non-overlapping epochs based on row index.
    
    Parameters:
    - csv_file: path to CSV with columns ['experiment','timestamp','value','subject','rating']
    - samples_per_epoch: number of consecutive samples per epoch (e.g. 2 s * 125 Hz = 250)
    
    Returns:
    - X_eda: np.ndarray of shape (n_epochs, 1, samples_per_epoch, 1)
    - y_eda: np.ndarray of labels (n_epochs,)
    """
    df = pd.read_csv(csv_file)
    # Ensure consistent ordering
    df = df.reset_index(drop=True)
    # Epoch index based on row index
    df['epoch_idx'] = df.index // samples_per_epoch

    X_list = []
    y_list = []

    # Group by experiment, subject, and computed epoch index
    for (exp, subj, ep), grp in df.groupby(['experiment', 'subject', 'epoch_idx']):
        grp = grp.sort_index()
        values = grp['value'].values
        if len(values) == samples_per_epoch:
            # shape for each epoch: (1 channel, samples, 1)
            X_list.append(values[np.newaxis, :, np.newaxis])
            y_list.append(grp['rating'].iloc[0])

    X_eda = np.concatenate(X_list, axis=0)
    y_eda = np.array(y_list)
    return X_eda, y_eda

# %%
# Load the training data
X_eeg_train, y_train = load_eeg_epochs(EEG_TRAINING_SET, EEG_CHANNELS, EEG_SAMPLES_PER_EPOCH)
X_hr_train, y_hr_train = load_wearable_epochs(HR_TRAINING_SET, WEARABLE_SAMPLES_PER_EPOCH)
X_eda_train, y_eda_train = load_wearable_epochs(EDA_TRAINING_SET, WEARABLE_SAMPLES_PER_EPOCH)

# Assert that y_train, y_hr_train, and y_eda_train are the same
assert np.array_equal(y_train, y_hr_train), "y_train and y_hr_train do not match!"
assert np.array_equal(y_train, y_eda_train), "y_train and y_eda_train do not match!"

# Shuffle the data
X_eeg_train, X_hr_train, X_eda_train, y_train = shuffle(X_eeg_train, X_hr_train, X_eda_train, y_train, random_state=42)

# %%
# Precompute preprocessed EEG (to get means/stds)
# Build a small model that inputs raw EEG and outputs the decimated, filtered EEG:
eeg_in = tf.keras.Input(shape=(6, EEG_SAMPLES_PER_EPOCH, 1))
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, hp_coeffs))(eeg_in)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, bp_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, bs_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, aa_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: z[:, :, ::4, :])(x)
preproc_model = tf.keras.Model(inputs=eeg_in, outputs=x, name='eeg_preproc')

# Run preprocessing on the entire training set
X_eeg_pre = preproc_model.predict(X_eeg_train, batch_size=16)  # shape (n_train,6,250,1)

# Align shapes and concatenate EEG+HR+EDA
# X_hr_train shape: (n_train, 250, 1) → reshape to (n_train, 1, 250, 1)
X_hr_train = X_hr_train.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)
# X_eda_train shape: (n_train, 250, 1) → reshape to (n_train, 1, 250, 1)
X_eda_train = X_eda_train.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)

X_merged = np.concatenate([X_eeg_pre, X_hr_train, X_eda_train], axis=1)  # shape (n_train,8,250,1)

# Compute channel-wise mean/std
channel_means = X_merged.mean(axis=(0,2,3))  # shape (8,)
channel_stds  = X_merged.std (axis=(0,2,3))  # shape (8,)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
# Build and compile the model
model = PreprocAndEEGNet(
    nb_classes=5,
    channel_means=channel_means,
    channel_stds=channel_stds
)
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    {'eeg_input': X_eeg_train, 'hr_input': X_hr_train, 'eda_input': X_eda_train},
    y_train,
    batch_size=128,
    epochs=1000,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - accuracy: 0.2479 - loss: 1.8569 - val_accuracy: 0.3889 - val_loss: 1.6098
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2558 - loss: 1.5882 - val_accuracy: 0.3333 - val_loss: 1.6088
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.2547 - loss: 1.5738 - val_accuracy: 0.2778 - val_loss: 1.6079
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.3544 - loss: 1.5440 - val_accuracy: 0.2778 - val_loss: 1.6069
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3316 - loss: 1.5508 - val_accuracy: 0.2778 - val_loss: 1.6061
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3869 - loss: 1.5331 - val_accuracy: 0.2778 - val_loss: 1.6054
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3383 - loss: 1.5230 - val_accuracy: 0.2778 - val_loss: 1.6047
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3906 - loss: 1.4977 - val_accuracy: 0.2778 - val_loss: 1.6038
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3801 - loss: 1.4924 - val_accuracy: 0.2778 - val_loss: 1.6027
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4324 - loss: 1.4679 - val_accuracy: 0.2778 - val_loss: 1.6012
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.3626 - loss: 1.4622 - val_accuracy: 0.2778 - val_loss: 1.5996
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3760 - loss: 1.4279 - val_accuracy: 0.2778 - val_loss: 1.5982
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3723 - loss: 1.4288 - val_accuracy: 0.2778 - val_loss: 1.5965
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3544 - loss: 1.4311 - val_accuracy: 0.2778 - val_loss: 1.5947
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.3652 - loss: 1.4310 - val_accuracy: 0.2778 - val_loss: 1.5923
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3775 - loss: 1.4135 - val_accuracy: 0.2778 - val_loss: 1.5896
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4137 - loss: 1.3823 - val_accuracy: 0.2778 - val_loss: 1.5866
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3734 - loss: 1.3730 - val_accuracy: 0.2778 - val_loss: 1.5838
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3880 - loss: 1.3758 - val_accuracy: 0.2778 - val_loss: 1.5807
# Epoch 20/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3966 - loss: 1.3558 - val_accuracy: 0.2778 - val_loss: 1.5770
# Epoch 21/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3951 - loss: 1.3538 - val_accuracy: 0.2778 - val_loss: 1.5732
# Epoch 22/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3791 - loss: 1.3592 - val_accuracy: 0.2778 - val_loss: 1.5691
# Epoch 23/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4044 - loss: 1.3534 - val_accuracy: 0.2778 - val_loss: 1.5653
# Epoch 24/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4081 - loss: 1.3587 - val_accuracy: 0.3889 - val_loss: 1.5617
# Epoch 25/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4070 - loss: 1.3289 - val_accuracy: 0.3889 - val_loss: 1.5589
# Epoch 26/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4406 - loss: 1.3203 - val_accuracy: 0.3889 - val_loss: 1.5562
# Epoch 27/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4059 - loss: 1.3522 - val_accuracy: 0.4444 - val_loss: 1.5534
# Epoch 28/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3940 - loss: 1.3105 - val_accuracy: 0.4444 - val_loss: 1.5507
# Epoch 29/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4111 - loss: 1.3176 - val_accuracy: 0.4444 - val_loss: 1.5486
# Epoch 30/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4432 - loss: 1.3090 - val_accuracy: 0.4444 - val_loss: 1.5463
# Epoch 31/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.4675 - loss: 1.2786 - val_accuracy: 0.4444 - val_loss: 1.5435
# Epoch 32/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4541 - loss: 1.2955 - val_accuracy: 0.4444 - val_loss: 1.5408
# Epoch 33/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4675 - loss: 1.2790 - val_accuracy: 0.4444 - val_loss: 1.5374
# Epoch 34/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4638 - loss: 1.2857 - val_accuracy: 0.4444 - val_loss: 1.5343
# Epoch 35/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4731 - loss: 1.2828 - val_accuracy: 0.4444 - val_loss: 1.5309
# Epoch 36/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4571 - loss: 1.2962 - val_accuracy: 0.4444 - val_loss: 1.5271
# Epoch 37/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4436 - loss: 1.2533 - val_accuracy: 0.4444 - val_loss: 1.5232
# Epoch 38/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4541 - loss: 1.2638 - val_accuracy: 0.4444 - val_loss: 1.5191
# Epoch 39/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4556 - loss: 1.2388 - val_accuracy: 0.4444 - val_loss: 1.5155
# Epoch 40/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4824 - loss: 1.2492 - val_accuracy: 0.4444 - val_loss: 1.5116
# Epoch 41/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4757 - loss: 1.2548 - val_accuracy: 0.4444 - val_loss: 1.5066
# Epoch 42/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4892 - loss: 1.2444 - val_accuracy: 0.4444 - val_loss: 1.5013
# Epoch 43/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4881 - loss: 1.2756 - val_accuracy: 0.4444 - val_loss: 1.4956
# Epoch 44/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4944 - loss: 1.2396 - val_accuracy: 0.4444 - val_loss: 1.4884
# Epoch 45/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5306 - loss: 1.2177 - val_accuracy: 0.4444 - val_loss: 1.4820
# Epoch 46/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5373 - loss: 1.2057 - val_accuracy: 0.4444 - val_loss: 1.4771
# Epoch 47/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5858 - loss: 1.2004 - val_accuracy: 0.4444 - val_loss: 1.4735
# Epoch 48/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5429 - loss: 1.2092 - val_accuracy: 0.4444 - val_loss: 1.4713
# Epoch 49/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5186 - loss: 1.2017 - val_accuracy: 0.3333 - val_loss: 1.4684
# Epoch 50/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5052 - loss: 1.2052 - val_accuracy: 0.3333 - val_loss: 1.4668
# Epoch 51/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5165 - loss: 1.2155 - val_accuracy: 0.3333 - val_loss: 1.4643
# Epoch 52/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5325 - loss: 1.1888 - val_accuracy: 0.3333 - val_loss: 1.4585
# Epoch 53/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5780 - loss: 1.1705 - val_accuracy: 0.3333 - val_loss: 1.4517
# Epoch 54/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4974 - loss: 1.1927 - val_accuracy: 0.3333 - val_loss: 1.4427
# Epoch 55/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5186 - loss: 1.1739 - val_accuracy: 0.3333 - val_loss: 1.4358
# Epoch 56/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5388 - loss: 1.1708 - val_accuracy: 0.3333 - val_loss: 1.4298
# Epoch 57/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5228 - loss: 1.1714 - val_accuracy: 0.4444 - val_loss: 1.4223
# Epoch 58/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5470 - loss: 1.1698 - val_accuracy: 0.5000 - val_loss: 1.4130
# Epoch 59/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5041 - loss: 1.1546 - val_accuracy: 0.5000 - val_loss: 1.4022
# Epoch 60/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5176 - loss: 1.1432 - val_accuracy: 0.5556 - val_loss: 1.3917
# Epoch 61/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5780 - loss: 1.1289 - val_accuracy: 0.5556 - val_loss: 1.3820
# Epoch 62/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4866 - loss: 1.1547 - val_accuracy: 0.5556 - val_loss: 1.3705
# Epoch 63/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5542 - loss: 1.1378 - val_accuracy: 0.5556 - val_loss: 1.3604
# Epoch 64/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5156 - loss: 1.1457 - val_accuracy: 0.5556 - val_loss: 1.3519
# Epoch 65/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5609 - loss: 1.1278 - val_accuracy: 0.5000 - val_loss: 1.3444
# Epoch 66/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5093 - loss: 1.1393 - val_accuracy: 0.5000 - val_loss: 1.3380
# Epoch 67/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5564 - loss: 1.1191 - val_accuracy: 0.5556 - val_loss: 1.3349
# Epoch 68/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5067 - loss: 1.1396 - val_accuracy: 0.5000 - val_loss: 1.3322
# Epoch 69/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5089 - loss: 1.1183 - val_accuracy: 0.5000 - val_loss: 1.3278
# Epoch 70/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5128 - loss: 1.1536 - val_accuracy: 0.5556 - val_loss: 1.3232
# Epoch 71/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5284 - loss: 1.1149 - val_accuracy: 0.5556 - val_loss: 1.3219
# Epoch 72/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5377 - loss: 1.1211 - val_accuracy: 0.5000 - val_loss: 1.3226
# Epoch 73/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5351 - loss: 1.1005 - val_accuracy: 0.5000 - val_loss: 1.3233
# Epoch 74/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5780 - loss: 1.0848 - val_accuracy: 0.5000 - val_loss: 1.3171
# Epoch 75/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5553 - loss: 1.0917 - val_accuracy: 0.5000 - val_loss: 1.3063
# Epoch 76/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5837 - loss: 1.1097 - val_accuracy: 0.5556 - val_loss: 1.2947
# Epoch 77/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5780 - loss: 1.0901 - val_accuracy: 0.5556 - val_loss: 1.2854
# Epoch 78/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5724 - loss: 1.1079 - val_accuracy: 0.6111 - val_loss: 1.2750
# Epoch 79/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5568 - loss: 1.1078 - val_accuracy: 0.6111 - val_loss: 1.2652
# Epoch 80/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6194 - loss: 1.0593 - val_accuracy: 0.6111 - val_loss: 1.2606
# Epoch 81/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5811 - loss: 1.0569 - val_accuracy: 0.6111 - val_loss: 1.2557
# Epoch 82/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5945 - loss: 1.0652 - val_accuracy: 0.6111 - val_loss: 1.2505
# Epoch 83/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5769 - loss: 1.0818 - val_accuracy: 0.6111 - val_loss: 1.2425
# Epoch 84/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5837 - loss: 1.0592 - val_accuracy: 0.6111 - val_loss: 1.2281
# Epoch 85/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6038 - loss: 1.0707 - val_accuracy: 0.6667 - val_loss: 1.2098
# Epoch 86/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5811 - loss: 1.0711 - val_accuracy: 0.6667 - val_loss: 1.1949
# Epoch 87/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6411 - loss: 1.0275 - val_accuracy: 0.6111 - val_loss: 1.1799
# Epoch 88/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6075 - loss: 1.0545 - val_accuracy: 0.6111 - val_loss: 1.1656
# Epoch 89/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6090 - loss: 1.0454 - val_accuracy: 0.6111 - val_loss: 1.1492
# Epoch 90/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6142 - loss: 1.0359 - val_accuracy: 0.6111 - val_loss: 1.1348
# Epoch 91/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5553 - loss: 1.0589 - val_accuracy: 0.6111 - val_loss: 1.1252
# Epoch 92/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6225 - loss: 1.0556 - val_accuracy: 0.6667 - val_loss: 1.1162
# Epoch 93/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5795 - loss: 1.0363 - val_accuracy: 0.6667 - val_loss: 1.1065
# Epoch 94/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5564 - loss: 1.0467 - val_accuracy: 0.6667 - val_loss: 1.0994
# Epoch 95/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6023 - loss: 1.0264 - val_accuracy: 0.6667 - val_loss: 1.0960
# Epoch 96/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5784 - loss: 1.0554 - val_accuracy: 0.6667 - val_loss: 1.0983
# Epoch 97/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5754 - loss: 1.0074 - val_accuracy: 0.7222 - val_loss: 1.1055
# Epoch 98/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.6090 - loss: 1.0158 - val_accuracy: 0.7222 - val_loss: 1.1116
# Epoch 99/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.6012 - loss: 1.0215 - val_accuracy: 0.7222 - val_loss: 1.1164
# Epoch 100/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5769 - loss: 1.0457 - val_accuracy: 0.7222 - val_loss: 1.1141
# Epoch 101/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5960 - loss: 1.0128 - val_accuracy: 0.7222 - val_loss: 1.1062
# Epoch 102/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5728 - loss: 1.0161 - val_accuracy: 0.7222 - val_loss: 1.0938
# Epoch 103/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5739 - loss: 1.0265 - val_accuracy: 0.7222 - val_loss: 1.0710
# Epoch 104/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6333 - loss: 1.0140 - val_accuracy: 0.7222 - val_loss: 1.0474
# Epoch 105/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6042 - loss: 1.0321 - val_accuracy: 0.7222 - val_loss: 1.0280
# Epoch 106/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6079 - loss: 0.9996 - val_accuracy: 0.7778 - val_loss: 1.0100
# Epoch 107/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6214 - loss: 1.0015 - val_accuracy: 0.7778 - val_loss: 0.9973
# Epoch 108/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5982 - loss: 1.0014 - val_accuracy: 0.7222 - val_loss: 0.9871
# Epoch 109/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6296 - loss: 1.0172 - val_accuracy: 0.7222 - val_loss: 0.9782
# Epoch 110/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6188 - loss: 0.9849 - val_accuracy: 0.7222 - val_loss: 0.9724
# Epoch 111/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6467 - loss: 0.9966 - val_accuracy: 0.7222 - val_loss: 0.9677
# Epoch 112/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6225 - loss: 1.0028 - val_accuracy: 0.7222 - val_loss: 0.9646
# Epoch 113/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6576 - loss: 0.9969 - val_accuracy: 0.7222 - val_loss: 0.9603
# Epoch 114/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5900 - loss: 0.9928 - val_accuracy: 0.7778 - val_loss: 0.9518
# Epoch 115/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6060 - loss: 0.9702 - val_accuracy: 0.7222 - val_loss: 0.9436
# Epoch 116/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6348 - loss: 0.9692 - val_accuracy: 0.7222 - val_loss: 0.9355
# Epoch 117/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5605 - loss: 0.9953 - val_accuracy: 0.7222 - val_loss: 0.9305
# Epoch 118/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6452 - loss: 0.9617 - val_accuracy: 0.7222 - val_loss: 0.9260
# Epoch 119/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6008 - loss: 1.0030 - val_accuracy: 0.7222 - val_loss: 0.9220
# Epoch 120/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6684 - loss: 0.9657 - val_accuracy: 0.7222 - val_loss: 0.9181
# Epoch 121/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5784 - loss: 1.0111 - val_accuracy: 0.6667 - val_loss: 0.9178
# Epoch 122/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6075 - loss: 0.9677 - val_accuracy: 0.6111 - val_loss: 0.9180
# Epoch 123/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6053 - loss: 0.9767 - val_accuracy: 0.6667 - val_loss: 0.9212
# Epoch 124/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6240 - loss: 0.9807 - val_accuracy: 0.6111 - val_loss: 0.9256
# Epoch 125/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5867 - loss: 0.9801 - val_accuracy: 0.6111 - val_loss: 0.9277
# Epoch 126/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6214 - loss: 0.9661 - val_accuracy: 0.5556 - val_loss: 0.9294
# Epoch 127/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6419 - loss: 0.9582 - val_accuracy: 0.5556 - val_loss: 0.9324
# Epoch 128/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6064 - loss: 0.9740 - val_accuracy: 0.5556 - val_loss: 0.9348
# Epoch 129/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6441 - loss: 0.9780 - val_accuracy: 0.5556 - val_loss: 0.9335
# Epoch 130/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6105 - loss: 0.9514 - val_accuracy: 0.5556 - val_loss: 0.9295
# Epoch 131/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6441 - loss: 0.9719 - val_accuracy: 0.5556 - val_loss: 0.9266
# Epoch 132/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6508 - loss: 0.9517 - val_accuracy: 0.6111 - val_loss: 0.9232
# Epoch 133/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6110 - loss: 0.9796 - val_accuracy: 0.6111 - val_loss: 0.9184
# Epoch 134/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6385 - loss: 0.9528 - val_accuracy: 0.6667 - val_loss: 0.9137
# Epoch 135/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6355 - loss: 0.9448 - val_accuracy: 0.6667 - val_loss: 0.9086
# Epoch 136/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6318 - loss: 0.9307 - val_accuracy: 0.6667 - val_loss: 0.9053
# Epoch 137/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6292 - loss: 0.9543 - val_accuracy: 0.6667 - val_loss: 0.9055
# Epoch 138/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6643 - loss: 0.9271 - val_accuracy: 0.6667 - val_loss: 0.9087
# Epoch 139/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6632 - loss: 0.9508 - val_accuracy: 0.6667 - val_loss: 0.9160
# Epoch 140/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6162 - loss: 0.9679 - val_accuracy: 0.6667 - val_loss: 0.9215
# Epoch 141/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6777 - loss: 0.9234 - val_accuracy: 0.6111 - val_loss: 0.9254
# Epoch 142/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6617 - loss: 0.9217 - val_accuracy: 0.6111 - val_loss: 0.9283
# Epoch 143/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5934 - loss: 0.9473 - val_accuracy: 0.6111 - val_loss: 0.9267
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6498 - loss: 0.9290 - val_accuracy: 0.6111 - val_loss: 0.9230
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5878 - loss: 0.9404 - val_accuracy: 0.6111 - val_loss: 0.9151
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6389 - loss: 0.9462 - val_accuracy: 0.6111 - val_loss: 0.9072
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6441 - loss: 0.9144 - val_accuracy: 0.6111 - val_loss: 0.8993
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6456 - loss: 0.9200 - val_accuracy: 0.6667 - val_loss: 0.8901
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6535 - loss: 0.9432 - val_accuracy: 0.6667 - val_loss: 0.8804
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6430 - loss: 0.9534 - val_accuracy: 0.6667 - val_loss: 0.8714
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6617 - loss: 0.8916 - val_accuracy: 0.7222 - val_loss: 0.8611
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6725 - loss: 0.8857 - val_accuracy: 0.7222 - val_loss: 0.8481
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6647 - loss: 0.9217 - val_accuracy: 0.7222 - val_loss: 0.8368
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6669 - loss: 0.8995 - val_accuracy: 0.7778 - val_loss: 0.8266
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6740 - loss: 0.9039 - val_accuracy: 0.7778 - val_loss: 0.8226
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6673 - loss: 0.9142 - val_accuracy: 0.7778 - val_loss: 0.8230
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6400 - loss: 0.9016 - val_accuracy: 0.7222 - val_loss: 0.8233
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6912 - loss: 0.8752 - val_accuracy: 0.7222 - val_loss: 0.8220
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6591 - loss: 0.8690 - val_accuracy: 0.7222 - val_loss: 0.8218
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6556 - loss: 0.9236 - val_accuracy: 0.7222 - val_loss: 0.8196
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6606 - loss: 0.9185 - val_accuracy: 0.7222 - val_loss: 0.8180
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6751 - loss: 0.8836 - val_accuracy: 0.7222 - val_loss: 0.8129
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7087 - loss: 0.8892 - val_accuracy: 0.7778 - val_loss: 0.8069
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6710 - loss: 0.8836 - val_accuracy: 0.7778 - val_loss: 0.8059
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7169 - loss: 0.8472 - val_accuracy: 0.7222 - val_loss: 0.8108
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6807 - loss: 0.8720 - val_accuracy: 0.7222 - val_loss: 0.8145
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6606 - loss: 0.8434 - val_accuracy: 0.6667 - val_loss: 0.8150
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6467 - loss: 0.8802 - val_accuracy: 0.6667 - val_loss: 0.8155
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6714 - loss: 0.8687 - val_accuracy: 0.6667 - val_loss: 0.8155
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6441 - loss: 0.8719 - val_accuracy: 0.6667 - val_loss: 0.8180
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6441 - loss: 0.8530 - val_accuracy: 0.6667 - val_loss: 0.8199
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6105 - loss: 0.8944 - val_accuracy: 0.6667 - val_loss: 0.8211
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6710 - loss: 0.8448 - val_accuracy: 0.7222 - val_loss: 0.8256
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6643 - loss: 0.8792 - val_accuracy: 0.7222 - val_loss: 0.8273
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6105 - loss: 0.9082 - val_accuracy: 0.7222 - val_loss: 0.8278
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6740 - loss: 0.8556 - val_accuracy: 0.7222 - val_loss: 0.8299
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6617 - loss: 0.8708 - val_accuracy: 0.7222 - val_loss: 0.8345
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7061 - loss: 0.8569 - val_accuracy: 0.7222 - val_loss: 0.8366
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6632 - loss: 0.8748 - val_accuracy: 0.7222 - val_loss: 0.8291
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6240 - loss: 0.8708 - val_accuracy: 0.7222 - val_loss: 0.8200
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6415 - loss: 0.8433 - val_accuracy: 0.7222 - val_loss: 0.8135
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6803 - loss: 0.8791 - val_accuracy: 0.7222 - val_loss: 0.8105
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6897 - loss: 0.8485 - val_accuracy: 0.7222 - val_loss: 0.8021
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6333 - loss: 0.8499 - val_accuracy: 0.7222 - val_loss: 0.7926
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6751 - loss: 0.8586 - val_accuracy: 0.7222 - val_loss: 0.7867
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7061 - loss: 0.8250 - val_accuracy: 0.7778 - val_loss: 0.7805
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6576 - loss: 0.8603 - val_accuracy: 0.7778 - val_loss: 0.7778
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6513 - loss: 0.8581 - val_accuracy: 0.7778 - val_loss: 0.7766
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6875 - loss: 0.8346 - val_accuracy: 0.7778 - val_loss: 0.7776
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6643 - loss: 0.8512 - val_accuracy: 0.7778 - val_loss: 0.7861
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6524 - loss: 0.8606 - val_accuracy: 0.7222 - val_loss: 0.7998
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6404 - loss: 0.8490 - val_accuracy: 0.7222 - val_loss: 0.8129
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6886 - loss: 0.8396 - val_accuracy: 0.7222 - val_loss: 0.8191
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6823 - loss: 0.8377 - val_accuracy: 0.7222 - val_loss: 0.8159
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6456 - loss: 0.8264 - val_accuracy: 0.7222 - val_loss: 0.8054
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6632 - loss: 0.8716 - val_accuracy: 0.7778 - val_loss: 0.7987
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6762 - loss: 0.8699 - val_accuracy: 0.7778 - val_loss: 0.7976
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7020 - loss: 0.8225 - val_accuracy: 0.7778 - val_loss: 0.8010
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7237 - loss: 0.8350 - val_accuracy: 0.7778 - val_loss: 0.8039
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7061 - loss: 0.8229 - val_accuracy: 0.7778 - val_loss: 0.8067
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6953 - loss: 0.8509 - val_accuracy: 0.7778 - val_loss: 0.8057
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6829 - loss: 0.8391 - val_accuracy: 0.7778 - val_loss: 0.8042
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6994 - loss: 0.8189 - val_accuracy: 0.7778 - val_loss: 0.8013
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6823 - loss: 0.8515 - val_accuracy: 0.7778 - val_loss: 0.8012
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6699 - loss: 0.8388 - val_accuracy: 0.7778 - val_loss: 0.8031
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7087 - loss: 0.7827 - val_accuracy: 0.7778 - val_loss: 0.7977
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6788 - loss: 0.8125 - val_accuracy: 0.7778 - val_loss: 0.7882
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6849 - loss: 0.8275 - val_accuracy: 0.7778 - val_loss: 0.7814
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7083 - loss: 0.8044 - val_accuracy: 0.7778 - val_loss: 0.7730
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6792 - loss: 0.8086 - val_accuracy: 0.7778 - val_loss: 0.7655
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7042 - loss: 0.8177 - val_accuracy: 0.7778 - val_loss: 0.7602
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6628 - loss: 0.8132 - val_accuracy: 0.7778 - val_loss: 0.7561
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6901 - loss: 0.8218 - val_accuracy: 0.7778 - val_loss: 0.7542
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7274 - loss: 0.8222 - val_accuracy: 0.7778 - val_loss: 0.7618
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6916 - loss: 0.8017 - val_accuracy: 0.7778 - val_loss: 0.7729
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6870 - loss: 0.7848 - val_accuracy: 0.7778 - val_loss: 0.7857
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6781 - loss: 0.8318 - val_accuracy: 0.7222 - val_loss: 0.7977
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7020 - loss: 0.8107 - val_accuracy: 0.7222 - val_loss: 0.8050
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6818 - loss: 0.8199 - val_accuracy: 0.7222 - val_loss: 0.8042
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6777 - loss: 0.8148 - val_accuracy: 0.7222 - val_loss: 0.7961
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7345 - loss: 0.8010 - val_accuracy: 0.7222 - val_loss: 0.7852
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6744 - loss: 0.7976 - val_accuracy: 0.7222 - val_loss: 0.7754
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7128 - loss: 0.7873 - val_accuracy: 0.7222 - val_loss: 0.7708
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6979 - loss: 0.7910 - val_accuracy: 0.7222 - val_loss: 0.7660
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6688 - loss: 0.8337 - val_accuracy: 0.7222 - val_loss: 0.7614
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7083 - loss: 0.7962 - val_accuracy: 0.7222 - val_loss: 0.7561
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7233 - loss: 0.7627 - val_accuracy: 0.7222 - val_loss: 0.7495
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6942 - loss: 0.7833 - val_accuracy: 0.7222 - val_loss: 0.7441
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6890 - loss: 0.7833 - val_accuracy: 0.7222 - val_loss: 0.7439
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6803 - loss: 0.7924 - val_accuracy: 0.7222 - val_loss: 0.7465
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7479 - loss: 0.7762 - val_accuracy: 0.7222 - val_loss: 0.7521
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6725 - loss: 0.8025 - val_accuracy: 0.7222 - val_loss: 0.7607
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7248 - loss: 0.7760 - val_accuracy: 0.7222 - val_loss: 0.7700
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7128 - loss: 0.7938 - val_accuracy: 0.7222 - val_loss: 0.7783
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7035 - loss: 0.7824 - val_accuracy: 0.7222 - val_loss: 0.7833
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6807 - loss: 0.7997 - val_accuracy: 0.7222 - val_loss: 0.7880
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7065 - loss: 0.7899 - val_accuracy: 0.7222 - val_loss: 0.7892
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7102 - loss: 0.7716 - val_accuracy: 0.7222 - val_loss: 0.7818
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7304 - loss: 0.7822 - val_accuracy: 0.7222 - val_loss: 0.7685
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7319 - loss: 0.7457 - val_accuracy: 0.7222 - val_loss: 0.7546
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7427 - loss: 0.7696 - val_accuracy: 0.7222 - val_loss: 0.7420
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7293 - loss: 0.7721 - val_accuracy: 0.7222 - val_loss: 0.7298
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6864 - loss: 0.7839 - val_accuracy: 0.7778 - val_loss: 0.7196
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7505 - loss: 0.7587 - val_accuracy: 0.7222 - val_loss: 0.7134
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7076 - loss: 0.7747 - val_accuracy: 0.7222 - val_loss: 0.7096
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7360 - loss: 0.7531 - val_accuracy: 0.7222 - val_loss: 0.7090
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7464 - loss: 0.7594 - val_accuracy: 0.7222 - val_loss: 0.7077
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7222 - loss: 0.7399 - val_accuracy: 0.7222 - val_loss: 0.7005
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6994 - loss: 0.7764 - val_accuracy: 0.7222 - val_loss: 0.6918
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7241 - loss: 0.7797 - val_accuracy: 0.7222 - val_loss: 0.6885
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6766 - loss: 0.7750 - val_accuracy: 0.7778 - val_loss: 0.6876
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7169 - loss: 0.7651 - val_accuracy: 0.7778 - val_loss: 0.6865
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6994 - loss: 0.7609 - val_accuracy: 0.7778 - val_loss: 0.6888
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6539 - loss: 0.7914 - val_accuracy: 0.7778 - val_loss: 0.6887
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7200 - loss: 0.7473 - val_accuracy: 0.7778 - val_loss: 0.6913
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6834 - loss: 0.7872 - val_accuracy: 0.7778 - val_loss: 0.6966
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7241 - loss: 0.7497 - val_accuracy: 0.7778 - val_loss: 0.7036
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7150 - loss: 0.7783 - val_accuracy: 0.7222 - val_loss: 0.7077
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6901 - loss: 0.7450 - val_accuracy: 0.7778 - val_loss: 0.7063
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6901 - loss: 0.7560 - val_accuracy: 0.7778 - val_loss: 0.7047
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6647 - loss: 0.7749 - val_accuracy: 0.7778 - val_loss: 0.7008
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7293 - loss: 0.7580 - val_accuracy: 0.7778 - val_loss: 0.6983
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7009 - loss: 0.7477 - val_accuracy: 0.7778 - val_loss: 0.7016
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7289 - loss: 0.7387 - val_accuracy: 0.7778 - val_loss: 0.7079
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7412 - loss: 0.7402 - val_accuracy: 0.7778 - val_loss: 0.7090
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7159 - loss: 0.7600 - val_accuracy: 0.7778 - val_loss: 0.7139
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7438 - loss: 0.7172 - val_accuracy: 0.7778 - val_loss: 0.7138
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6998 - loss: 0.7395 - val_accuracy: 0.7778 - val_loss: 0.7080
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7009 - loss: 0.7620 - val_accuracy: 0.7778 - val_loss: 0.7014
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7222 - loss: 0.7343 - val_accuracy: 0.7778 - val_loss: 0.6924
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7304 - loss: 0.7321 - val_accuracy: 0.7778 - val_loss: 0.6811
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6994 - loss: 0.7303 - val_accuracy: 0.7778 - val_loss: 0.6710
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6886 - loss: 0.7567 - val_accuracy: 0.7778 - val_loss: 0.6676
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6916 - loss: 0.7343 - val_accuracy: 0.7778 - val_loss: 0.6707
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7453 - loss: 0.7364 - val_accuracy: 0.7778 - val_loss: 0.6762
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6968 - loss: 0.7329 - val_accuracy: 0.7778 - val_loss: 0.6794
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6942 - loss: 0.7587 - val_accuracy: 0.7778 - val_loss: 0.6784
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7154 - loss: 0.7348 - val_accuracy: 0.7778 - val_loss: 0.6740
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7013 - loss: 0.7255 - val_accuracy: 0.7778 - val_loss: 0.6713
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6942 - loss: 0.7343 - val_accuracy: 0.7778 - val_loss: 0.6721
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7046 - loss: 0.7177 - val_accuracy: 0.7778 - val_loss: 0.6760
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6901 - loss: 0.7242 - val_accuracy: 0.7778 - val_loss: 0.6825
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7200 - loss: 0.7255 - val_accuracy: 0.7778 - val_loss: 0.6891
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6725 - loss: 0.7571 - val_accuracy: 0.7778 - val_loss: 0.6951
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7061 - loss: 0.7247 - val_accuracy: 0.7778 - val_loss: 0.6968
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7087 - loss: 0.7487 - val_accuracy: 0.7778 - val_loss: 0.6970
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7233 - loss: 0.7172 - val_accuracy: 0.7778 - val_loss: 0.6911
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7191 - loss: 0.7431 - val_accuracy: 0.7778 - val_loss: 0.6836
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6840 - loss: 0.7603 - val_accuracy: 0.7778 - val_loss: 0.6742
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7629 - loss: 0.7267 - val_accuracy: 0.7778 - val_loss: 0.6631
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7360 - loss: 0.7260 - val_accuracy: 0.7778 - val_loss: 0.6556
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7334 - loss: 0.7482 - val_accuracy: 0.7778 - val_loss: 0.6523
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7154 - loss: 0.7241 - val_accuracy: 0.7778 - val_loss: 0.6592
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7495 - loss: 0.7183 - val_accuracy: 0.7778 - val_loss: 0.6694
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7009 - loss: 0.7314 - val_accuracy: 0.7778 - val_loss: 0.6785
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7319 - loss: 0.7107 - val_accuracy: 0.7778 - val_loss: 0.6852
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7128 - loss: 0.7253 - val_accuracy: 0.7778 - val_loss: 0.6885
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7495 - loss: 0.7364 - val_accuracy: 0.7778 - val_loss: 0.6825
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6844 - loss: 0.7385 - val_accuracy: 0.7778 - val_loss: 0.6714
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7913 - loss: 0.6840 - val_accuracy: 0.7778 - val_loss: 0.6578
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7371 - loss: 0.7161 - val_accuracy: 0.7778 - val_loss: 0.6486
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7763 - loss: 0.7020 - val_accuracy: 0.7778 - val_loss: 0.6506
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7846 - loss: 0.7141 - val_accuracy: 0.7778 - val_loss: 0.6585
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7143 - loss: 0.7144 - val_accuracy: 0.7778 - val_loss: 0.6649
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7159 - loss: 0.7401 - val_accuracy: 0.7778 - val_loss: 0.6671
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7495 - loss: 0.6984 - val_accuracy: 0.7778 - val_loss: 0.6629
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7237 - loss: 0.6973 - val_accuracy: 0.7778 - val_loss: 0.6552
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7464 - loss: 0.7111 - val_accuracy: 0.7778 - val_loss: 0.6469
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7382 - loss: 0.6924 - val_accuracy: 0.7778 - val_loss: 0.6382
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7815 - loss: 0.6847 - val_accuracy: 0.7778 - val_loss: 0.6296
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7375 - loss: 0.7111 - val_accuracy: 0.7778 - val_loss: 0.6239
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7495 - loss: 0.7003 - val_accuracy: 0.7778 - val_loss: 0.6225
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7588 - loss: 0.6841 - val_accuracy: 0.7778 - val_loss: 0.6273
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7304 - loss: 0.7035 - val_accuracy: 0.7778 - val_loss: 0.6295
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7143 - loss: 0.6937 - val_accuracy: 0.7778 - val_loss: 0.6286
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7375 - loss: 0.7020 - val_accuracy: 0.7778 - val_loss: 0.6341
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7215 - loss: 0.7172 - val_accuracy: 0.7778 - val_loss: 0.6400
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7505 - loss: 0.6974 - val_accuracy: 0.7778 - val_loss: 0.6408
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7397 - loss: 0.6790 - val_accuracy: 0.7778 - val_loss: 0.6416
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7521 - loss: 0.6859 - val_accuracy: 0.7778 - val_loss: 0.6457
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7495 - loss: 0.6638 - val_accuracy: 0.7778 - val_loss: 0.6515
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7386 - loss: 0.6715 - val_accuracy: 0.7778 - val_loss: 0.6512
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7800 - loss: 0.6402 - val_accuracy: 0.7778 - val_loss: 0.6475
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7453 - loss: 0.6854 - val_accuracy: 0.7778 - val_loss: 0.6410
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7883 - loss: 0.6602 - val_accuracy: 0.7778 - val_loss: 0.6344
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7599 - loss: 0.6778 - val_accuracy: 0.8333 - val_loss: 0.6289
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7898 - loss: 0.6369 - val_accuracy: 0.8333 - val_loss: 0.6265
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7629 - loss: 0.6956 - val_accuracy: 0.8333 - val_loss: 0.6257
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7532 - loss: 0.6977 - val_accuracy: 0.7222 - val_loss: 0.6295
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7599 - loss: 0.6872 - val_accuracy: 0.7222 - val_loss: 0.6278
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7588 - loss: 0.6814 - val_accuracy: 0.7222 - val_loss: 0.6233
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7883 - loss: 0.6786 - val_accuracy: 0.7222 - val_loss: 0.6205
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7655 - loss: 0.6860 - val_accuracy: 0.7222 - val_loss: 0.6286
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7913 - loss: 0.6464 - val_accuracy: 0.6667 - val_loss: 0.6374
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7599 - loss: 0.6864 - val_accuracy: 0.6667 - val_loss: 0.6406
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7416 - loss: 0.6698 - val_accuracy: 0.6667 - val_loss: 0.6405
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7685 - loss: 0.6517 - val_accuracy: 0.6667 - val_loss: 0.6402
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7857 - loss: 0.6511 - val_accuracy: 0.7778 - val_loss: 0.6351
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7722 - loss: 0.6478 - val_accuracy: 0.7778 - val_loss: 0.6284
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7800 - loss: 0.6451 - val_accuracy: 0.7778 - val_loss: 0.6207
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7603 - loss: 0.6448 - val_accuracy: 0.7778 - val_loss: 0.6136
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7510 - loss: 0.6592 - val_accuracy: 0.7778 - val_loss: 0.6076
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7629 - loss: 0.6673 - val_accuracy: 0.7778 - val_loss: 0.6068
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7831 - loss: 0.6514 - val_accuracy: 0.7778 - val_loss: 0.6050
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7326 - loss: 0.6693 - val_accuracy: 0.7778 - val_loss: 0.5997
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7987 - loss: 0.6155 - val_accuracy: 0.8333 - val_loss: 0.5924
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7935 - loss: 0.6393 - val_accuracy: 0.8889 - val_loss: 0.5883
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8032 - loss: 0.6295 - val_accuracy: 0.8889 - val_loss: 0.5855
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7913 - loss: 0.6382 - val_accuracy: 0.8889 - val_loss: 0.5872
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7453 - loss: 0.6399 - val_accuracy: 0.8333 - val_loss: 0.5930
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7752 - loss: 0.6396 - val_accuracy: 0.8333 - val_loss: 0.6068
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7185 - loss: 0.6829 - val_accuracy: 0.7778 - val_loss: 0.6234
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7453 - loss: 0.6629 - val_accuracy: 0.7778 - val_loss: 0.6331
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8032 - loss: 0.6396 - val_accuracy: 0.7778 - val_loss: 0.6295
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7551 - loss: 0.6747 - val_accuracy: 0.7778 - val_loss: 0.6172
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7909 - loss: 0.6450 - val_accuracy: 0.8333 - val_loss: 0.6048
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7861 - loss: 0.6253 - val_accuracy: 0.8333 - val_loss: 0.5896
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7841 - loss: 0.6429 - val_accuracy: 0.8889 - val_loss: 0.5733
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7495 - loss: 0.6364 - val_accuracy: 0.8889 - val_loss: 0.5637
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8151 - loss: 0.6285 - val_accuracy: 0.8333 - val_loss: 0.5632
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8151 - loss: 0.6428 - val_accuracy: 0.7778 - val_loss: 0.5651
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7711 - loss: 0.6398 - val_accuracy: 0.7778 - val_loss: 0.5690
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7588 - loss: 0.6552 - val_accuracy: 0.7778 - val_loss: 0.5688
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8017 - loss: 0.6541 - val_accuracy: 0.8333 - val_loss: 0.5683
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7711 - loss: 0.6381 - val_accuracy: 0.8333 - val_loss: 0.5614
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8125 - loss: 0.6141 - val_accuracy: 0.8889 - val_loss: 0.5481
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7924 - loss: 0.6273 - val_accuracy: 0.8889 - val_loss: 0.5270
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7562 - loss: 0.6241 - val_accuracy: 0.8889 - val_loss: 0.5112
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7640 - loss: 0.6615 - val_accuracy: 0.8889 - val_loss: 0.5013
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8043 - loss: 0.6111 - val_accuracy: 0.9444 - val_loss: 0.4987
# Epoch 371/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7722 - loss: 0.6443 - val_accuracy: 0.9444 - val_loss: 0.5015
# Epoch 372/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7748 - loss: 0.6207 - val_accuracy: 0.8889 - val_loss: 0.5096
# Epoch 373/1000
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8704 - loss: 0.3824 - val_accuracy: 0.9444 - val_loss: 0.2930
# Epoch 878/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8749 - loss: 0.3778 - val_accuracy: 0.9444 - val_loss: 0.2908
# Epoch 879/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8760 - loss: 0.3836 - val_accuracy: 0.9444 - val_loss: 0.3040
# Epoch 880/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8854 - loss: 0.3572 - val_accuracy: 0.8889 - val_loss: 0.3224
# Epoch 881/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8977 - loss: 0.3430 - val_accuracy: 0.8889 - val_loss: 0.3413
# Epoch 882/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8760 - loss: 0.3915 - val_accuracy: 0.8333 - val_loss: 0.3490
# Epoch 883/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8895 - loss: 0.3920 - val_accuracy: 0.8333 - val_loss: 0.3503
# Epoch 884/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8734 - loss: 0.3701 - val_accuracy: 0.8333 - val_loss: 0.3538
# Epoch 885/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8559 - loss: 0.4119 - val_accuracy: 0.8889 - val_loss: 0.3583
# Epoch 886/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9107 - loss: 0.3698 - val_accuracy: 0.8889 - val_loss: 0.3662
# Epoch 887/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8611 - loss: 0.3973 - val_accuracy: 0.8333 - val_loss: 0.3810
# Epoch 888/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8786 - loss: 0.3763 - val_accuracy: 0.8333 - val_loss: 0.3909
# Epoch 889/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8487 - loss: 0.3943 - val_accuracy: 0.8333 - val_loss: 0.3954
# Epoch 890/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8719 - loss: 0.3988 - val_accuracy: 0.8333 - val_loss: 0.3909
# Epoch 891/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8895 - loss: 0.3638 - val_accuracy: 0.8333 - val_loss: 0.3909
# Epoch 892/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9029 - loss: 0.3684 - val_accuracy: 0.8333 - val_loss: 0.3992
# Epoch 893/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8838 - loss: 0.3748 - val_accuracy: 0.8333 - val_loss: 0.4113
# Epoch 894/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8741 - loss: 0.4122 - val_accuracy: 0.8333 - val_loss: 0.4254
# Epoch 895/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8775 - loss: 0.3762 - val_accuracy: 0.8333 - val_loss: 0.4493
# Epoch 896/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8786 - loss: 0.4053 - val_accuracy: 0.8333 - val_loss: 0.4839
# Epoch 897/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8637 - loss: 0.3948 - val_accuracy: 0.8333 - val_loss: 0.5045
# Epoch 898/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8827 - loss: 0.3855 - val_accuracy: 0.8333 - val_loss: 0.4864
# Epoch 899/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8880 - loss: 0.4038 - val_accuracy: 0.8333 - val_loss: 0.4456
# Epoch 900/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8962 - loss: 0.3615 - val_accuracy: 0.8333 - val_loss: 0.4000
# Epoch 901/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8544 - loss: 0.4039 - val_accuracy: 0.8333 - val_loss: 0.3680
# Epoch 902/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8988 - loss: 0.3661 - val_accuracy: 0.8333 - val_loss: 0.3456
# Epoch 903/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8906 - loss: 0.4065 - val_accuracy: 0.8333 - val_loss: 0.3348
# Epoch 904/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8626 - loss: 0.3857 - val_accuracy: 0.8333 - val_loss: 0.3326
# Epoch 905/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8730 - loss: 0.3706 - val_accuracy: 0.8333 - val_loss: 0.3358
# Epoch 906/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8734 - loss: 0.3659 - val_accuracy: 0.8333 - val_loss: 0.3435
# Epoch 907/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8704 - loss: 0.3798 - val_accuracy: 0.8333 - val_loss: 0.3465
# Epoch 908/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8947 - loss: 0.3575 - val_accuracy: 0.7778 - val_loss: 0.3460
# Epoch 909/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8756 - loss: 0.3704 - val_accuracy: 0.8333 - val_loss: 0.3448
# Epoch 910/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8854 - loss: 0.3657 - val_accuracy: 0.8333 - val_loss: 0.3503
# Epoch 911/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8719 - loss: 0.3639 - val_accuracy: 0.8333 - val_loss: 0.3667
# Epoch 912/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8823 - loss: 0.3734 - val_accuracy: 0.7778 - val_loss: 0.3923
# Epoch 913/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8570 - loss: 0.3998 - val_accuracy: 0.7778 - val_loss: 0.4057
# Epoch 914/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8559 - loss: 0.3802 - val_accuracy: 0.8333 - val_loss: 0.4077
# Epoch 915/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9029 - loss: 0.3617 - val_accuracy: 0.7778 - val_loss: 0.3995
# Epoch 916/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8921 - loss: 0.3667 - val_accuracy: 0.7778 - val_loss: 0.3807
# Epoch 917/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8749 - loss: 0.3798 - val_accuracy: 0.8333 - val_loss: 0.3669
# Epoch 918/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8611 - loss: 0.4133 - val_accuracy: 0.8333 - val_loss: 0.3566
# Epoch 919/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8880 - loss: 0.3757 - val_accuracy: 0.8333 - val_loss: 0.3555
# Epoch 920/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8854 - loss: 0.3508 - val_accuracy: 0.8333 - val_loss: 0.3495
# Epoch 921/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8921 - loss: 0.3597 - val_accuracy: 0.8333 - val_loss: 0.3342
# Epoch 922/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8910 - loss: 0.3664 - val_accuracy: 0.8889 - val_loss: 0.3163
# Epoch 923/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8775 - loss: 0.3911 - val_accuracy: 0.8889 - val_loss: 0.3038
# Epoch 924/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8801 - loss: 0.3555 - val_accuracy: 0.9444 - val_loss: 0.2952
# Epoch 925/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8838 - loss: 0.3623 - val_accuracy: 0.9444 - val_loss: 0.2882
# Epoch 926/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8921 - loss: 0.3550 - val_accuracy: 1.0000 - val_loss: 0.2864
# Epoch 927/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8667 - loss: 0.3961 - val_accuracy: 1.0000 - val_loss: 0.2855
# Epoch 928/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8962 - loss: 0.3651 - val_accuracy: 1.0000 - val_loss: 0.2864
# Epoch 929/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9029 - loss: 0.3578 - val_accuracy: 1.0000 - val_loss: 0.2927
# Epoch 930/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8368 - loss: 0.4164 - val_accuracy: 1.0000 - val_loss: 0.2993
# Epoch 931/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9018 - loss: 0.3506 - val_accuracy: 0.8889 - val_loss: 0.3083
# Epoch 932/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8760 - loss: 0.3759 - val_accuracy: 0.8333 - val_loss: 0.3196
# Epoch 933/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9003 - loss: 0.3829 - val_accuracy: 0.8889 - val_loss: 0.3261
# Epoch 934/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9205 - loss: 0.3492 - val_accuracy: 0.8889 - val_loss: 0.3263
# Epoch 935/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8936 - loss: 0.3560 - val_accuracy: 0.8889 - val_loss: 0.3273
# Epoch 936/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9092 - loss: 0.3416 - val_accuracy: 0.8889 - val_loss: 0.3318
# Epoch 937/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9081 - loss: 0.3356 - val_accuracy: 0.8889 - val_loss: 0.3370
# Epoch 938/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8827 - loss: 0.3639 - val_accuracy: 0.8889 - val_loss: 0.3449
# Epoch 939/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9179 - loss: 0.3613 - val_accuracy: 0.8889 - val_loss: 0.3593
# Epoch 940/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8827 - loss: 0.3516 - val_accuracy: 0.8333 - val_loss: 0.3674
# Epoch 941/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8600 - loss: 0.3938 - val_accuracy: 0.8333 - val_loss: 0.3641
# Epoch 942/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8947 - loss: 0.3628 - val_accuracy: 0.8889 - val_loss: 0.3481
# Epoch 943/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8719 - loss: 0.3750 - val_accuracy: 0.8889 - val_loss: 0.3207
# Epoch 944/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8962 - loss: 0.3507 - val_accuracy: 0.9444 - val_loss: 0.2927
# Epoch 945/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9231 - loss: 0.3322 - val_accuracy: 1.0000 - val_loss: 0.2796
# Epoch 946/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8786 - loss: 0.3535 - val_accuracy: 1.0000 - val_loss: 0.2750
# Epoch 947/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8760 - loss: 0.3622 - val_accuracy: 1.0000 - val_loss: 0.2772
# Epoch 948/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8719 - loss: 0.3774 - val_accuracy: 1.0000 - val_loss: 0.2836
# Epoch 949/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8921 - loss: 0.3483 - val_accuracy: 1.0000 - val_loss: 0.2897
# Epoch 950/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8626 - loss: 0.4098 - val_accuracy: 1.0000 - val_loss: 0.2925
# Epoch 951/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8559 - loss: 0.3981 - val_accuracy: 1.0000 - val_loss: 0.2931
# Epoch 952/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8518 - loss: 0.3721 - val_accuracy: 0.9444 - val_loss: 0.2962
# Epoch 953/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8827 - loss: 0.3644 - val_accuracy: 0.9444 - val_loss: 0.2953
# Epoch 954/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9029 - loss: 0.3439 - val_accuracy: 0.9444 - val_loss: 0.2906
# Epoch 955/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9137 - loss: 0.3661 - val_accuracy: 1.0000 - val_loss: 0.2835
# Epoch 956/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8786 - loss: 0.3613 - val_accuracy: 0.9444 - val_loss: 0.2808
# Epoch 957/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8708 - loss: 0.3618 - val_accuracy: 0.9444 - val_loss: 0.2861
# Epoch 958/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8678 - loss: 0.3793 - val_accuracy: 0.8889 - val_loss: 0.3020
# Epoch 959/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8760 - loss: 0.3763 - val_accuracy: 0.8889 - val_loss: 0.3194
# Epoch 960/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8730 - loss: 0.3630 - val_accuracy: 0.8889 - val_loss: 0.3384
# Epoch 961/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9014 - loss: 0.3395 - val_accuracy: 0.8333 - val_loss: 0.3532
# Epoch 962/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9309 - loss: 0.3450 - val_accuracy: 0.8333 - val_loss: 0.3614
# Epoch 963/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8611 - loss: 0.3698 - val_accuracy: 0.8333 - val_loss: 0.3496
# Epoch 964/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9081 - loss: 0.3265 - val_accuracy: 0.8889 - val_loss: 0.3296
# Epoch 965/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9189 - loss: 0.3714 - val_accuracy: 0.8889 - val_loss: 0.3183
# Epoch 966/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8827 - loss: 0.3882 - val_accuracy: 0.8889 - val_loss: 0.3126
# Epoch 967/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8812 - loss: 0.3754 - val_accuracy: 0.9444 - val_loss: 0.3005
# Epoch 968/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9044 - loss: 0.3390 - val_accuracy: 1.0000 - val_loss: 0.2870
# Epoch 969/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8533 - loss: 0.3721 - val_accuracy: 1.0000 - val_loss: 0.2704
# Epoch 970/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8906 - loss: 0.3589 - val_accuracy: 0.9444 - val_loss: 0.2608
# Epoch 971/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9179 - loss: 0.3200 - val_accuracy: 0.9444 - val_loss: 0.2585
# Epoch 972/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8932 - loss: 0.3510 - val_accuracy: 0.9444 - val_loss: 0.2570
# Epoch 973/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8962 - loss: 0.3539 - val_accuracy: 0.9444 - val_loss: 0.2579
# Epoch 974/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9018 - loss: 0.3692 - val_accuracy: 0.9444 - val_loss: 0.2612
# Epoch 975/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8786 - loss: 0.3694 - val_accuracy: 0.9444 - val_loss: 0.2656
# Epoch 976/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9432 - loss: 0.3238 - val_accuracy: 0.9444 - val_loss: 0.2740
# Epoch 977/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8801 - loss: 0.3783 - val_accuracy: 0.8889 - val_loss: 0.2816
# Epoch 978/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8611 - loss: 0.3779 - val_accuracy: 0.8889 - val_loss: 0.2859
# Epoch 979/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8854 - loss: 0.3646 - val_accuracy: 0.8889 - val_loss: 0.2824
# Epoch 980/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8962 - loss: 0.3302 - val_accuracy: 0.8889 - val_loss: 0.2761
# Epoch 981/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8962 - loss: 0.3625 - val_accuracy: 0.9444 - val_loss: 0.2716
# Epoch 982/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8574 - loss: 0.3476 - val_accuracy: 0.9444 - val_loss: 0.2694
# Epoch 983/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8906 - loss: 0.3380 - val_accuracy: 0.9444 - val_loss: 0.2693
# Epoch 984/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8745 - loss: 0.3503 - val_accuracy: 0.9444 - val_loss: 0.2760
# Epoch 985/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9070 - loss: 0.3186 - val_accuracy: 0.9444 - val_loss: 0.2834
# Epoch 986/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8719 - loss: 0.3526 - val_accuracy: 0.9444 - val_loss: 0.2863
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8745 - loss: 0.3514 - val_accuracy: 0.8889 - val_loss: 0.2900
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8869 - loss: 0.3393 - val_accuracy: 0.8889 - val_loss: 0.2935
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8827 - loss: 0.3455 - val_accuracy: 0.8889 - val_loss: 0.2945
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8565 - loss: 0.3648 - val_accuracy: 0.8889 - val_loss: 0.2904
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9179 - loss: 0.3403 - val_accuracy: 0.9444 - val_loss: 0.2845
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8745 - loss: 0.3653 - val_accuracy: 1.0000 - val_loss: 0.2818
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8910 - loss: 0.3263 - val_accuracy: 0.9444 - val_loss: 0.2819
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8383 - loss: 0.4148 - val_accuracy: 0.9444 - val_loss: 0.2803
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8843 - loss: 0.3887 - val_accuracy: 1.0000 - val_loss: 0.2745
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8988 - loss: 0.3183 - val_accuracy: 1.0000 - val_loss: 0.2692
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8678 - loss: 0.3757 - val_accuracy: 0.9444 - val_loss: 0.2661
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9122 - loss: 0.3447 - val_accuracy: 0.9444 - val_loss: 0.2648
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8910 - loss: 0.3476 - val_accuracy: 0.9444 - val_loss: 0.2683
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8771 - loss: 0.3463 - val_accuracy: 0.9444 - val_loss: 0.2708

# %%
# Evaluate the model

# Load the test data
X_eeg_test, y_test = load_eeg_epochs(EEG_TEST_SET, EEG_CHANNELS, EEG_SAMPLES_PER_EPOCH)
X_hr_test, y_hr_test = load_wearable_epochs(HR_TEST_SET, WEARABLE_SAMPLES_PER_EPOCH)
X_eda_test, y_eda_test = load_wearable_epochs(EDA_TEST_SET, WEARABLE_SAMPLES_PER_EPOCH)

# Assert that y_test, y_hr_test, and y_eda_test are the same
assert np.array_equal(y_test, y_hr_test), "y_test and y_hr_test do not match!"
assert np.array_equal(y_test, y_eda_test), "y_test and y_eda_test do not match!"

# Shuffle the data
X_eeg_test, X_hr_test, X_eda_test, y_test = shuffle(X_eeg_test, X_hr_test, X_eda_test, y_test, random_state=42)

# Align shapes
# X_hr_test shape: (n_test, 250, 1) → reshape to (n_test, 1, 250, 1)
X_hr_test = X_hr_test.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)
# X_eda_test shape: (n_test, 250, 1) → reshape to (n_test, 1, 250, 1)
X_eda_test = X_eda_test.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)

# Model evaluation
test_loss, test_accuracy = model.evaluate(
    {'eeg_input': X_eeg_test, 'hr_input': X_hr_test, 'eda_input': X_eda_test},
    y_test,
    batch_size=128,
    verbose=1
)
print(f"Test loss: {test_loss:.4f}, Test accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3333 - loss: 2.3257
# Test loss: 2.3257, Test accuracy: 0.3333

# %% [markdown]
# Step 5: Model conversion to TFLite

# %%
# -------------------- Conversion to TFLite --------------------
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # optional quantization
tflite_model = converter.convert()
with open(TFLITE_MODEL,'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\giova\AppData\Local\Temp\tmp2j3zio5f\assets
# INFO:tensorflow:Assets written to: C:\Users\giova\AppData\Local\Temp\tmp2j3zio5f\assets
# Saved artifact at 'C:\Users\giova\AppData\Local\Temp\tmp2j3zio5f'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 6, 1000, 1), dtype=tf.float32, name='eeg_input'), TensorSpec(shape=(None, 1, 250, 1), dtype=tf.float32, name='hr_input'), TensorSpec(shape=(None, 1, 250, 1), dtype=tf.float32, name='eda_input')]
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   1586326941264: TensorSpec(shape=(1, 8, 1, 1), dtype=tf.float32, name=None)
#   1585172267952: TensorSpec(shape=(1, 8, 1, 1), dtype=tf.float32, name=None)
#   1585172282208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172564624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172563744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172279216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172563392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172272704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172569200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172570960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172566736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172576944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172577824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172744320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172743616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172744496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172744672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172756464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585172753296: TensorSpec(shape=(), dtype=tf.resource, name=None)
