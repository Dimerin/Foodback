# %% [markdown]
# Parameters Definition

# %%
# ------------------ Folders ------------------

# Dataset
DATASET = "dataset/"

# Raw Data
RAW_DATASET = DATASET + "raw/"

# Upsampled Data (for HR and EDA)
UPSAMPLED_DATASET = DATASET + "upsampled/"

# Splitted Data
SPLITTED_DATASET = DATASET + "splitted/"
# Training and Test Sets
TRAINING_SET = SPLITTED_DATASET + "training_set/"
TEST_SET = SPLITTED_DATASET + "test_set/"

# ---------------------------------------------


# ------------------- Files -------------------

# Raw Data
RAW_EEG = RAW_DATASET + "eeg_data.csv"
RAW_HR = RAW_DATASET + "hr_data.csv"
RAW_EDA = RAW_DATASET + "eda_data.csv"

# Upsampled Data
UPSAMPLED_HR = UPSAMPLED_DATASET + "upsampled_hr_data.csv"
UPSAMPLED_EDA = UPSAMPLED_DATASET + "upsampled_eda_data.csv"


# Training and Test Sets
# EEG
EEG_TRAINING_SET = TRAINING_SET + "eeg_training_set.csv"
EEG_TEST_SET = TEST_SET + "eeg_test_set.csv"
# HR
HR_TRAINING_SET = TRAINING_SET + "hr_training_set.csv"
HR_TEST_SET = TEST_SET + "hr_test_set.csv"
# EDA
EDA_TRAINING_SET = TRAINING_SET + "eda_training_set.csv"
EDA_TEST_SET = TEST_SET + "eda_test_set.csv"

# TensorFlowLite Model
TFLITE_MODEL = "eegnet_preproc.tflite"

# ---------------------------------------------


# ----------------- Constants -----------------

# Epoch Duration in seconds
EPOCH_DURATION = 2

# EEG Channels
EEG_CHANNELS = ['ch1','ch2','ch3','ch4','ch5','ch6']
# EEG Sampling Frequency
EEG_SAMPLING_FREQUENCY = 500 # Hz
# Samples per epoch
EEG_SAMPLES_PER_EPOCH = EPOCH_DURATION * EEG_SAMPLING_FREQUENCY  # 2 seconds at 500 Hz

# Target Sampling Frequency
FS_TARGET  = 125 # Hz

# Wearable sampling frequency
WEARABLE_SAMPLES_PER_EPOCH = EPOCH_DURATION * FS_TARGET  # 2 seconds at 125 Hz

# ---------------------------------------------

# %%
# ------------------- Imports -------------------
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from scipy.signal import firwin
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Lambda, Conv2D, DepthwiseConv2D, SeparableConv2D,
    BatchNormalization, Activation, AveragePooling2D,
    Dropout, Flatten, Dense, Concatenate
)
from tensorflow.keras.constraints import max_norm
# --------------------------------------------------

# %% [markdown]
# Step 1: Upsample data coming from the smartwatch to bring it to 125Hz

# %%
# Utility function to upsample data
def upsample_data(group, target_freq=125, duration_s=10):
    # Calculate start and end timestamps per experiment
    start = group['timestamp'].min()
    end = start + duration_s * 1000
    # Generate target timestamps (125 samples/sec × duration)
    target_times = np.linspace(start, end, target_freq * duration_s)
    # Interpolate 'value' at these timestamps
    values = np.interp(target_times, group['timestamp'], group['value'])
    # Build upsampled DataFrame
    up_df = pd.DataFrame({
        'experiment': group['experiment'].iloc[0],
        'timestamp': target_times.astype(int),
        'value': values,
        'subject': group['subject'].iloc[0],
        'rating': group['rating'].iloc[0]
    })
    # Ensure exactly target_freq*duration_s rows
    return up_df.iloc[:target_freq * duration_s]

# %%
# Heart Rate

# 1. Read the raw CSV (all experiments)
raw_df = pd.read_csv(RAW_HR)

# 2. Upsample each experiment
upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# 3. Export to CSV
upsampled_df.to_csv(UPSAMPLED_HR, index=False)

print(f"Upsampling complete! Data saved to {UPSAMPLED_HR}.")
# Out:
# Upsampling complete! Data saved to dataset/upsampled/upsampled_hr_data.csv.
# C:\Users\giova\AppData\Local\Temp\ipykernel_19072\845244483.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# %%
# EDA

# 1. Read the raw CSV (all experiments)
raw_df = pd.read_csv(RAW_EDA)

# 2. Upsample each experiment
upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# 3. Export to CSV
upsampled_df.to_csv(UPSAMPLED_EDA, index=False)

print(f"Upsampling complete! Data saved to {UPSAMPLED_EDA}.")
# Out:
# C:\Users\giova\AppData\Local\Temp\ipykernel_19072\2098848758.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)
# Upsampling complete! Data saved to dataset/upsampled/upsampled_eda_data.csv.

# %% [markdown]
# Step 2: Split data into training and test sets using an hold-out strategy

# %%
# Load the EEG raw dataset
eeg_df = pd.read_csv(RAW_EEG)

# Load the upsampled heart-rate dataset
hr_df = pd.read_csv(UPSAMPLED_HR)

# Load the Upsampled eda dataset
eda_df = pd.read_csv(UPSAMPLED_EDA)

# Extract unique experiment IDs from the EEG data
experiments = eeg_df['experiment'].unique()

# Split experiments: 80% train, 20% test
train_exps, test_exps = train_test_split(
    experiments,
    test_size=0.2,
    random_state=42
)

# Partition the three datasets by the same experiment split
# EEG splits
eeg_train = eeg_df[eeg_df['experiment'].isin(train_exps)].reset_index(drop=True)
eeg_test  = eeg_df[eeg_df['experiment'].isin(test_exps)].reset_index(drop=True)

# Heart-rate splits
hr_train = hr_df[hr_df['experiment'].isin(train_exps)].reset_index(drop=True)
hr_test  = hr_df[hr_df['experiment'].isin(test_exps)].reset_index(drop=True)

# EDA splits
eda_train = eda_df[eda_df['experiment'].isin(train_exps)].reset_index(drop=True)
eda_test  = eda_df[eda_df['experiment'].isin(test_exps)].reset_index(drop=True)

# Creating the folders if they do not exist
# Create the training set folder
if not os.path.exists(TRAINING_SET):
    os.makedirs(TRAINING_SET)

# Create the test set folder
if not os.path.exists(TEST_SET):
    os.makedirs(TEST_SET)

# Save the splitted files
# EEG
eeg_train.to_csv(EEG_TRAINING_SET, index=False)
eeg_test.to_csv(EEG_TEST_SET, index=False)

# Heart-rate
hr_train.to_csv(HR_TRAINING_SET, index=False)
hr_test.to_csv(HR_TEST_SET, index=False)

# EDA
eda_train.to_csv(EDA_TRAINING_SET, index=False)
eda_test.to_csv(EDA_TEST_SET, index=False)

# Sanity checks
print("Train experiments:", train_exps)
print("Test experiments :", test_exps)
print(f"EEG train rows: {len(eeg_train)}, test rows: {len(eeg_test)}")
print(f"HR train rows: {len(hr_train)}, test rows: {len(hr_test)}")
print(f"EDA train rows: {len(eda_train)}, test rows: {len(eda_test)}")
# Out:
# Train experiments: [ 4  7 25 33 20 18 14 43 16 10 17 38 32 28  1 31 30  6 12 34  2 41 22  3
#  35 24 37 11 23 19 45 21  8 15 29 39]
# Test experiments : [40 26 27 44 36 42  5 13  9]
# EEG train rows: 180000, test rows: 45000
# HR train rows: 45000, test rows: 11250
# EDA train rows: 45000, test rows: 11250

# %% [markdown]
# Step 3: Model definition

# %%
# -------------------- Design FIR filters --------------------
fs_in       = 500                   # incoming sample rate
fs_target   = 125                   # desired rate after decimation
dec_factor  = fs_in // fs_target    # must be 4
numtaps     = 101                   # filter length 

# 1) High-pass (0.5 Hz) for detrend
hp_coeffs   = firwin(numtaps, cutoff=0.5, fs=fs_in, pass_zero=False)
# 2) Band-pass (0.5–50 Hz)
bp_coeffs   = firwin(numtaps, cutoff=[0.5, 50.], fs=fs_in, pass_zero=False)
# 3) Notch (49–51 Hz)
bs_coeffs   = firwin(numtaps, cutoff=[49., 51.], fs=fs_in, pass_zero=True)
# 4) Anti-alias low-pass (≤62.5 Hz)
aa_coeffs   = firwin(numtaps, cutoff=fs_target/2, fs=fs_in)

# -------------------- Helper to apply 1D FIR --------------------
def apply_fir(x, coeffs):
    """ x: (B, Ch, T, 1) → applies 1-D FIR along time via depthwise conv """
    # 1) remove trailing singleton and transpose to NHWC with time in W, channels in C:
    #    (B, Ch, T, 1) → (B, T, Ch)
    x2 = tf.squeeze(x, -1)
    #    (B, T, Ch) → (B, 1, T, Ch)
    x2 = tf.expand_dims(x2, 1)

    # 2) build depthwise kernel of shape (1, filter_len, in_channels=Ch, channel_multiplier=1)
    #    coeffs is (filter_len,), so first reshape to (1, filter_len, 1, 1)
    k = tf.constant(coeffs.reshape(1, -1, 1, 1), tf.float32)
    #    then tile the "in_channels" dimension to match your EEG channels
    n_ch = x2.shape[-1]
    k = tf.tile(k, [1, 1, n_ch, 1])  # now (1, filter_len, Ch, 1)

    # 3) depthwise conv2d → same padding
    y = tf.nn.depthwise_conv2d(
        x2,
        k,
        strides=[1, 1, 1, 1],
        padding='SAME',
        data_format='NHWC'
    )
    # y has shape (B, 1, T, Ch); we want back (B, Ch, T, 1)

    y = tf.squeeze(y, 1)            # → (B, T, Ch)
    y = tf.transpose(y, [0, 2, 1])  # → (B, Ch, T)
    return y[..., tf.newaxis]       # → (B, Ch, T, 1)


# -------------------- Combined model --------------------
def PreprocAndEEGNet(nb_classes,
                     channel_means, channel_stds,  # arrays of shape (8,)
                     eeg_chans=6,
                     fs_in=500,                    # original raw rate for EEG
                     fs_target=125,                # rate after decimation
                     duration_s=2.0,               # length of each input epoch in seconds
                     dropoutRate=0.5,
                     F1=8, D=2, F2=16,
                     norm_rate=0.25):
    # Calculate dynamic shapes
    Samples_in = int(fs_in * duration_s)       # e.g. 1000 samples @ 500 Hz
    Samples    = int(fs_target * duration_s)   # e.g. 250 samples @ 125 Hz
    dec_factor = fs_in // fs_target            # 4
    kernLength = int(0.5 * fs_target)          # half the target rate: 62
    
    # EEG input path
    eeg_in = Input(shape=(eeg_chans, Samples_in, 1), name='eeg_input')

    # 1) High-pass
    x = Lambda(lambda z: apply_fir(z, hp_coeffs), output_shape=lambda input_shape: input_shape, name='hp')(eeg_in)
    # 2) Band-pass
    x = Lambda(lambda z: apply_fir(z, bp_coeffs), output_shape=lambda input_shape: input_shape, name='bp')(x)
    # 3) Notch
    x = Lambda(lambda z: apply_fir(z, bs_coeffs), output_shape=lambda input_shape: input_shape, name='notch')(x)
    # 4) Anti-alias low-pass
    x = Lambda(lambda z: apply_fir(z, aa_coeffs), output_shape=lambda input_shape: input_shape, name='aa')(x)
    # 5) Decimate by slicing every dec_factor-th sample
    x = Lambda(lambda z: z[:, :, ::dec_factor, :], name='decimate')(x)

    # now x has shape (batch, Chans, Samples_in/4, 1) → (batch,6,250,1)

    # HR input path (no filtering, already 125 Hz)
    hr_in = Input(shape=(1, Samples, 1), name='hr_input')

    # EDA input path (no filtering, already 125 Hz)
    eda_in = Input(shape=(1, Samples, 1), name='eda_input')
    
    # 3) Concatenate along channel axis → (B, 8, 250, 1)
    merged = Concatenate(axis=1)([x, hr_in, eda_in])
    Chans = eeg_chans + 2  # now 8
    
    # --- EEGNet layers expects Samples=250 ---
    # Keras Implementation of EEGNet
    # http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    # Normalization
    # we broadcast: (1,8,1,1) → will divide/subtract per-channel
    means = tf.constant(channel_means.reshape(1, -1, 1, 1), dtype=tf.float32)
    stds  = tf.constant(channel_stds .reshape(1, -1, 1, 1), dtype=tf.float32)
    norm  = Lambda(lambda z: (z - means) / stds, name="normalize")(merged)

    # Block 1
    b1 = Conv2D(F1, (1, kernLength), padding='same', use_bias=False)(norm)
    b1 = BatchNormalization()(b1)
    b1 = DepthwiseConv2D((Chans, 1), use_bias=False,
                        depth_multiplier=D,
                        depthwise_constraint=max_norm(1.))(b1)
    b1 = BatchNormalization()(b1)
    b1 = Activation('elu')(b1)
    b1 = AveragePooling2D((1, 4))(b1)
    b1 = Dropout(dropoutRate)(b1)

    # Block 2
    b2 = SeparableConv2D(F2, (1, 16), padding='same', use_bias=False)(b1)
    b2 = BatchNormalization()(b2)
    b2 = Activation('elu')(b2)
    b2 = AveragePooling2D((1, 8))(b2)
    b2 = Dropout(dropoutRate)(b2)
    
    # Classification head
    flat = Flatten(name='flatten')(b2)
    dense= Dense(nb_classes, kernel_constraint=max_norm(norm_rate), name='dense')(flat)
    out  = Activation('softmax', name='softmax')(dense)
        
    return Model(inputs=[eeg_in, hr_in, eda_in], outputs=out, name='EEGNet_with_Preproc')
    

# Example instantiation
model = PreprocAndEEGNet(nb_classes=5, channel_means=np.zeros(8), channel_stds=np.ones(8))

# Compile / train
model.compile('adam', 'sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\giova\miniconda3\envs\MSSS\lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "EEGNet_with_Preproc"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ eeg_input           │ (None, 6, 1000,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hp (Lambda)         │ (None, 6, 1000,   │          0 │ eeg_input[0][0]   │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bp (Lambda)         │ (None, 6, 1000,   │          0 │ hp[0][0]          │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ notch (Lambda)      │ (None, 6, 1000,   │          0 │ bp[0][0]          │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aa (Lambda)         │ (None, 6, 1000,   │          0 │ notch[0][0]       │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decimate (Lambda)   │ (None, 6, 250, 1) │          0 │ aa[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hr_input            │ (None, 1, 250, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eda_input           │ (None, 1, 250, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 250, 1) │          0 │ decimate[0][0],   │
# │ (Concatenate)       │                   │            │ hr_input[0][0],   │
# │                     │                   │            │ eda_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalize (Lambda)  │ (None, 8, 250, 1) │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 250, 8) │        496 │ normalize[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 8, 250, 8) │         32 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 1, 250,    │        128 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 250,    │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1, 250,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 1, 62, 16) │          0 │ activation[0][0]  │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1, 62, 16) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 1, 62, 16) │        512 │ dropout[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 62, 16) │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1, 62, 16) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 1, 7, 16)  │          0 │ activation_1[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1, 7, 16)  │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 112)       │          0 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5)         │        565 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax             │ (None, 5)         │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,861 (7.27 KB)
#  Trainable params: 1,781 (6.96 KB)
#  Non-trainable params: 80 (320.00 B)

# %% [markdown]
# Step 4: Model training and evaluation

# %%
# Utility functions for loading epochs

def load_eeg_epochs(csv_file, channels, packets_per_epoch):
    df = pd.read_csv(csv_file)
    df['epoch_idx'] = (df['sample'] // packets_per_epoch).astype(int)
    X_list, y_list = [], []
    for (_, _, epoch_idx), grp in df.groupby(['experiment','subject','epoch_idx']):
        grp = grp.sort_values('sample')
        data = grp[channels].values.T  # (6, packets_per_epoch)
        X_list.append(data[..., np.newaxis])
        y_list.append(grp['rating'].iloc[0])
    return np.stack(X_list), np.array(y_list)

def load_wearable_epochs(csv_file, samples_per_epoch):
    """
    Load and segment HR or EDA data into non-overlapping epochs based on row index.
    
    Parameters:
    - csv_file: path to CSV with columns ['experiment','timestamp','value','subject','rating']
    - samples_per_epoch: number of consecutive samples per epoch (e.g. 2 s * 125 Hz = 250)
    
    Returns:
    - X_eda: np.ndarray of shape (n_epochs, 1, samples_per_epoch, 1)
    - y_eda: np.ndarray of labels (n_epochs,)
    """
    df = pd.read_csv(csv_file)
    # Ensure consistent ordering
    df = df.reset_index(drop=True)
    # Epoch index based on row index
    df['epoch_idx'] = df.index // samples_per_epoch

    X_list = []
    y_list = []

    # Group by experiment, subject, and computed epoch index
    for (exp, subj, ep), grp in df.groupby(['experiment', 'subject', 'epoch_idx']):
        grp = grp.sort_index()
        values = grp['value'].values
        if len(values) == samples_per_epoch:
            # shape for each epoch: (1 channel, samples, 1)
            X_list.append(values[np.newaxis, :, np.newaxis])
            y_list.append(grp['rating'].iloc[0])

    X_eda = np.concatenate(X_list, axis=0)
    y_eda = np.array(y_list)
    return X_eda, y_eda

# %%
# Load the training data
X_eeg_train, y_train = load_eeg_epochs(EEG_TRAINING_SET, EEG_CHANNELS, EEG_SAMPLES_PER_EPOCH)
X_hr_train, y_hr_train = load_wearable_epochs(HR_TRAINING_SET, WEARABLE_SAMPLES_PER_EPOCH)
X_eda_train, y_eda_train = load_wearable_epochs(EDA_TRAINING_SET, WEARABLE_SAMPLES_PER_EPOCH)

# Assert that y_train, y_hr_train, and y_eda_train are the same
assert np.array_equal(y_train, y_hr_train), "y_train and y_hr_train do not match!"
assert np.array_equal(y_train, y_eda_train), "y_train and y_eda_train do not match!"

# Shuffle the data
X_eeg_train, X_hr_train, X_eda_train, y_train = shuffle(X_eeg_train, X_hr_train, X_eda_train, y_train, random_state=42)

# %%
# Precompute preprocessed EEG (to get means/stds)
# Build a small model that inputs raw EEG and outputs the decimated, filtered EEG:
eeg_in = tf.keras.Input(shape=(6, EEG_SAMPLES_PER_EPOCH, 1))
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, hp_coeffs))(eeg_in)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, bp_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, bs_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, aa_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: z[:, :, ::4, :])(x)
preproc_model = tf.keras.Model(inputs=eeg_in, outputs=x, name='eeg_preproc')

# Run preprocessing on the entire training set
X_eeg_pre = preproc_model.predict(X_eeg_train, batch_size=16)  # shape (n_train,6,250,1)

# Align shapes and concatenate EEG+HR+EDA
# X_hr_train shape: (n_train, 250, 1) → reshape to (n_train, 1, 250, 1)
X_hr_train = X_hr_train.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)
# X_eda_train shape: (n_train, 250, 1) → reshape to (n_train, 1, 250, 1)
X_eda_train = X_eda_train.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)

X_merged = np.concatenate([X_eeg_pre, X_hr_train, X_eda_train], axis=1)  # shape (n_train,8,250,1)

# Compute channel-wise mean/std
channel_means = X_merged.mean(axis=(0,2,3))  # shape (8,)
channel_stds  = X_merged.std (axis=(0,2,3))  # shape (8,)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# Build and compile the model
model = PreprocAndEEGNet(
    nb_classes=5,
    channel_means=channel_means,
    channel_stds=channel_stds
)
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    {'eeg_input': X_eeg_train, 'hr_input': X_hr_train, 'eda_input': X_eda_train},
    y_train,
    batch_size=128,
    epochs=1000,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.2625 - loss: 1.7419 - val_accuracy: 0.2222 - val_loss: 1.6087
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2397 - loss: 1.5946 - val_accuracy: 0.2222 - val_loss: 1.6082
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2588 - loss: 1.5949 - val_accuracy: 0.2778 - val_loss: 1.6077
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2965 - loss: 1.5687 - val_accuracy: 0.2778 - val_loss: 1.6070
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3502 - loss: 1.5605 - val_accuracy: 0.3333 - val_loss: 1.6061
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3047 - loss: 1.5559 - val_accuracy: 0.3333 - val_loss: 1.6051
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3951 - loss: 1.5340 - val_accuracy: 0.3333 - val_loss: 1.6039
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4163 - loss: 1.5331 - val_accuracy: 0.3333 - val_loss: 1.6026
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4107 - loss: 1.4943 - val_accuracy: 0.3333 - val_loss: 1.6011
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4235 - loss: 1.4753 - val_accuracy: 0.3333 - val_loss: 1.5996
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4350 - loss: 1.4609 - val_accuracy: 0.3333 - val_loss: 1.5979
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4328 - loss: 1.4732 - val_accuracy: 0.3333 - val_loss: 1.5963
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4380 - loss: 1.4617 - val_accuracy: 0.3333 - val_loss: 1.5945
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4365 - loss: 1.4293 - val_accuracy: 0.3333 - val_loss: 1.5927
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4742 - loss: 1.4227 - val_accuracy: 0.3333 - val_loss: 1.5908
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4567 - loss: 1.4164 - val_accuracy: 0.2778 - val_loss: 1.5886
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4567 - loss: 1.3982 - val_accuracy: 0.2778 - val_loss: 1.5864
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4556 - loss: 1.3973 - val_accuracy: 0.2778 - val_loss: 1.5843
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4634 - loss: 1.3852 - val_accuracy: 0.2778 - val_loss: 1.5822
# Epoch 20/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4675 - loss: 1.3724 - val_accuracy: 0.2778 - val_loss: 1.5797
# Epoch 21/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4634 - loss: 1.3677 - val_accuracy: 0.2778 - val_loss: 1.5771
# Epoch 22/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4593 - loss: 1.3572 - val_accuracy: 0.2778 - val_loss: 1.5744
# Epoch 23/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4545 - loss: 1.3632 - val_accuracy: 0.2778 - val_loss: 1.5715
# Epoch 24/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4504 - loss: 1.3468 - val_accuracy: 0.2778 - val_loss: 1.5684
# Epoch 25/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4380 - loss: 1.3541 - val_accuracy: 0.2778 - val_loss: 1.5648
# Epoch 26/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4421 - loss: 1.3224 - val_accuracy: 0.2778 - val_loss: 1.5610
# Epoch 27/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4690 - loss: 1.3121 - val_accuracy: 0.2778 - val_loss: 1.5572
# Epoch 28/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4586 - loss: 1.3057 - val_accuracy: 0.3333 - val_loss: 1.5538
# Epoch 29/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4716 - loss: 1.3097 - val_accuracy: 0.3333 - val_loss: 1.5513
# Epoch 30/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4649 - loss: 1.2824 - val_accuracy: 0.3333 - val_loss: 1.5497
# Epoch 31/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4768 - loss: 1.2813 - val_accuracy: 0.3333 - val_loss: 1.5480
# Epoch 32/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4835 - loss: 1.2879 - val_accuracy: 0.3333 - val_loss: 1.5458
# Epoch 33/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5119 - loss: 1.2606 - val_accuracy: 0.3333 - val_loss: 1.5431
# Epoch 34/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4761 - loss: 1.2770 - val_accuracy: 0.3889 - val_loss: 1.5405
# Epoch 35/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4746 - loss: 1.2649 - val_accuracy: 0.3889 - val_loss: 1.5367
# Epoch 36/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5056 - loss: 1.2661 - val_accuracy: 0.3889 - val_loss: 1.5329
# Epoch 37/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5052 - loss: 1.2396 - val_accuracy: 0.3889 - val_loss: 1.5292
# Epoch 38/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5202 - loss: 1.2499 - val_accuracy: 0.3889 - val_loss: 1.5263
# Epoch 39/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4653 - loss: 1.2585 - val_accuracy: 0.3889 - val_loss: 1.5225
# Epoch 40/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5512 - loss: 1.2240 - val_accuracy: 0.3889 - val_loss: 1.5181
# Epoch 41/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5015 - loss: 1.2421 - val_accuracy: 0.3333 - val_loss: 1.5132
# Epoch 42/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5392 - loss: 1.2225 - val_accuracy: 0.3333 - val_loss: 1.5078
# Epoch 43/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5388 - loss: 1.2070 - val_accuracy: 0.3889 - val_loss: 1.5023
# Epoch 44/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5728 - loss: 1.2225 - val_accuracy: 0.3889 - val_loss: 1.4971
# Epoch 45/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5620 - loss: 1.2145 - val_accuracy: 0.3889 - val_loss: 1.4918
# Epoch 46/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6001 - loss: 1.1752 - val_accuracy: 0.3889 - val_loss: 1.4872
# Epoch 47/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4903 - loss: 1.2245 - val_accuracy: 0.3889 - val_loss: 1.4842
# Epoch 48/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5444 - loss: 1.1838 - val_accuracy: 0.4444 - val_loss: 1.4817
# Epoch 49/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5269 - loss: 1.1937 - val_accuracy: 0.4444 - val_loss: 1.4793
# Epoch 50/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5982 - loss: 1.1507 - val_accuracy: 0.4444 - val_loss: 1.4757
# Epoch 51/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5605 - loss: 1.1883 - val_accuracy: 0.4444 - val_loss: 1.4691
# Epoch 52/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5971 - loss: 1.1720 - val_accuracy: 0.5000 - val_loss: 1.4593
# Epoch 53/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5579 - loss: 1.1887 - val_accuracy: 0.4444 - val_loss: 1.4485
# Epoch 54/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5475 - loss: 1.1837 - val_accuracy: 0.4444 - val_loss: 1.4394
# Epoch 55/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5496 - loss: 1.1701 - val_accuracy: 0.4444 - val_loss: 1.4320
# Epoch 56/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5557 - loss: 1.1778 - val_accuracy: 0.4444 - val_loss: 1.4262
# Epoch 57/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5806 - loss: 1.1639 - val_accuracy: 0.5000 - val_loss: 1.4212
# Epoch 58/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5620 - loss: 1.1481 - val_accuracy: 0.5000 - val_loss: 1.4159
# Epoch 59/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5791 - loss: 1.1322 - val_accuracy: 0.5000 - val_loss: 1.4106
# Epoch 60/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5863 - loss: 1.1346 - val_accuracy: 0.5000 - val_loss: 1.4057
# Epoch 61/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6049 - loss: 1.1517 - val_accuracy: 0.5000 - val_loss: 1.3981
# Epoch 62/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5635 - loss: 1.1232 - val_accuracy: 0.5000 - val_loss: 1.3895
# Epoch 63/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5713 - loss: 1.1566 - val_accuracy: 0.5000 - val_loss: 1.3789
# Epoch 64/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5997 - loss: 1.1398 - val_accuracy: 0.4444 - val_loss: 1.3691
# Epoch 65/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5542 - loss: 1.1438 - val_accuracy: 0.4444 - val_loss: 1.3627
# Epoch 66/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6023 - loss: 1.1027 - val_accuracy: 0.4444 - val_loss: 1.3558
# Epoch 67/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6027 - loss: 1.1380 - val_accuracy: 0.4444 - val_loss: 1.3498
# Epoch 68/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6545 - loss: 1.1140 - val_accuracy: 0.4444 - val_loss: 1.3442
# Epoch 69/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6277 - loss: 1.1141 - val_accuracy: 0.4444 - val_loss: 1.3374
# Epoch 70/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6177 - loss: 1.1013 - val_accuracy: 0.4444 - val_loss: 1.3309
# Epoch 71/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6162 - loss: 1.0938 - val_accuracy: 0.3889 - val_loss: 1.3269
# Epoch 72/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6348 - loss: 1.0886 - val_accuracy: 0.3889 - val_loss: 1.3248
# Epoch 73/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5691 - loss: 1.1135 - val_accuracy: 0.3889 - val_loss: 1.3249
# Epoch 74/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6385 - loss: 1.0672 - val_accuracy: 0.4444 - val_loss: 1.3252
# Epoch 75/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6359 - loss: 1.1063 - val_accuracy: 0.5000 - val_loss: 1.3222
# Epoch 76/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6090 - loss: 1.0791 - val_accuracy: 0.5000 - val_loss: 1.3171
# Epoch 77/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5915 - loss: 1.0845 - val_accuracy: 0.5000 - val_loss: 1.3106
# Epoch 78/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6441 - loss: 1.0569 - val_accuracy: 0.5000 - val_loss: 1.3030
# Epoch 79/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6090 - loss: 1.0963 - val_accuracy: 0.5000 - val_loss: 1.2932
# Epoch 80/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5956 - loss: 1.0531 - val_accuracy: 0.5000 - val_loss: 1.2863
# Epoch 81/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5847 - loss: 1.0912 - val_accuracy: 0.5000 - val_loss: 1.2784
# Epoch 82/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5904 - loss: 1.0715 - val_accuracy: 0.5000 - val_loss: 1.2722
# Epoch 83/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6400 - loss: 1.0562 - val_accuracy: 0.5556 - val_loss: 1.2686
# Epoch 84/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6296 - loss: 1.0517 - val_accuracy: 0.5556 - val_loss: 1.2656
# Epoch 85/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6333 - loss: 1.0634 - val_accuracy: 0.5556 - val_loss: 1.2598
# Epoch 86/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6199 - loss: 1.0563 - val_accuracy: 0.5000 - val_loss: 1.2509
# Epoch 87/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6240 - loss: 1.0592 - val_accuracy: 0.5000 - val_loss: 1.2421
# Epoch 88/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6400 - loss: 1.0517 - val_accuracy: 0.5000 - val_loss: 1.2320
# Epoch 89/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6183 - loss: 1.0623 - val_accuracy: 0.5556 - val_loss: 1.2228
# Epoch 90/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6162 - loss: 1.0802 - val_accuracy: 0.5556 - val_loss: 1.2158
# Epoch 91/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6064 - loss: 1.0440 - val_accuracy: 0.6111 - val_loss: 1.2086
# Epoch 92/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6404 - loss: 1.0405 - val_accuracy: 0.6111 - val_loss: 1.2021
# Epoch 93/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6251 - loss: 1.0274 - val_accuracy: 0.6111 - val_loss: 1.1983
# Epoch 94/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6151 - loss: 1.0386 - val_accuracy: 0.5556 - val_loss: 1.1951
# Epoch 95/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6214 - loss: 1.0519 - val_accuracy: 0.5556 - val_loss: 1.1904
# Epoch 96/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6281 - loss: 1.0338 - val_accuracy: 0.5556 - val_loss: 1.1871
# Epoch 97/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6378 - loss: 1.0291 - val_accuracy: 0.5556 - val_loss: 1.1829
# Epoch 98/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6173 - loss: 1.0289 - val_accuracy: 0.5556 - val_loss: 1.1789
# Epoch 99/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5945 - loss: 1.0410 - val_accuracy: 0.5000 - val_loss: 1.1783
# Epoch 100/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6576 - loss: 1.0338 - val_accuracy: 0.5000 - val_loss: 1.1781
# Epoch 101/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5997 - loss: 1.0387 - val_accuracy: 0.5556 - val_loss: 1.1727
# Epoch 102/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6781 - loss: 0.9924 - val_accuracy: 0.5556 - val_loss: 1.1674
# Epoch 103/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5986 - loss: 1.0463 - val_accuracy: 0.5556 - val_loss: 1.1629
# Epoch 104/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6322 - loss: 1.0026 - val_accuracy: 0.5556 - val_loss: 1.1576
# Epoch 105/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6188 - loss: 1.0034 - val_accuracy: 0.5556 - val_loss: 1.1503
# Epoch 106/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5826 - loss: 1.0050 - val_accuracy: 0.5556 - val_loss: 1.1390
# Epoch 107/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6385 - loss: 1.0243 - val_accuracy: 0.5556 - val_loss: 1.1299
# Epoch 108/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6255 - loss: 0.9784 - val_accuracy: 0.6111 - val_loss: 1.1246
# Epoch 109/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6296 - loss: 0.9975 - val_accuracy: 0.6111 - val_loss: 1.1210
# Epoch 110/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5975 - loss: 1.0084 - val_accuracy: 0.6111 - val_loss: 1.1181
# Epoch 111/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6131 - loss: 0.9874 - val_accuracy: 0.6111 - val_loss: 1.1185
# Epoch 112/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6199 - loss: 0.9860 - val_accuracy: 0.6111 - val_loss: 1.1212
# Epoch 113/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6766 - loss: 0.9953 - val_accuracy: 0.6111 - val_loss: 1.1231
# Epoch 114/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7124 - loss: 0.9730 - val_accuracy: 0.6111 - val_loss: 1.1232
# Epoch 115/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6430 - loss: 1.0147 - val_accuracy: 0.5556 - val_loss: 1.1253
# Epoch 116/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6493 - loss: 0.9820 - val_accuracy: 0.6111 - val_loss: 1.1235
# Epoch 117/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6580 - loss: 0.9910 - val_accuracy: 0.6111 - val_loss: 1.1133
# Epoch 118/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6508 - loss: 0.9736 - val_accuracy: 0.6111 - val_loss: 1.0998
# Epoch 119/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6344 - loss: 0.9548 - val_accuracy: 0.6111 - val_loss: 1.0828
# Epoch 120/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6736 - loss: 0.9991 - val_accuracy: 0.6111 - val_loss: 1.0692
# Epoch 121/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6916 - loss: 0.9503 - val_accuracy: 0.6667 - val_loss: 1.0604
# Epoch 122/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6554 - loss: 0.9968 - val_accuracy: 0.6667 - val_loss: 1.0538
# Epoch 123/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6482 - loss: 0.9808 - val_accuracy: 0.7222 - val_loss: 1.0478
# Epoch 124/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7191 - loss: 0.9521 - val_accuracy: 0.7222 - val_loss: 1.0407
# Epoch 125/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6587 - loss: 1.0091 - val_accuracy: 0.7222 - val_loss: 1.0312
# Epoch 126/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6669 - loss: 0.9460 - val_accuracy: 0.6667 - val_loss: 1.0245
# Epoch 127/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6255 - loss: 0.9613 - val_accuracy: 0.7222 - val_loss: 1.0221
# Epoch 128/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7113 - loss: 0.9523 - val_accuracy: 0.7222 - val_loss: 1.0168
# Epoch 129/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6901 - loss: 0.9299 - val_accuracy: 0.7222 - val_loss: 1.0147
# Epoch 130/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6818 - loss: 0.9553 - val_accuracy: 0.7222 - val_loss: 1.0136
# Epoch 131/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7050 - loss: 0.9610 - val_accuracy: 0.7222 - val_loss: 1.0101
# Epoch 132/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7196 - loss: 0.9086 - val_accuracy: 0.7222 - val_loss: 1.0030
# Epoch 133/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6890 - loss: 0.9577 - val_accuracy: 0.7222 - val_loss: 0.9967
# Epoch 134/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6792 - loss: 0.9750 - val_accuracy: 0.7222 - val_loss: 0.9903
# Epoch 135/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6994 - loss: 0.9191 - val_accuracy: 0.7222 - val_loss: 0.9872
# Epoch 136/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6860 - loss: 0.9766 - val_accuracy: 0.7222 - val_loss: 0.9890
# Epoch 137/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7061 - loss: 0.9329 - val_accuracy: 0.7222 - val_loss: 0.9953
# Epoch 138/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7139 - loss: 0.9225 - val_accuracy: 0.6667 - val_loss: 1.0011
# Epoch 139/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6348 - loss: 0.9718 - val_accuracy: 0.6667 - val_loss: 0.9986
# Epoch 140/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6688 - loss: 0.9597 - val_accuracy: 0.6667 - val_loss: 0.9925
# Epoch 141/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6673 - loss: 0.9396 - val_accuracy: 0.6667 - val_loss: 0.9878
# Epoch 142/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6647 - loss: 0.9471 - val_accuracy: 0.7222 - val_loss: 0.9814
# Epoch 143/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6807 - loss: 0.9247 - val_accuracy: 0.7222 - val_loss: 0.9748
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6818 - loss: 0.9453 - val_accuracy: 0.7222 - val_loss: 0.9627
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6441 - loss: 0.9509 - val_accuracy: 0.6667 - val_loss: 0.9494
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6430 - loss: 0.9517 - val_accuracy: 0.6667 - val_loss: 0.9451
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6968 - loss: 0.9324 - val_accuracy: 0.6667 - val_loss: 0.9480
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6829 - loss: 0.9206 - val_accuracy: 0.6667 - val_loss: 0.9594
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6979 - loss: 0.9292 - val_accuracy: 0.6111 - val_loss: 0.9703
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7252 - loss: 0.8837 - val_accuracy: 0.6111 - val_loss: 0.9807
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6766 - loss: 0.9310 - val_accuracy: 0.6111 - val_loss: 0.9833
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6647 - loss: 0.9165 - val_accuracy: 0.6111 - val_loss: 0.9751
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6565 - loss: 0.9346 - val_accuracy: 0.6111 - val_loss: 0.9624
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6864 - loss: 0.9394 - val_accuracy: 0.6667 - val_loss: 0.9550
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7222 - loss: 0.9069 - val_accuracy: 0.6667 - val_loss: 0.9497
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6860 - loss: 0.9027 - val_accuracy: 0.6667 - val_loss: 0.9461
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7020 - loss: 0.8778 - val_accuracy: 0.6667 - val_loss: 0.9434
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6901 - loss: 0.8985 - val_accuracy: 0.7222 - val_loss: 0.9368
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7196 - loss: 0.8805 - val_accuracy: 0.6667 - val_loss: 0.9262
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6673 - loss: 0.9279 - val_accuracy: 0.7222 - val_loss: 0.9193
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6897 - loss: 0.9130 - val_accuracy: 0.6667 - val_loss: 0.9140
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7412 - loss: 0.9126 - val_accuracy: 0.6667 - val_loss: 0.9101
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6860 - loss: 0.9044 - val_accuracy: 0.6667 - val_loss: 0.9055
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6591 - loss: 0.9210 - val_accuracy: 0.7222 - val_loss: 0.9070
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6550 - loss: 0.9190 - val_accuracy: 0.6111 - val_loss: 0.9108
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6710 - loss: 0.8654 - val_accuracy: 0.6667 - val_loss: 0.9080
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6441 - loss: 0.9147 - val_accuracy: 0.7222 - val_loss: 0.9062
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6953 - loss: 0.8839 - val_accuracy: 0.6111 - val_loss: 0.9108
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6591 - loss: 0.8910 - val_accuracy: 0.6111 - val_loss: 0.9189
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6983 - loss: 0.8968 - val_accuracy: 0.6111 - val_loss: 0.9272
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7196 - loss: 0.8943 - val_accuracy: 0.5556 - val_loss: 0.9373
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7102 - loss: 0.8827 - val_accuracy: 0.5556 - val_loss: 0.9467
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6807 - loss: 0.8731 - val_accuracy: 0.6111 - val_loss: 0.9497
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7020 - loss: 0.8687 - val_accuracy: 0.6111 - val_loss: 0.9494
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6565 - loss: 0.9009 - val_accuracy: 0.6111 - val_loss: 0.9429
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6632 - loss: 0.8639 - val_accuracy: 0.6111 - val_loss: 0.9270
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6710 - loss: 0.9079 - val_accuracy: 0.6111 - val_loss: 0.9099
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6632 - loss: 0.8807 - val_accuracy: 0.6111 - val_loss: 0.8902
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6535 - loss: 0.8743 - val_accuracy: 0.6667 - val_loss: 0.8707
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6415 - loss: 0.9067 - val_accuracy: 0.6667 - val_loss: 0.8525
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6927 - loss: 0.8706 - val_accuracy: 0.6111 - val_loss: 0.8407
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6829 - loss: 0.8677 - val_accuracy: 0.6667 - val_loss: 0.8317
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7237 - loss: 0.8429 - val_accuracy: 0.6667 - val_loss: 0.8241
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7050 - loss: 0.8710 - val_accuracy: 0.6667 - val_loss: 0.8202
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6916 - loss: 0.8952 - val_accuracy: 0.6667 - val_loss: 0.8231
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6916 - loss: 0.8622 - val_accuracy: 0.6667 - val_loss: 0.8286
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7020 - loss: 0.8485 - val_accuracy: 0.6111 - val_loss: 0.8367
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6632 - loss: 0.8696 - val_accuracy: 0.6111 - val_loss: 0.8492
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6344 - loss: 0.8587 - val_accuracy: 0.6111 - val_loss: 0.8624
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6781 - loss: 0.8628 - val_accuracy: 0.6111 - val_loss: 0.8698
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6860 - loss: 0.8739 - val_accuracy: 0.6111 - val_loss: 0.8695
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6378 - loss: 0.9031 - val_accuracy: 0.6111 - val_loss: 0.8625
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6714 - loss: 0.8407 - val_accuracy: 0.6667 - val_loss: 0.8535
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6994 - loss: 0.8418 - val_accuracy: 0.7222 - val_loss: 0.8480
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6916 - loss: 0.8435 - val_accuracy: 0.6667 - val_loss: 0.8444
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7065 - loss: 0.8599 - val_accuracy: 0.6111 - val_loss: 0.8401
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7169 - loss: 0.8158 - val_accuracy: 0.6111 - val_loss: 0.8398
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7020 - loss: 0.8545 - val_accuracy: 0.6111 - val_loss: 0.8461
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7252 - loss: 0.8420 - val_accuracy: 0.5556 - val_loss: 0.8545
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6591 - loss: 0.8695 - val_accuracy: 0.5556 - val_loss: 0.8577
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7091 - loss: 0.8440 - val_accuracy: 0.6111 - val_loss: 0.8563
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7427 - loss: 0.8515 - val_accuracy: 0.6111 - val_loss: 0.8508
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7267 - loss: 0.8312 - val_accuracy: 0.5556 - val_loss: 0.8486
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6953 - loss: 0.8278 - val_accuracy: 0.6111 - val_loss: 0.8537
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7046 - loss: 0.8427 - val_accuracy: 0.6667 - val_loss: 0.8589
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6777 - loss: 0.8374 - val_accuracy: 0.6667 - val_loss: 0.8597
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6721 - loss: 0.8657 - val_accuracy: 0.6667 - val_loss: 0.8612
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7154 - loss: 0.8237 - val_accuracy: 0.7222 - val_loss: 0.8676
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7308 - loss: 0.8260 - val_accuracy: 0.7778 - val_loss: 0.8813
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7304 - loss: 0.8169 - val_accuracy: 0.7778 - val_loss: 0.8961
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7547 - loss: 0.8187 - val_accuracy: 0.7778 - val_loss: 0.9059
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7020 - loss: 0.8259 - val_accuracy: 0.6667 - val_loss: 0.9125
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6886 - loss: 0.8172 - val_accuracy: 0.6667 - val_loss: 0.9097
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6972 - loss: 0.8301 - val_accuracy: 0.6667 - val_loss: 0.9021
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7211 - loss: 0.8248 - val_accuracy: 0.6667 - val_loss: 0.8997
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6814 - loss: 0.8104 - val_accuracy: 0.6111 - val_loss: 0.8947
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7139 - loss: 0.7866 - val_accuracy: 0.6667 - val_loss: 0.8880
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7102 - loss: 0.8116 - val_accuracy: 0.6667 - val_loss: 0.8787
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7614 - loss: 0.7936 - val_accuracy: 0.6667 - val_loss: 0.8636
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7278 - loss: 0.8245 - val_accuracy: 0.6667 - val_loss: 0.8380
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7185 - loss: 0.8249 - val_accuracy: 0.6111 - val_loss: 0.8138
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6953 - loss: 0.7927 - val_accuracy: 0.6667 - val_loss: 0.7955
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7744 - loss: 0.8003 - val_accuracy: 0.7222 - val_loss: 0.7813
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6972 - loss: 0.8241 - val_accuracy: 0.7222 - val_loss: 0.7700
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7113 - loss: 0.7573 - val_accuracy: 0.7222 - val_loss: 0.7609
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7050 - loss: 0.7782 - val_accuracy: 0.7222 - val_loss: 0.7547
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6849 - loss: 0.8146 - val_accuracy: 0.7778 - val_loss: 0.7483
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6875 - loss: 0.7786 - val_accuracy: 0.7778 - val_loss: 0.7408
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6942 - loss: 0.8315 - val_accuracy: 0.7778 - val_loss: 0.7385
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6849 - loss: 0.8114 - val_accuracy: 0.7778 - val_loss: 0.7403
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7438 - loss: 0.8039 - val_accuracy: 0.7778 - val_loss: 0.7446
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7464 - loss: 0.7847 - val_accuracy: 0.7778 - val_loss: 0.7449
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7319 - loss: 0.8211 - val_accuracy: 0.7222 - val_loss: 0.7454
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6766 - loss: 0.8354 - val_accuracy: 0.6667 - val_loss: 0.7520
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6781 - loss: 0.8144 - val_accuracy: 0.6111 - val_loss: 0.7593
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7102 - loss: 0.7852 - val_accuracy: 0.6111 - val_loss: 0.7666
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7180 - loss: 0.7679 - val_accuracy: 0.5556 - val_loss: 0.7721
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7039 - loss: 0.7978 - val_accuracy: 0.5556 - val_loss: 0.7771
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7143 - loss: 0.7989 - val_accuracy: 0.6111 - val_loss: 0.7820
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7464 - loss: 0.7870 - val_accuracy: 0.6111 - val_loss: 0.7842
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7180 - loss: 0.7862 - val_accuracy: 0.6111 - val_loss: 0.7827
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7098 - loss: 0.7893 - val_accuracy: 0.5556 - val_loss: 0.7793
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7222 - loss: 0.7641 - val_accuracy: 0.5556 - val_loss: 0.7733
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7259 - loss: 0.7570 - val_accuracy: 0.6111 - val_loss: 0.7671
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7371 - loss: 0.7594 - val_accuracy: 0.6111 - val_loss: 0.7633
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7226 - loss: 0.7909 - val_accuracy: 0.6667 - val_loss: 0.7620
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7222 - loss: 0.7896 - val_accuracy: 0.6667 - val_loss: 0.7609
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7087 - loss: 0.7780 - val_accuracy: 0.6667 - val_loss: 0.7586
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7629 - loss: 0.7754 - val_accuracy: 0.7222 - val_loss: 0.7570
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7005 - loss: 0.7730 - val_accuracy: 0.8333 - val_loss: 0.7591
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6994 - loss: 0.8182 - val_accuracy: 0.8333 - val_loss: 0.7621
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7334 - loss: 0.7521 - val_accuracy: 0.8333 - val_loss: 0.7698
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7211 - loss: 0.7608 - val_accuracy: 0.7778 - val_loss: 0.7711
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7098 - loss: 0.7730 - val_accuracy: 0.7778 - val_loss: 0.7581
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7087 - loss: 0.7925 - val_accuracy: 0.7778 - val_loss: 0.7446
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7629 - loss: 0.7658 - val_accuracy: 0.8333 - val_loss: 0.7316
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6983 - loss: 0.7780 - val_accuracy: 0.8333 - val_loss: 0.7242
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7237 - loss: 0.7794 - val_accuracy: 0.8333 - val_loss: 0.7190
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7464 - loss: 0.7675 - val_accuracy: 0.7778 - val_loss: 0.7115
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7091 - loss: 0.7791 - val_accuracy: 0.8333 - val_loss: 0.7000
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7390 - loss: 0.7945 - val_accuracy: 0.8889 - val_loss: 0.6934
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6844 - loss: 0.7809 - val_accuracy: 0.8889 - val_loss: 0.6950
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7128 - loss: 0.7725 - val_accuracy: 0.8889 - val_loss: 0.6966
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7603 - loss: 0.7341 - val_accuracy: 0.8889 - val_loss: 0.6948
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7375 - loss: 0.7550 - val_accuracy: 0.8889 - val_loss: 0.6898
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7505 - loss: 0.7268 - val_accuracy: 0.8889 - val_loss: 0.6858
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7532 - loss: 0.7410 - val_accuracy: 0.8889 - val_loss: 0.6867
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7453 - loss: 0.7716 - val_accuracy: 0.8889 - val_loss: 0.6888
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7423 - loss: 0.7807 - val_accuracy: 0.8333 - val_loss: 0.6909
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7117 - loss: 0.7603 - val_accuracy: 0.8333 - val_loss: 0.6933
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6762 - loss: 0.8142 - val_accuracy: 0.8333 - val_loss: 0.6971
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7614 - loss: 0.7300 - val_accuracy: 0.8889 - val_loss: 0.6990
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7035 - loss: 0.7771 - val_accuracy: 0.8889 - val_loss: 0.7031
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7501 - loss: 0.7354 - val_accuracy: 0.7778 - val_loss: 0.7090
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7532 - loss: 0.7328 - val_accuracy: 0.7222 - val_loss: 0.7231
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7898 - loss: 0.7344 - val_accuracy: 0.7222 - val_loss: 0.7353
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7883 - loss: 0.7157 - val_accuracy: 0.7222 - val_loss: 0.7351
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7397 - loss: 0.7538 - val_accuracy: 0.7222 - val_loss: 0.7237
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7551 - loss: 0.7428 - val_accuracy: 0.7222 - val_loss: 0.7150
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7976 - loss: 0.6867 - val_accuracy: 0.8333 - val_loss: 0.7024
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7991 - loss: 0.7472 - val_accuracy: 0.8889 - val_loss: 0.6893
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7356 - loss: 0.7493 - val_accuracy: 0.8333 - val_loss: 0.6789
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7562 - loss: 0.7157 - val_accuracy: 0.7778 - val_loss: 0.6706
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7289 - loss: 0.7162 - val_accuracy: 0.8333 - val_loss: 0.6621
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7584 - loss: 0.7561 - val_accuracy: 0.8889 - val_loss: 0.6566
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7020 - loss: 0.7607 - val_accuracy: 0.8889 - val_loss: 0.6586
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7211 - loss: 0.7671 - val_accuracy: 0.8333 - val_loss: 0.6707
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7573 - loss: 0.7407 - val_accuracy: 0.8333 - val_loss: 0.6810
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7547 - loss: 0.7102 - val_accuracy: 0.8333 - val_loss: 0.6871
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6860 - loss: 0.7494 - val_accuracy: 0.8333 - val_loss: 0.6905
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6957 - loss: 0.7391 - val_accuracy: 0.8333 - val_loss: 0.6904
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7319 - loss: 0.7356 - val_accuracy: 0.8333 - val_loss: 0.6864
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7304 - loss: 0.7296 - val_accuracy: 0.8333 - val_loss: 0.6798
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7382 - loss: 0.7355 - val_accuracy: 0.8333 - val_loss: 0.6724
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7289 - loss: 0.7343 - val_accuracy: 0.7778 - val_loss: 0.6681
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7722 - loss: 0.7116 - val_accuracy: 0.8333 - val_loss: 0.6652
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7397 - loss: 0.7171 - val_accuracy: 0.8333 - val_loss: 0.6595
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7532 - loss: 0.7129 - val_accuracy: 0.7778 - val_loss: 0.6555
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7401 - loss: 0.7500 - val_accuracy: 0.8333 - val_loss: 0.6536
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7330 - loss: 0.7424 - val_accuracy: 0.8333 - val_loss: 0.6504
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7375 - loss: 0.7340 - val_accuracy: 0.8333 - val_loss: 0.6484
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7562 - loss: 0.7112 - val_accuracy: 0.8889 - val_loss: 0.6444
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7293 - loss: 0.7117 - val_accuracy: 0.8889 - val_loss: 0.6404
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7345 - loss: 0.7078 - val_accuracy: 0.8889 - val_loss: 0.6360
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7479 - loss: 0.7005 - val_accuracy: 0.8889 - val_loss: 0.6316
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7237 - loss: 0.7232 - val_accuracy: 0.8889 - val_loss: 0.6312
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7330 - loss: 0.7012 - val_accuracy: 0.8889 - val_loss: 0.6307
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7479 - loss: 0.7225 - val_accuracy: 0.8889 - val_loss: 0.6284
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7315 - loss: 0.7107 - val_accuracy: 0.8889 - val_loss: 0.6304
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7490 - loss: 0.6977 - val_accuracy: 0.8889 - val_loss: 0.6301
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.7852 - loss: 0.7050 - val_accuracy: 0.9444 - val_loss: 0.6242
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7479 - loss: 0.7139 - val_accuracy: 0.9444 - val_loss: 0.6171
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7468 - loss: 0.7132 - val_accuracy: 0.9444 - val_loss: 0.6152
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7640 - loss: 0.7051 - val_accuracy: 0.9444 - val_loss: 0.6173
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7640 - loss: 0.6971 - val_accuracy: 0.9444 - val_loss: 0.6219
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7666 - loss: 0.6830 - val_accuracy: 0.8889 - val_loss: 0.6257
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8058 - loss: 0.7021 - val_accuracy: 0.8889 - val_loss: 0.6318
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7800 - loss: 0.6956 - val_accuracy: 0.8889 - val_loss: 0.6374
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7815 - loss: 0.6725 - val_accuracy: 0.9444 - val_loss: 0.6370
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7763 - loss: 0.7225 - val_accuracy: 0.9444 - val_loss: 0.6321
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7304 - loss: 0.6968 - val_accuracy: 0.8889 - val_loss: 0.6252
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7293 - loss: 0.6949 - val_accuracy: 0.9444 - val_loss: 0.6186
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7800 - loss: 0.6979 - val_accuracy: 0.9444 - val_loss: 0.6139
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7412 - loss: 0.7022 - val_accuracy: 0.9444 - val_loss: 0.6085
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7883 - loss: 0.6789 - val_accuracy: 0.8889 - val_loss: 0.6088
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7438 - loss: 0.7275 - val_accuracy: 0.8889 - val_loss: 0.6164
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7898 - loss: 0.6970 - val_accuracy: 0.8889 - val_loss: 0.6212
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7573 - loss: 0.7125 - val_accuracy: 0.8889 - val_loss: 0.6218
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7640 - loss: 0.6930 - val_accuracy: 0.8889 - val_loss: 0.6234
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7659 - loss: 0.6760 - val_accuracy: 0.8889 - val_loss: 0.6266
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7371 - loss: 0.7454 - val_accuracy: 0.8889 - val_loss: 0.6345
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7625 - loss: 0.6861 - val_accuracy: 0.8889 - val_loss: 0.6455
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7356 - loss: 0.6911 - val_accuracy: 0.8889 - val_loss: 0.6554
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7722 - loss: 0.6608 - val_accuracy: 0.8889 - val_loss: 0.6662
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7547 - loss: 0.6726 - val_accuracy: 0.7778 - val_loss: 0.6721
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7629 - loss: 0.6810 - val_accuracy: 0.7222 - val_loss: 0.6712
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7894 - loss: 0.6732 - val_accuracy: 0.6667 - val_loss: 0.6649
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7640 - loss: 0.6762 - val_accuracy: 0.6667 - val_loss: 0.6555
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7711 - loss: 0.6941 - val_accuracy: 0.6667 - val_loss: 0.6468
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7573 - loss: 0.6860 - val_accuracy: 0.7778 - val_loss: 0.6416
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7883 - loss: 0.6484 - val_accuracy: 0.7778 - val_loss: 0.6399
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7401 - loss: 0.6837 - val_accuracy: 0.7222 - val_loss: 0.6394
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7490 - loss: 0.6942 - val_accuracy: 0.7778 - val_loss: 0.6373
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7763 - loss: 0.6500 - val_accuracy: 0.7778 - val_loss: 0.6291
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7464 - loss: 0.6848 - val_accuracy: 0.7778 - val_loss: 0.6218
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7599 - loss: 0.6858 - val_accuracy: 0.8333 - val_loss: 0.6172
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8032 - loss: 0.6520 - val_accuracy: 0.8889 - val_loss: 0.6125
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7603 - loss: 0.6846 - val_accuracy: 0.8889 - val_loss: 0.6124
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7991 - loss: 0.6818 - val_accuracy: 0.8889 - val_loss: 0.6148
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7737 - loss: 0.6705 - val_accuracy: 0.8889 - val_loss: 0.6188
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7815 - loss: 0.6709 - val_accuracy: 0.9444 - val_loss: 0.6209
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7898 - loss: 0.6750 - val_accuracy: 0.9444 - val_loss: 0.6241
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7636 - loss: 0.6486 - val_accuracy: 0.8889 - val_loss: 0.6320
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7304 - loss: 0.6678 - val_accuracy: 0.7778 - val_loss: 0.6419
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7603 - loss: 0.6699 - val_accuracy: 0.7778 - val_loss: 0.6415
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7785 - loss: 0.6753 - val_accuracy: 0.7778 - val_loss: 0.6411
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7293 - loss: 0.7010 - val_accuracy: 0.7778 - val_loss: 0.6470
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7278 - loss: 0.6758 - val_accuracy: 0.7778 - val_loss: 0.6514
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7852 - loss: 0.6919 - val_accuracy: 0.7222 - val_loss: 0.6576
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7562 - loss: 0.6548 - val_accuracy: 0.7222 - val_loss: 0.6624
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7748 - loss: 0.6821 - val_accuracy: 0.7222 - val_loss: 0.6765
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7744 - loss: 0.6868 - val_accuracy: 0.6111 - val_loss: 0.6902
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7614 - loss: 0.6758 - val_accuracy: 0.7222 - val_loss: 0.6830
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7345 - loss: 0.6737 - val_accuracy: 0.7778 - val_loss: 0.6669
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7815 - loss: 0.6351 - val_accuracy: 0.7778 - val_loss: 0.6505
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7815 - loss: 0.6663 - val_accuracy: 0.7778 - val_loss: 0.6343
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7692 - loss: 0.6572 - val_accuracy: 0.8333 - val_loss: 0.6200
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7887 - loss: 0.6502 - val_accuracy: 0.8333 - val_loss: 0.6116
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7965 - loss: 0.6591 - val_accuracy: 0.8889 - val_loss: 0.6100
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7804 - loss: 0.6588 - val_accuracy: 0.8889 - val_loss: 0.6089
# Epoch 371/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7804 - loss: 0.6641 - val_accuracy: 0.8333 - val_loss: 0.6068
# Epoch 372/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7696 - loss: 0.6666 - val_accuracy: 0.8333 - val_loss: 0.6077
# Epoch 373/1000
# ...
# Epoch 878/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8895 - loss: 0.3828 - val_accuracy: 0.8889 - val_loss: 0.3994
# Epoch 879/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8182 - loss: 0.4029 - val_accuracy: 0.8889 - val_loss: 0.4111
# Epoch 880/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8708 - loss: 0.4010 - val_accuracy: 0.8889 - val_loss: 0.4154
# Epoch 881/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8869 - loss: 0.3983 - val_accuracy: 0.8889 - val_loss: 0.4115
# Epoch 882/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8476 - loss: 0.4395 - val_accuracy: 0.8889 - val_loss: 0.4113
# Epoch 883/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8652 - loss: 0.4291 - val_accuracy: 0.8333 - val_loss: 0.4154
# Epoch 884/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8704 - loss: 0.4242 - val_accuracy: 0.8333 - val_loss: 0.4115
# Epoch 885/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8864 - loss: 0.4046 - val_accuracy: 0.8333 - val_loss: 0.4045
# Epoch 886/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8559 - loss: 0.4002 - val_accuracy: 0.8333 - val_loss: 0.4055
# Epoch 887/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8786 - loss: 0.3852 - val_accuracy: 0.8333 - val_loss: 0.4152
# Epoch 888/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8446 - loss: 0.4064 - val_accuracy: 0.8333 - val_loss: 0.4338
# Epoch 889/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8528 - loss: 0.4062 - val_accuracy: 0.8333 - val_loss: 0.4548
# Epoch 890/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8312 - loss: 0.4426 - val_accuracy: 0.8333 - val_loss: 0.4620
# Epoch 891/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8869 - loss: 0.4418 - val_accuracy: 0.8333 - val_loss: 0.4620
# Epoch 892/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8895 - loss: 0.3923 - val_accuracy: 0.8333 - val_loss: 0.4650
# Epoch 893/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8843 - loss: 0.4279 - val_accuracy: 0.8333 - val_loss: 0.4551
# Epoch 894/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8544 - loss: 0.3807 - val_accuracy: 0.8889 - val_loss: 0.4445
# Epoch 895/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8827 - loss: 0.4099 - val_accuracy: 0.8889 - val_loss: 0.4345
# Epoch 896/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8611 - loss: 0.4084 - val_accuracy: 0.8889 - val_loss: 0.4259
# Epoch 897/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8678 - loss: 0.3940 - val_accuracy: 0.8889 - val_loss: 0.4197
# Epoch 898/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8435 - loss: 0.4042 - val_accuracy: 0.8889 - val_loss: 0.4161
# Epoch 899/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8812 - loss: 0.3952 - val_accuracy: 0.8889 - val_loss: 0.4135
# Epoch 900/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8528 - loss: 0.4072 - val_accuracy: 0.8889 - val_loss: 0.4061
# Epoch 901/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8353 - loss: 0.3989 - val_accuracy: 0.8889 - val_loss: 0.3913
# Epoch 902/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8823 - loss: 0.4243 - val_accuracy: 0.8889 - val_loss: 0.3775
# Epoch 903/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8734 - loss: 0.4310 - val_accuracy: 0.8889 - val_loss: 0.3689
# Epoch 904/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8786 - loss: 0.4139 - val_accuracy: 0.9444 - val_loss: 0.3654
# Epoch 905/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8704 - loss: 0.4125 - val_accuracy: 0.9444 - val_loss: 0.3660
# Epoch 906/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9055 - loss: 0.3714 - val_accuracy: 0.9444 - val_loss: 0.3711
# Epoch 907/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8544 - loss: 0.4130 - val_accuracy: 0.9444 - val_loss: 0.3802
# Epoch 908/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8659 - loss: 0.4339 - val_accuracy: 0.9444 - val_loss: 0.3940
# Epoch 909/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8704 - loss: 0.4214 - val_accuracy: 0.9444 - val_loss: 0.4162
# Epoch 910/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9174 - loss: 0.3825 - val_accuracy: 0.9444 - val_loss: 0.4350
# Epoch 911/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8229 - loss: 0.4378 - val_accuracy: 0.9444 - val_loss: 0.4330
# Epoch 912/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8435 - loss: 0.3880 - val_accuracy: 0.8889 - val_loss: 0.4144
# Epoch 913/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8559 - loss: 0.4263 - val_accuracy: 0.8889 - val_loss: 0.3992
# Epoch 914/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8838 - loss: 0.4014 - val_accuracy: 0.8889 - val_loss: 0.3889
# Epoch 915/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8652 - loss: 0.4311 - val_accuracy: 0.8889 - val_loss: 0.3792
# Epoch 916/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8693 - loss: 0.3970 - val_accuracy: 0.9444 - val_loss: 0.3720
# Epoch 917/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8368 - loss: 0.4286 - val_accuracy: 0.9444 - val_loss: 0.3666
# Epoch 918/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8682 - loss: 0.3992 - val_accuracy: 0.9444 - val_loss: 0.3642
# Epoch 919/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8786 - loss: 0.4161 - val_accuracy: 0.8889 - val_loss: 0.3678
# Epoch 920/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8827 - loss: 0.3875 - val_accuracy: 0.8889 - val_loss: 0.3783
# Epoch 921/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8435 - loss: 0.4094 - val_accuracy: 0.8889 - val_loss: 0.3926
# Epoch 922/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8678 - loss: 0.3861 - val_accuracy: 0.8889 - val_loss: 0.4096
# Epoch 923/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8849 - loss: 0.3931 - val_accuracy: 0.8333 - val_loss: 0.4115
# Epoch 924/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8409 - loss: 0.4233 - val_accuracy: 0.8889 - val_loss: 0.4039
# Epoch 925/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8786 - loss: 0.3991 - val_accuracy: 0.8889 - val_loss: 0.4025
# Epoch 926/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8962 - loss: 0.3904 - val_accuracy: 0.8889 - val_loss: 0.4067
# Epoch 927/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8652 - loss: 0.4047 - val_accuracy: 0.8333 - val_loss: 0.4167
# Epoch 928/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8745 - loss: 0.3932 - val_accuracy: 0.8333 - val_loss: 0.4164
# Epoch 929/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9029 - loss: 0.3500 - val_accuracy: 0.8333 - val_loss: 0.4056
# Epoch 930/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8652 - loss: 0.4038 - val_accuracy: 0.8333 - val_loss: 0.3899
# Epoch 931/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8342 - loss: 0.4264 - val_accuracy: 0.8333 - val_loss: 0.3770
# Epoch 932/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8745 - loss: 0.3964 - val_accuracy: 0.8889 - val_loss: 0.3671
# Epoch 933/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8611 - loss: 0.4076 - val_accuracy: 0.8889 - val_loss: 0.3646
# Epoch 934/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8476 - loss: 0.4295 - val_accuracy: 0.8889 - val_loss: 0.3670
# Epoch 935/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8502 - loss: 0.3757 - val_accuracy: 0.8889 - val_loss: 0.3734
# Epoch 936/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8585 - loss: 0.4114 - val_accuracy: 0.8889 - val_loss: 0.3834
# Epoch 937/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8756 - loss: 0.3824 - val_accuracy: 0.8333 - val_loss: 0.3933
# Epoch 938/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9107 - loss: 0.3683 - val_accuracy: 0.8333 - val_loss: 0.4066
# Epoch 939/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8678 - loss: 0.3941 - val_accuracy: 0.8333 - val_loss: 0.4111
# Epoch 940/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9040 - loss: 0.3824 - val_accuracy: 0.8333 - val_loss: 0.4108
# Epoch 941/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8745 - loss: 0.4025 - val_accuracy: 0.8333 - val_loss: 0.4110
# Epoch 942/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8652 - loss: 0.3958 - val_accuracy: 0.8333 - val_loss: 0.4115
# Epoch 943/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8921 - loss: 0.3735 - val_accuracy: 0.8333 - val_loss: 0.4114
# Epoch 944/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8652 - loss: 0.3973 - val_accuracy: 0.8333 - val_loss: 0.4088
# Epoch 945/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8585 - loss: 0.4444 - val_accuracy: 0.8333 - val_loss: 0.3964
# Epoch 946/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8559 - loss: 0.4227 - val_accuracy: 0.8333 - val_loss: 0.3843
# Epoch 947/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8797 - loss: 0.3836 - val_accuracy: 0.8889 - val_loss: 0.3827
# Epoch 948/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8704 - loss: 0.3614 - val_accuracy: 0.8889 - val_loss: 0.3798
# Epoch 949/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8637 - loss: 0.4181 - val_accuracy: 0.9444 - val_loss: 0.3751
# Epoch 950/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8435 - loss: 0.4299 - val_accuracy: 0.9444 - val_loss: 0.3616
# Epoch 951/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8734 - loss: 0.3984 - val_accuracy: 0.8889 - val_loss: 0.3499
# Epoch 952/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8947 - loss: 0.3793 - val_accuracy: 1.0000 - val_loss: 0.3407
# Epoch 953/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8424 - loss: 0.4263 - val_accuracy: 1.0000 - val_loss: 0.3356
# Epoch 954/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8745 - loss: 0.3917 - val_accuracy: 0.8889 - val_loss: 0.3387
# Epoch 955/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8518 - loss: 0.4279 - val_accuracy: 0.8889 - val_loss: 0.3444
# Epoch 956/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8533 - loss: 0.4152 - val_accuracy: 0.8889 - val_loss: 0.3474
# Epoch 957/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8260 - loss: 0.4194 - val_accuracy: 0.8889 - val_loss: 0.3551
# Epoch 958/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8570 - loss: 0.4060 - val_accuracy: 0.9444 - val_loss: 0.3692
# Epoch 959/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8611 - loss: 0.3989 - val_accuracy: 0.8889 - val_loss: 0.3822
# Epoch 960/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8581 - loss: 0.4229 - val_accuracy: 0.8889 - val_loss: 0.3964
# Epoch 961/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9122 - loss: 0.3744 - val_accuracy: 0.8889 - val_loss: 0.4172
# Epoch 962/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8693 - loss: 0.3976 - val_accuracy: 0.8889 - val_loss: 0.4277
# Epoch 963/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8544 - loss: 0.4121 - val_accuracy: 0.8889 - val_loss: 0.4308
# Epoch 964/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8492 - loss: 0.3947 - val_accuracy: 0.8889 - val_loss: 0.4329
# Epoch 965/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8936 - loss: 0.3646 - val_accuracy: 0.8889 - val_loss: 0.4248
# Epoch 966/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8932 - loss: 0.3909 - val_accuracy: 0.8889 - val_loss: 0.4148
# Epoch 967/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8791 - loss: 0.3994 - val_accuracy: 0.8889 - val_loss: 0.4046
# Epoch 968/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8678 - loss: 0.4046 - val_accuracy: 0.8889 - val_loss: 0.3955
# Epoch 969/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8611 - loss: 0.3964 - val_accuracy: 0.8333 - val_loss: 0.3953
# Epoch 970/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8786 - loss: 0.3890 - val_accuracy: 0.8333 - val_loss: 0.4042
# Epoch 971/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8574 - loss: 0.3911 - val_accuracy: 0.8333 - val_loss: 0.4087
# Epoch 972/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8797 - loss: 0.3967 - val_accuracy: 0.8333 - val_loss: 0.4157
# Epoch 973/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8559 - loss: 0.4127 - val_accuracy: 0.8889 - val_loss: 0.4212
# Epoch 974/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8461 - loss: 0.3910 - val_accuracy: 0.8889 - val_loss: 0.4248
# Epoch 975/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8570 - loss: 0.3874 - val_accuracy: 0.8333 - val_loss: 0.4267
# Epoch 976/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8492 - loss: 0.4010 - val_accuracy: 0.8889 - val_loss: 0.4217
# Epoch 977/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8895 - loss: 0.3714 - val_accuracy: 0.8889 - val_loss: 0.4134
# Epoch 978/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9029 - loss: 0.3771 - val_accuracy: 0.7778 - val_loss: 0.4133
# Epoch 979/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8383 - loss: 0.4020 - val_accuracy: 0.7778 - val_loss: 0.4146
# Epoch 980/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8988 - loss: 0.3692 - val_accuracy: 0.7778 - val_loss: 0.4132
# Epoch 981/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8492 - loss: 0.3811 - val_accuracy: 0.8333 - val_loss: 0.3998
# Epoch 982/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8394 - loss: 0.3887 - val_accuracy: 0.8889 - val_loss: 0.3759
# Epoch 983/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9137 - loss: 0.3565 - val_accuracy: 0.9444 - val_loss: 0.3572
# Epoch 984/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8487 - loss: 0.4563 - val_accuracy: 0.9444 - val_loss: 0.3554
# Epoch 985/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8858 - loss: 0.3615 - val_accuracy: 0.8889 - val_loss: 0.3629
# Epoch 986/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8921 - loss: 0.3600 - val_accuracy: 0.8889 - val_loss: 0.3674
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8797 - loss: 0.3978 - val_accuracy: 0.8333 - val_loss: 0.3642
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8760 - loss: 0.3808 - val_accuracy: 0.8333 - val_loss: 0.3611
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8492 - loss: 0.3981 - val_accuracy: 0.9444 - val_loss: 0.3563
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8461 - loss: 0.4088 - val_accuracy: 0.9444 - val_loss: 0.3488
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8208 - loss: 0.4132 - val_accuracy: 0.8889 - val_loss: 0.3431
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8465 - loss: 0.3891 - val_accuracy: 0.8889 - val_loss: 0.3512
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8693 - loss: 0.3752 - val_accuracy: 0.8889 - val_loss: 0.3644
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8570 - loss: 0.3924 - val_accuracy: 0.8889 - val_loss: 0.3725
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8988 - loss: 0.3771 - val_accuracy: 0.8889 - val_loss: 0.3784
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8719 - loss: 0.3776 - val_accuracy: 0.8889 - val_loss: 0.3798
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8812 - loss: 0.3736 - val_accuracy: 0.8889 - val_loss: 0.3776
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8275 - loss: 0.3678 - val_accuracy: 0.8889 - val_loss: 0.3717
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8869 - loss: 0.3830 - val_accuracy: 0.8889 - val_loss: 0.3674
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8730 - loss: 0.3654 - val_accuracy: 0.8889 - val_loss: 0.3654

# %%
# Evaluate the model

# Load the test data
X_eeg_test, y_test = load_eeg_epochs(EEG_TEST_SET, EEG_CHANNELS, EEG_SAMPLES_PER_EPOCH)
X_hr_test, y_hr_test = load_wearable_epochs(HR_TEST_SET, WEARABLE_SAMPLES_PER_EPOCH)
X_eda_test, y_eda_test = load_wearable_epochs(EDA_TEST_SET, WEARABLE_SAMPLES_PER_EPOCH)

# Assert that y_test, y_hr_test, and y_eda_test are the same
assert np.array_equal(y_test, y_hr_test), "y_test and y_hr_test do not match!"
assert np.array_equal(y_test, y_eda_test), "y_test and y_eda_test do not match!"

# Shuffle the data
X_eeg_test, X_hr_test, X_eda_test, y_test = shuffle(X_eeg_test, X_hr_test, X_eda_test, y_test, random_state=42)

# Align shapes
# X_hr_test shape: (n_test, 250, 1) → reshape to (n_test, 1, 250, 1)
X_hr_test = X_hr_test.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)
# X_eda_test shape: (n_test, 250, 1) → reshape to (n_test, 1, 250, 1)
X_eda_test = X_eda_test.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)

# Model evaluation
test_loss, test_accuracy = model.evaluate(
    {'eeg_input': X_eeg_test, 'hr_input': X_hr_test, 'eda_input': X_eda_test},
    y_test,
    batch_size=64,
    verbose=1
)
print(f"Test loss: {test_loss:.4f}, Test accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3333 - loss: 2.7411
# Test loss: 2.7411, Test accuracy: 0.3333

# %% [markdown]
# Step 5: Model conversion to TFLite

# %%
# -------------------- Conversion to TFLite --------------------
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # optional quantization
tflite_model = converter.convert()
with open(TFLITE_MODEL,'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\giova\AppData\Local\Temp\tmp9rn9_0ip\assets
# INFO:tensorflow:Assets written to: C:\Users\giova\AppData\Local\Temp\tmp9rn9_0ip\assets
# Saved artifact at 'C:\Users\giova\AppData\Local\Temp\tmp9rn9_0ip'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 6, 1000, 1), dtype=tf.float32, name='eeg_input'), TensorSpec(shape=(None, 1, 250, 1), dtype=tf.float32, name='hr_input'), TensorSpec(shape=(None, 1, 250, 1), dtype=tf.float32, name='eda_input')]
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   1569855054672: TensorSpec(shape=(1, 8, 1, 1), dtype=tf.float32, name=None)
#   1569855050800: TensorSpec(shape=(1, 8, 1, 1), dtype=tf.float32, name=None)
#   1569930107664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930366640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930368752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930367520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930365760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569855053440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930371568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930367696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930372624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930367344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930375616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930594432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930596016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930597424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930594080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930607984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1569930604992: TensorSpec(shape=(), dtype=tf.resource, name=None)
