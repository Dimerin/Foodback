# %% [markdown]
# Parameters Definition

# %%
# ------------------ Folders ------------------

# Dataset
DATASET = "dataset/"

# Raw Data
RAW_DATASET = DATASET + "raw/"

# Upsampled Data (for HR and EDA)
UPSAMPLED_DATASET = DATASET + "upsampled/"

# Splitted Data
SPLITTED_DATASET = DATASET + "splitted/"
# Training and Test Sets
TRAINING_SET = SPLITTED_DATASET + "training_set/"
TEST_SET = SPLITTED_DATASET + "test_set/"

# ---------------------------------------------


# ------------------- Files -------------------

# Raw Data
RAW_EEG = RAW_DATASET + "eeg_data.csv"
RAW_HR = RAW_DATASET + "hr_data.csv"
RAW_EDA = RAW_DATASET + "eda_data.csv"

# Upsampled Data
UPSAMPLED_HR = UPSAMPLED_DATASET + "upsampled_hr_data.csv"
UPSAMPLED_EDA = UPSAMPLED_DATASET + "upsampled_eda_data.csv"


# Training and Test Sets
# EEG
EEG_TRAINING_SET = TRAINING_SET + "eeg_training_set.csv"
EEG_TEST_SET = TEST_SET + "eeg_test_set.csv"
# HR
HR_TRAINING_SET = TRAINING_SET + "hr_training_set.csv"
HR_TEST_SET = TEST_SET + "hr_test_set.csv"
# EDA
EDA_TRAINING_SET = TRAINING_SET + "eda_training_set.csv"
EDA_TEST_SET = TEST_SET + "eda_test_set.csv"

# TensorFlowLite Model
TFLITE_MODEL = "eegnet_preproc.tflite"

# ---------------------------------------------


# ----------------- Constants -----------------

# Epoch Duration in seconds
EPOCH_DURATION = 2

# EEG Channels
EEG_CHANNELS = ['ch1','ch2','ch3','ch4','ch5','ch6']
# EEG Sampling Frequency
EEG_SAMPLING_FREQUENCY = 500 # Hz
# Samples per epoch
EEG_SAMPLES_PER_EPOCH = EPOCH_DURATION * EEG_SAMPLING_FREQUENCY  # 2 seconds at 500 Hz

# Target Sampling Frequency
FS_TARGET  = 125 # Hz

# Wearable sampling frequency
WEARABLE_SAMPLES_PER_EPOCH = EPOCH_DURATION * FS_TARGET  # 2 seconds at 125 Hz

# ---------------------------------------------

# %%
# ------------------- Imports -------------------
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from scipy.signal import firwin
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Lambda, Conv2D, DepthwiseConv2D, SeparableConv2D,
    BatchNormalization, Activation, AveragePooling2D,
    Dropout, Flatten, Dense, Concatenate
)
from tensorflow.keras.constraints import max_norm
# --------------------------------------------------

# %% [markdown]
# Step 1: Upsample data coming from the smartwatch to bring it to 125Hz

# %%
# Utility function to upsample data
def upsample_data(group, target_freq=125, duration_s=10):
    # Calculate start and end timestamps per experiment
    start = group['timestamp'].min()
    end = start + duration_s * 1000
    # Generate target timestamps (125 samples/sec × duration)
    target_times = np.linspace(start, end, target_freq * duration_s)
    # Interpolate 'value' at these timestamps
    values = np.interp(target_times, group['timestamp'], group['value'])
    # Build upsampled DataFrame
    up_df = pd.DataFrame({
        'experiment': group['experiment'].iloc[0],
        'timestamp': target_times.astype(int),
        'value': values,
        'subject': group['subject'].iloc[0],
        'rating': group['rating'].iloc[0]
    })
    # Ensure exactly target_freq*duration_s rows
    return up_df.iloc[:target_freq * duration_s]

# %%
# Heart Rate

# 1. Read the raw CSV (all experiments)
raw_df = pd.read_csv(RAW_HR)

# 2. Upsample each experiment
upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# 3. Export to CSV

# Creating output directory if it doesn't exist
os.makedirs(UPSAMPLED_DATASET, exist_ok=True)

upsampled_df.to_csv(UPSAMPLED_HR, index=False)

print(f"Upsampling complete! Data saved to {UPSAMPLED_HR}.")
# Out:
# Upsampling complete! Data saved to dataset/upsampled/upsampled_hr_data.csv.
# C:\Users\giova\AppData\Local\Temp\ipykernel_20216\2837762272.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# %%
# EDA

# 1. Read the raw CSV (all experiments)
raw_df = pd.read_csv(RAW_EDA)

# 2. Upsample each experiment
upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# 3. Export to CSV

# Creating output directory if it doesn't exist
os.makedirs(UPSAMPLED_DATASET, exist_ok=True)

upsampled_df.to_csv(UPSAMPLED_EDA, index=False)

print(f"Upsampling complete! Data saved to {UPSAMPLED_EDA}.")
# Out:
# Upsampling complete! Data saved to dataset/upsampled/upsampled_eda_data.csv.
# C:\Users\giova\AppData\Local\Temp\ipykernel_20216\2060052639.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   upsampled_df = raw_df.groupby('experiment', group_keys=False).apply(upsample_data)

# %% [markdown]
# Step 2: Split data into training and test sets using an hold-out strategy

# %%
# Load the EEG raw dataset
eeg_df = pd.read_csv(RAW_EEG)

# Load the upsampled heart-rate dataset
hr_df = pd.read_csv(UPSAMPLED_HR)

# Load the Upsampled eda dataset
eda_df = pd.read_csv(UPSAMPLED_EDA)

# Extract unique experiment IDs from the EEG data
experiments = eeg_df['experiment'].unique()

# Split experiments: 80% train, 20% test
train_exps, test_exps = train_test_split(
    experiments,
    test_size=0.2,
    random_state=42
)

# Partition the three datasets by the same experiment split
# EEG splits
eeg_train = eeg_df[eeg_df['experiment'].isin(train_exps)].reset_index(drop=True)
eeg_test  = eeg_df[eeg_df['experiment'].isin(test_exps)].reset_index(drop=True)

# Heart-rate splits
hr_train = hr_df[hr_df['experiment'].isin(train_exps)].reset_index(drop=True)
hr_test  = hr_df[hr_df['experiment'].isin(test_exps)].reset_index(drop=True)

# EDA splits
eda_train = eda_df[eda_df['experiment'].isin(train_exps)].reset_index(drop=True)
eda_test  = eda_df[eda_df['experiment'].isin(test_exps)].reset_index(drop=True)

# Creating output folders if they do not exist
os.makedirs(TRAINING_SET, exist_ok=True)
os.makedirs(TEST_SET,     exist_ok=True)

# Save the training and test sets to CSV files
# EEG
eeg_train.to_csv(EEG_TRAINING_SET, index=False)
eeg_test.to_csv(EEG_TEST_SET, index=False)

# Heart-rate
hr_train.to_csv(HR_TRAINING_SET, index=False)
hr_test.to_csv(HR_TEST_SET, index=False)

# EDA
eda_train.to_csv(EDA_TRAINING_SET, index=False)
eda_test.to_csv(EDA_TEST_SET, index=False)

# Sanity checks
print("Train experiments:", train_exps)
print("Test experiments :", test_exps)
print(f"EEG train rows: {len(eeg_train)}, test rows: {len(eeg_test)}")
print(f"HR train rows: {len(hr_train)}, test rows: {len(hr_test)}")
print(f"EDA train rows: {len(eda_train)}, test rows: {len(eda_test)}")
# Out:
# Train experiments: [ 4  7 25 33 20 18 14 43 16 10 17 38 32 28  1 31 30  6 12 34  2 41 22  3
#  35 24 37 11 23 19 45 21  8 15 29 39]
# Test experiments : [40 26 27 44 36 42  5 13  9]
# EEG train rows: 180000, test rows: 45000
# HR train rows: 45000, test rows: 11250
# EDA train rows: 45000, test rows: 11250

# %% [markdown]
# Step 3: Model definition

# %%
# -------------------- Design FIR filters --------------------
fs_in       = 500                   # incoming sample rate
fs_target   = 125                   # desired rate after decimation
dec_factor  = fs_in // fs_target    # must be 4
numtaps     = 101                   # filter length 

# 1) High-pass (0.5 Hz) for detrend
hp_coeffs   = firwin(numtaps, cutoff=0.5, fs=fs_in, pass_zero=False)
# 2) Band-pass (0.5–50 Hz)
bp_coeffs   = firwin(numtaps, cutoff=[0.5, 50.], fs=fs_in, pass_zero=False)
# 3) Notch (49–51 Hz)
bs_coeffs   = firwin(numtaps, cutoff=[49., 51.], fs=fs_in, pass_zero=True)
# 4) Anti-alias low-pass (≤62.5 Hz)
aa_coeffs   = firwin(numtaps, cutoff=fs_target/2, fs=fs_in)

# -------------------- Helper to apply 1D FIR --------------------
def apply_fir(x, coeffs):
    """ x: (B, Ch, T, 1) → applies 1-D FIR along time via depthwise conv """
    # 1) remove trailing singleton and transpose to NHWC with time in W, channels in C:
    #    (B, Ch, T, 1) → (B, T, Ch)
    x2 = tf.squeeze(x, -1)
    #    (B, T, Ch) → (B, 1, T, Ch)
    x2 = tf.expand_dims(x2, 1)

    # 2) build depthwise kernel of shape (1, filter_len, in_channels=Ch, channel_multiplier=1)
    #    coeffs is (filter_len,), so first reshape to (1, filter_len, 1, 1)
    k = tf.constant(coeffs.reshape(1, -1, 1, 1), tf.float32)
    #    then tile the "in_channels" dimension to match your EEG channels
    n_ch = x2.shape[-1]
    k = tf.tile(k, [1, 1, n_ch, 1])  # now (1, filter_len, Ch, 1)

    # 3) depthwise conv2d → same padding
    y = tf.nn.depthwise_conv2d(
        x2,
        k,
        strides=[1, 1, 1, 1],
        padding='SAME',
        data_format='NHWC'
    )
    # y has shape (B, 1, T, Ch); we want back (B, Ch, T, 1)

    y = tf.squeeze(y, 1)            # → (B, T, Ch)
    y = tf.transpose(y, [0, 2, 1])  # → (B, Ch, T)
    return y[..., tf.newaxis]       # → (B, Ch, T, 1)


# -------------------- Combined model --------------------
def PreprocAndEEGNet(nb_classes,
                     channel_means, channel_stds,  # arrays of shape (8,)
                     eeg_chans=6,
                     fs_in=500,                    # original raw rate for EEG
                     fs_target=125,                # rate after decimation
                     duration_s=2.0,               # length of each input epoch in seconds
                     dropoutRate=0.5,
                     F1=8, D=2, F2=16,
                     norm_rate=0.25):
    # Calculate dynamic shapes
    Samples_in = int(fs_in * duration_s)       # e.g. 1000 samples @ 500 Hz
    Samples    = int(fs_target * duration_s)   # e.g. 250 samples @ 125 Hz
    dec_factor = fs_in // fs_target            # 4
    kernLength = int(0.5 * fs_target)          # half the target rate: 62
    
    # EEG input path
    eeg_in = Input(shape=(eeg_chans, Samples_in, 1), name='eeg_input')

    # 1) High-pass
    x = Lambda(lambda z: apply_fir(z, hp_coeffs), output_shape=lambda input_shape: input_shape, name='hp')(eeg_in)
    # 2) Band-pass
    x = Lambda(lambda z: apply_fir(z, bp_coeffs), output_shape=lambda input_shape: input_shape, name='bp')(x)
    # 3) Notch
    x = Lambda(lambda z: apply_fir(z, bs_coeffs), output_shape=lambda input_shape: input_shape, name='notch')(x)
    # 4) Anti-alias low-pass
    x = Lambda(lambda z: apply_fir(z, aa_coeffs), output_shape=lambda input_shape: input_shape, name='aa')(x)
    # 5) Decimate by slicing every dec_factor-th sample
    x = Lambda(lambda z: z[:, :, ::dec_factor, :], name='decimate')(x)

    # now x has shape (batch, Chans, Samples_in/4, 1) → (batch,6,250,1)

    # HR input path (no filtering, already 125 Hz)
    hr_in = Input(shape=(1, Samples, 1), name='hr_input')

    # EDA input path (no filtering, already 125 Hz)
    eda_in = Input(shape=(1, Samples, 1), name='eda_input')
    
    # 3) Concatenate along channel axis → (B, 8, 250, 1)
    merged = Concatenate(axis=1)([x, hr_in, eda_in])
    Chans = eeg_chans + 2  # now 8
    
    # --- EEGNet layers expects Samples=250 ---
    # Keras Implementation of EEGNet
    # http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    # Normalization
    # we broadcast: (1,8,1,1) → will divide/subtract per-channel
    means = tf.constant(channel_means.reshape(1, -1, 1, 1), dtype=tf.float32)
    stds  = tf.constant(channel_stds .reshape(1, -1, 1, 1), dtype=tf.float32)
    norm  = Lambda(lambda z: (z - means) / stds, name="normalize")(merged)

    # Block 1
    b1 = Conv2D(F1, (1, kernLength), padding='same', use_bias=False)(norm)
    b1 = BatchNormalization()(b1)
    b1 = DepthwiseConv2D((Chans, 1), use_bias=False,
                        depth_multiplier=D,
                        depthwise_constraint=max_norm(1.))(b1)
    b1 = BatchNormalization()(b1)
    b1 = Activation('elu')(b1)
    b1 = AveragePooling2D((1, 4))(b1)
    b1 = Dropout(dropoutRate)(b1)

    # Block 2
    b2 = SeparableConv2D(F2, (1, 16), padding='same', use_bias=False)(b1)
    b2 = BatchNormalization()(b2)
    b2 = Activation('elu')(b2)
    b2 = AveragePooling2D((1, 8))(b2)
    b2 = Dropout(dropoutRate)(b2)
    
    # Classification head
    flat = Flatten(name='flatten')(b2)
    dense= Dense(nb_classes, kernel_constraint=max_norm(norm_rate), name='dense')(flat)
    out  = Activation('softmax', name='softmax')(dense)
        
    return Model(inputs=[eeg_in, hr_in, eda_in], outputs=out, name='EEGNet_with_Preproc')
    

# Example instantiation
model = PreprocAndEEGNet(nb_classes=5, channel_means=np.zeros(8), channel_stds=np.ones(8))

# Compile / train
model.compile('adam', 'sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "EEGNet_with_Preproc"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ eeg_input           │ (None, 6, 1000,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hp (Lambda)         │ (None, 6, 1000,   │          0 │ eeg_input[0][0]   │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bp (Lambda)         │ (None, 6, 1000,   │          0 │ hp[0][0]          │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ notch (Lambda)      │ (None, 6, 1000,   │          0 │ bp[0][0]          │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aa (Lambda)         │ (None, 6, 1000,   │          0 │ notch[0][0]       │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decimate (Lambda)   │ (None, 6, 250, 1) │          0 │ aa[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hr_input            │ (None, 1, 250, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eda_input           │ (None, 1, 250, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 8, 250, 1) │          0 │ decimate[0][0],   │
# │ (Concatenate)       │                   │            │ hr_input[0][0],   │
# │                     │                   │            │ eda_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalize (Lambda)  │ (None, 8, 250, 1) │          0 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 250, 8) │        496 │ normalize[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 250, 8) │         32 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 1, 250,    │        128 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 250,    │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 1, 250,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 1, 62, 16) │          0 │ activation_12[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 1, 62, 16) │          0 │ average_pooling2… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 1, 62, 16) │        512 │ dropout_12[0][0]  │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 62, 16) │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 1, 62, 16) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 1, 7, 16)  │          0 │ activation_13[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 1, 7, 16)  │          0 │ average_pooling2… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 112)       │          0 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5)         │        565 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax             │ (None, 5)         │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,861 (7.27 KB)
#  Trainable params: 1,781 (6.96 KB)
#  Non-trainable params: 80 (320.00 B)

# %% [markdown]
# Step 4: Model training and evaluation

# %%
# Utility functions for loading epochs

def load_eeg_epochs(csv_file, channels, packets_per_epoch):
    df = pd.read_csv(csv_file)
    df['epoch_idx'] = (df['sample'] // packets_per_epoch).astype(int)
    X_list, y_list = [], []
    for (_, _, epoch_idx), grp in df.groupby(['experiment','subject','epoch_idx']):
        grp = grp.sort_values('sample')
        data = grp[channels].values.T  # (6, packets_per_epoch)
        X_list.append(data[..., np.newaxis])
        y_list.append(grp['rating'].iloc[0])
    return np.stack(X_list), np.array(y_list)

def load_wearable_epochs(csv_file, samples_per_epoch):
    """
    Load and segment HR or EDA data into non-overlapping epochs based on row index.
    
    Parameters:
    - csv_file: path to CSV with columns ['experiment','timestamp','value','subject','rating']
    - samples_per_epoch: number of consecutive samples per epoch (e.g. 2 s * 125 Hz = 250)
    
    Returns:
    - X_eda: np.ndarray of shape (n_epochs, 1, samples_per_epoch, 1)
    - y_eda: np.ndarray of labels (n_epochs,)
    """
    df = pd.read_csv(csv_file)
    # Ensure consistent ordering
    df = df.reset_index(drop=True)
    # Epoch index based on row index
    df['epoch_idx'] = df.index // samples_per_epoch

    X_list = []
    y_list = []

    # Group by experiment, subject, and computed epoch index
    for (exp, subj, ep), grp in df.groupby(['experiment', 'subject', 'epoch_idx']):
        grp = grp.sort_index()
        values = grp['value'].values
        if len(values) == samples_per_epoch:
            # shape for each epoch: (1 channel, samples, 1)
            X_list.append(values[np.newaxis, :, np.newaxis])
            y_list.append(grp['rating'].iloc[0])

    X_eda = np.concatenate(X_list, axis=0)
    y_eda = np.array(y_list)
    return X_eda, y_eda

# %%
# Load the training data
X_eeg_train, y_train = load_eeg_epochs(EEG_TRAINING_SET, EEG_CHANNELS, EEG_SAMPLES_PER_EPOCH)
X_hr_train, y_hr_train = load_wearable_epochs(HR_TRAINING_SET, WEARABLE_SAMPLES_PER_EPOCH)
X_eda_train, y_eda_train = load_wearable_epochs(EDA_TRAINING_SET, WEARABLE_SAMPLES_PER_EPOCH)

# Assert that y_train, y_hr_train, and y_eda_train are the same
assert np.array_equal(y_train, y_hr_train), "y_train and y_hr_train do not match!"
assert np.array_equal(y_train, y_eda_train), "y_train and y_eda_train do not match!"

# Shuffle the data
X_eeg_train, X_hr_train, X_eda_train, y_train = shuffle(X_eeg_train, X_hr_train, X_eda_train, y_train, random_state=42)

# %%
# Precompute preprocessed EEG (to get means/stds)
# Build a small model that inputs raw EEG and outputs the decimated, filtered EEG:
eeg_in = tf.keras.Input(shape=(6, EEG_SAMPLES_PER_EPOCH, 1))
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, hp_coeffs))(eeg_in)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, bp_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, bs_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: apply_fir(z, aa_coeffs))(x)
x = tf.keras.layers.Lambda(lambda z: z[:, :, ::4, :])(x)
preproc_model = tf.keras.Model(inputs=eeg_in, outputs=x, name='eeg_preproc')

# Run preprocessing on the entire training set
X_eeg_pre = preproc_model.predict(X_eeg_train, batch_size=16)  # shape (n_train,6,250,1)

# Align shapes and concatenate EEG+HR+EDA
# X_hr_train shape: (n_train, 250, 1) → reshape to (n_train, 1, 250, 1)
X_hr_train = X_hr_train.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)
# X_eda_train shape: (n_train, 250, 1) → reshape to (n_train, 1, 250, 1)
X_eda_train = X_eda_train.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)

X_merged = np.concatenate([X_eeg_pre, X_hr_train, X_eda_train], axis=1)  # shape (n_train,8,250,1)

# Compute channel-wise mean/std
channel_means = X_merged.mean(axis=(0,2,3))  # shape (8,)
channel_stds  = X_merged.std (axis=(0,2,3))  # shape (8,)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# Build and compile the model
model = PreprocAndEEGNet(
    nb_classes=5,
    channel_means=channel_means,
    channel_stds=channel_stds
)
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    {'eeg_input': X_eeg_train, 'hr_input': X_hr_train, 'eda_input': X_eda_train},
    y_train,
    batch_size=128,
    epochs=1000,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - accuracy: 0.1968 - loss: 1.9549 - val_accuracy: 0.0556 - val_loss: 1.6104
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.1849 - loss: 1.6168 - val_accuracy: 0.1111 - val_loss: 1.6085
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2820 - loss: 1.5803 - val_accuracy: 0.1111 - val_loss: 1.6065
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2872 - loss: 1.5639 - val_accuracy: 0.1667 - val_loss: 1.6043
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3114 - loss: 1.5338 - val_accuracy: 0.1667 - val_loss: 1.6018
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3869 - loss: 1.5133 - val_accuracy: 0.2222 - val_loss: 1.5994
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3017 - loss: 1.5260 - val_accuracy: 0.2222 - val_loss: 1.5971
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.3760 - loss: 1.4917 - val_accuracy: 0.2778 - val_loss: 1.5949
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4059 - loss: 1.4618 - val_accuracy: 0.3889 - val_loss: 1.5925
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4354 - loss: 1.4315 - val_accuracy: 0.3889 - val_loss: 1.5901
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4608 - loss: 1.4378 - val_accuracy: 0.3889 - val_loss: 1.5879
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4354 - loss: 1.4272 - val_accuracy: 0.3889 - val_loss: 1.5855
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4454 - loss: 1.4096 - val_accuracy: 0.3889 - val_loss: 1.5833
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4339 - loss: 1.4017 - val_accuracy: 0.3889 - val_loss: 1.5811
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4933 - loss: 1.3929 - val_accuracy: 0.3889 - val_loss: 1.5788
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4686 - loss: 1.3640 - val_accuracy: 0.3889 - val_loss: 1.5766
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4473 - loss: 1.3523 - val_accuracy: 0.3889 - val_loss: 1.5740
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4933 - loss: 1.3337 - val_accuracy: 0.3889 - val_loss: 1.5710
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4638 - loss: 1.3569 - val_accuracy: 0.3333 - val_loss: 1.5683
# Epoch 20/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4840 - loss: 1.3081 - val_accuracy: 0.3889 - val_loss: 1.5660
# Epoch 21/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5067 - loss: 1.2965 - val_accuracy: 0.3889 - val_loss: 1.5639
# Epoch 22/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4974 - loss: 1.2879 - val_accuracy: 0.3889 - val_loss: 1.5620
# Epoch 23/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4892 - loss: 1.2818 - val_accuracy: 0.3333 - val_loss: 1.5607
# Epoch 24/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5067 - loss: 1.2538 - val_accuracy: 0.2778 - val_loss: 1.5603
# Epoch 25/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4851 - loss: 1.2940 - val_accuracy: 0.2778 - val_loss: 1.5604
# Epoch 26/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4798 - loss: 1.2660 - val_accuracy: 0.3333 - val_loss: 1.5602
# Epoch 27/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5284 - loss: 1.2673 - val_accuracy: 0.3333 - val_loss: 1.5588
# Epoch 28/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5030 - loss: 1.2668 - val_accuracy: 0.2778 - val_loss: 1.5563
# Epoch 29/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5366 - loss: 1.2496 - val_accuracy: 0.2222 - val_loss: 1.5535
# Epoch 30/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5422 - loss: 1.2465 - val_accuracy: 0.2778 - val_loss: 1.5511
# Epoch 31/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5448 - loss: 1.2520 - val_accuracy: 0.2778 - val_loss: 1.5480
# Epoch 32/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5284 - loss: 1.2317 - val_accuracy: 0.2778 - val_loss: 1.5438
# Epoch 33/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5620 - loss: 1.2097 - val_accuracy: 0.2222 - val_loss: 1.5394
# Epoch 34/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5228 - loss: 1.2006 - val_accuracy: 0.2222 - val_loss: 1.5359
# Epoch 35/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5538 - loss: 1.2119 - val_accuracy: 0.2778 - val_loss: 1.5327
# Epoch 36/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5522 - loss: 1.1830 - val_accuracy: 0.2778 - val_loss: 1.5295
# Epoch 37/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5490 - loss: 1.2097 - val_accuracy: 0.2778 - val_loss: 1.5268
# Epoch 38/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5683 - loss: 1.1797 - val_accuracy: 0.2778 - val_loss: 1.5247
# Epoch 39/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5444 - loss: 1.1584 - val_accuracy: 0.3333 - val_loss: 1.5218
# Epoch 40/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5754 - loss: 1.1930 - val_accuracy: 0.3333 - val_loss: 1.5172
# Epoch 41/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5594 - loss: 1.1813 - val_accuracy: 0.3333 - val_loss: 1.5116
# Epoch 42/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5661 - loss: 1.1783 - val_accuracy: 0.2778 - val_loss: 1.5068
# Epoch 43/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5997 - loss: 1.1680 - val_accuracy: 0.2778 - val_loss: 1.5021
# Epoch 44/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6053 - loss: 1.1550 - val_accuracy: 0.2778 - val_loss: 1.4977
# Epoch 45/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6012 - loss: 1.1416 - val_accuracy: 0.2778 - val_loss: 1.4943
# Epoch 46/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5475 - loss: 1.1608 - val_accuracy: 0.2778 - val_loss: 1.4901
# Epoch 47/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6131 - loss: 1.1756 - val_accuracy: 0.2778 - val_loss: 1.4862
# Epoch 48/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5889 - loss: 1.1343 - val_accuracy: 0.2778 - val_loss: 1.4829
# Epoch 49/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6441 - loss: 1.1255 - val_accuracy: 0.2778 - val_loss: 1.4787
# Epoch 50/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6281 - loss: 1.1619 - val_accuracy: 0.2778 - val_loss: 1.4738
# Epoch 51/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6214 - loss: 1.1388 - val_accuracy: 0.2778 - val_loss: 1.4693
# Epoch 52/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6038 - loss: 1.1423 - val_accuracy: 0.2778 - val_loss: 1.4638
# Epoch 53/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6524 - loss: 1.1285 - val_accuracy: 0.2778 - val_loss: 1.4583
# Epoch 54/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6281 - loss: 1.1154 - val_accuracy: 0.3333 - val_loss: 1.4527
# Epoch 55/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6049 - loss: 1.1356 - val_accuracy: 0.3333 - val_loss: 1.4473
# Epoch 56/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6105 - loss: 1.1345 - val_accuracy: 0.3333 - val_loss: 1.4417
# Epoch 57/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5826 - loss: 1.1359 - val_accuracy: 0.3333 - val_loss: 1.4376
# Epoch 58/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6508 - loss: 1.1063 - val_accuracy: 0.3889 - val_loss: 1.4347
# Epoch 59/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6034 - loss: 1.1074 - val_accuracy: 0.4444 - val_loss: 1.4297
# Epoch 60/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6318 - loss: 1.0924 - val_accuracy: 0.5000 - val_loss: 1.4250
# Epoch 61/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5934 - loss: 1.1491 - val_accuracy: 0.5000 - val_loss: 1.4193
# Epoch 62/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6400 - loss: 1.1033 - val_accuracy: 0.5000 - val_loss: 1.4101
# Epoch 63/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5832 - loss: 1.1247 - val_accuracy: 0.4444 - val_loss: 1.4020
# Epoch 64/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6225 - loss: 1.0952 - val_accuracy: 0.4444 - val_loss: 1.3960
# Epoch 65/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6038 - loss: 1.1079 - val_accuracy: 0.4444 - val_loss: 1.3893
# Epoch 66/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5971 - loss: 1.0758 - val_accuracy: 0.4444 - val_loss: 1.3828
# Epoch 67/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6105 - loss: 1.0712 - val_accuracy: 0.4444 - val_loss: 1.3785
# Epoch 68/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6034 - loss: 1.0714 - val_accuracy: 0.3889 - val_loss: 1.3756
# Epoch 69/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6094 - loss: 1.0950 - val_accuracy: 0.3889 - val_loss: 1.3730
# Epoch 70/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6281 - loss: 1.0773 - val_accuracy: 0.3889 - val_loss: 1.3682
# Epoch 71/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6318 - loss: 1.0984 - val_accuracy: 0.3889 - val_loss: 1.3623
# Epoch 72/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6001 - loss: 1.0593 - val_accuracy: 0.3889 - val_loss: 1.3572
# Epoch 73/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6478 - loss: 1.0562 - val_accuracy: 0.3889 - val_loss: 1.3526
# Epoch 74/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6333 - loss: 1.0564 - val_accuracy: 0.4444 - val_loss: 1.3493
# Epoch 75/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6561 - loss: 1.0479 - val_accuracy: 0.4444 - val_loss: 1.3471
# Epoch 76/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6225 - loss: 1.0404 - val_accuracy: 0.4444 - val_loss: 1.3448
# Epoch 77/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6214 - loss: 1.0495 - val_accuracy: 0.4444 - val_loss: 1.3431
# Epoch 78/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6209 - loss: 1.0556 - val_accuracy: 0.4444 - val_loss: 1.3382
# Epoch 79/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5971 - loss: 1.0679 - val_accuracy: 0.4444 - val_loss: 1.3323
# Epoch 80/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6266 - loss: 1.0558 - val_accuracy: 0.4444 - val_loss: 1.3257
# Epoch 81/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6240 - loss: 1.0310 - val_accuracy: 0.4444 - val_loss: 1.3194
# Epoch 82/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6225 - loss: 1.0519 - val_accuracy: 0.4444 - val_loss: 1.3142
# Epoch 83/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6296 - loss: 1.0230 - val_accuracy: 0.4444 - val_loss: 1.3102
# Epoch 84/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6404 - loss: 1.0290 - val_accuracy: 0.3889 - val_loss: 1.3094
# Epoch 85/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6508 - loss: 1.0393 - val_accuracy: 0.3333 - val_loss: 1.3129
# Epoch 86/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6472 - loss: 1.0231 - val_accuracy: 0.2778 - val_loss: 1.3151
# Epoch 87/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6120 - loss: 1.0457 - val_accuracy: 0.3333 - val_loss: 1.3182
# Epoch 88/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6266 - loss: 1.0432 - val_accuracy: 0.3889 - val_loss: 1.2996
# Epoch 89/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6400 - loss: 1.0357 - val_accuracy: 0.4444 - val_loss: 1.2832
# Epoch 90/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6430 - loss: 1.0272 - val_accuracy: 0.5556 - val_loss: 1.2708
# Epoch 91/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6818 - loss: 1.0097 - val_accuracy: 0.5556 - val_loss: 1.2590
# Epoch 92/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6389 - loss: 1.0301 - val_accuracy: 0.5556 - val_loss: 1.2482
# Epoch 93/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6157 - loss: 1.0270 - val_accuracy: 0.5556 - val_loss: 1.2411
# Epoch 94/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6844 - loss: 0.9949 - val_accuracy: 0.5556 - val_loss: 1.2338
# Epoch 95/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6539 - loss: 0.9928 - val_accuracy: 0.5556 - val_loss: 1.2253
# Epoch 96/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6404 - loss: 1.0270 - val_accuracy: 0.6111 - val_loss: 1.2160
# Epoch 97/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6120 - loss: 1.0200 - val_accuracy: 0.6111 - val_loss: 1.2059
# Epoch 98/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6829 - loss: 0.9659 - val_accuracy: 0.6111 - val_loss: 1.1977
# Epoch 99/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6456 - loss: 0.9906 - val_accuracy: 0.6111 - val_loss: 1.1925
# Epoch 100/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6153 - loss: 1.0077 - val_accuracy: 0.6111 - val_loss: 1.1919
# Epoch 101/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6322 - loss: 0.9819 - val_accuracy: 0.6111 - val_loss: 1.1932
# Epoch 102/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6146 - loss: 0.9954 - val_accuracy: 0.6111 - val_loss: 1.1964
# Epoch 103/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6199 - loss: 0.9952 - val_accuracy: 0.6111 - val_loss: 1.1984
# Epoch 104/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6456 - loss: 0.9876 - val_accuracy: 0.6667 - val_loss: 1.1990
# Epoch 105/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6203 - loss: 0.9903 - val_accuracy: 0.6667 - val_loss: 1.2004
# Epoch 106/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6363 - loss: 0.9665 - val_accuracy: 0.6667 - val_loss: 1.1995
# Epoch 107/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6632 - loss: 0.9951 - val_accuracy: 0.6111 - val_loss: 1.1970
# Epoch 108/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6688 - loss: 1.0051 - val_accuracy: 0.5556 - val_loss: 1.1938
# Epoch 109/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6415 - loss: 0.9431 - val_accuracy: 0.5556 - val_loss: 1.1875
# Epoch 110/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6404 - loss: 0.9925 - val_accuracy: 0.5556 - val_loss: 1.1825
# Epoch 111/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6524 - loss: 0.9790 - val_accuracy: 0.5556 - val_loss: 1.1830
# Epoch 112/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6214 - loss: 0.9738 - val_accuracy: 0.5556 - val_loss: 1.1792
# Epoch 113/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6740 - loss: 0.9815 - val_accuracy: 0.6111 - val_loss: 1.1722
# Epoch 114/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6535 - loss: 0.9635 - val_accuracy: 0.7222 - val_loss: 1.1593
# Epoch 115/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6348 - loss: 0.9798 - val_accuracy: 0.7222 - val_loss: 1.1446
# Epoch 116/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6214 - loss: 0.9662 - val_accuracy: 0.7778 - val_loss: 1.1325
# Epoch 117/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6580 - loss: 0.9436 - val_accuracy: 0.7778 - val_loss: 1.1202
# Epoch 118/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6658 - loss: 0.9700 - val_accuracy: 0.7222 - val_loss: 1.1099
# Epoch 119/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6441 - loss: 0.9463 - val_accuracy: 0.6667 - val_loss: 1.1020
# Epoch 120/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6426 - loss: 0.9515 - val_accuracy: 0.7222 - val_loss: 1.0942
# Epoch 121/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6363 - loss: 0.9730 - val_accuracy: 0.7778 - val_loss: 1.0834
# Epoch 122/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6602 - loss: 0.9214 - val_accuracy: 0.7778 - val_loss: 1.0736
# Epoch 123/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7139 - loss: 0.9139 - val_accuracy: 0.7778 - val_loss: 1.0681
# Epoch 124/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6498 - loss: 0.9494 - val_accuracy: 0.7778 - val_loss: 1.0684
# Epoch 125/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6901 - loss: 0.9389 - val_accuracy: 0.7778 - val_loss: 1.0722
# Epoch 126/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6968 - loss: 0.9296 - val_accuracy: 0.7778 - val_loss: 1.0716
# Epoch 127/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7267 - loss: 0.9419 - val_accuracy: 0.7778 - val_loss: 1.0672
# Epoch 128/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6617 - loss: 0.9582 - val_accuracy: 0.7778 - val_loss: 1.0643
# Epoch 129/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6591 - loss: 0.9577 - val_accuracy: 0.7778 - val_loss: 1.0669
# Epoch 130/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6844 - loss: 0.9206 - val_accuracy: 0.7222 - val_loss: 1.0707
# Epoch 131/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6524 - loss: 0.9586 - val_accuracy: 0.6667 - val_loss: 1.0719
# Epoch 132/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6979 - loss: 0.9269 - val_accuracy: 0.6667 - val_loss: 1.0685
# Epoch 133/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6415 - loss: 0.9294 - val_accuracy: 0.6667 - val_loss: 1.0665
# Epoch 134/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6844 - loss: 0.9206 - val_accuracy: 0.6667 - val_loss: 1.0635
# Epoch 135/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6370 - loss: 0.9249 - val_accuracy: 0.6667 - val_loss: 1.0567
# Epoch 136/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6617 - loss: 0.9244 - val_accuracy: 0.6667 - val_loss: 1.0491
# Epoch 137/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6968 - loss: 0.9042 - val_accuracy: 0.7222 - val_loss: 1.0457
# Epoch 138/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6740 - loss: 0.9525 - val_accuracy: 0.7222 - val_loss: 1.0361
# Epoch 139/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6400 - loss: 0.9007 - val_accuracy: 0.7778 - val_loss: 1.0278
# Epoch 140/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6647 - loss: 0.9104 - val_accuracy: 0.7778 - val_loss: 1.0240
# Epoch 141/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6949 - loss: 0.9202 - val_accuracy: 0.7778 - val_loss: 1.0196
# Epoch 142/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6710 - loss: 0.8903 - val_accuracy: 0.7222 - val_loss: 1.0193
# Epoch 143/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6684 - loss: 0.9064 - val_accuracy: 0.7222 - val_loss: 1.0176
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6498 - loss: 0.9187 - val_accuracy: 0.6667 - val_loss: 1.0075
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6493 - loss: 0.9330 - val_accuracy: 0.6667 - val_loss: 0.9920
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6467 - loss: 0.9345 - val_accuracy: 0.7222 - val_loss: 0.9806
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6658 - loss: 0.9001 - val_accuracy: 0.6667 - val_loss: 0.9725
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6183 - loss: 0.9202 - val_accuracy: 0.6111 - val_loss: 0.9689
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6576 - loss: 0.9128 - val_accuracy: 0.6111 - val_loss: 0.9645
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7046 - loss: 0.8797 - val_accuracy: 0.6667 - val_loss: 0.9579
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6669 - loss: 0.8837 - val_accuracy: 0.6667 - val_loss: 0.9512
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6669 - loss: 0.9002 - val_accuracy: 0.6667 - val_loss: 0.9458
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7139 - loss: 0.8942 - val_accuracy: 0.7222 - val_loss: 0.9400
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6632 - loss: 0.9169 - val_accuracy: 0.7222 - val_loss: 0.9313
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7397 - loss: 0.8578 - val_accuracy: 0.7222 - val_loss: 0.9233
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6818 - loss: 0.9140 - val_accuracy: 0.7778 - val_loss: 0.9185
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7020 - loss: 0.8983 - val_accuracy: 0.7778 - val_loss: 0.9188
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6897 - loss: 0.8859 - val_accuracy: 0.7778 - val_loss: 0.9243
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7020 - loss: 0.8924 - val_accuracy: 0.7778 - val_loss: 0.9347
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6844 - loss: 0.8591 - val_accuracy: 0.7222 - val_loss: 0.9444
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6602 - loss: 0.8756 - val_accuracy: 0.7222 - val_loss: 0.9480
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7035 - loss: 0.8615 - val_accuracy: 0.7222 - val_loss: 0.9488
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6699 - loss: 0.8906 - val_accuracy: 0.7222 - val_loss: 0.9488
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7248 - loss: 0.8801 - val_accuracy: 0.7222 - val_loss: 0.9519
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6740 - loss: 0.8560 - val_accuracy: 0.7222 - val_loss: 0.9539
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6669 - loss: 0.8624 - val_accuracy: 0.7222 - val_loss: 0.9517
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7091 - loss: 0.8722 - val_accuracy: 0.6667 - val_loss: 0.9463
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7009 - loss: 0.8726 - val_accuracy: 0.6667 - val_loss: 0.9411
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6912 - loss: 0.8515 - val_accuracy: 0.6667 - val_loss: 0.9376
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6788 - loss: 0.8615 - val_accuracy: 0.6667 - val_loss: 0.9355
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7087 - loss: 0.8743 - val_accuracy: 0.6667 - val_loss: 0.9269
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6953 - loss: 0.8424 - val_accuracy: 0.6667 - val_loss: 0.9141
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7087 - loss: 0.8565 - val_accuracy: 0.7222 - val_loss: 0.9082
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7087 - loss: 0.8385 - val_accuracy: 0.7222 - val_loss: 0.9102
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7397 - loss: 0.8492 - val_accuracy: 0.7222 - val_loss: 0.9149
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6807 - loss: 0.8699 - val_accuracy: 0.6667 - val_loss: 0.9204
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7169 - loss: 0.8381 - val_accuracy: 0.6111 - val_loss: 0.9270
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6807 - loss: 0.8286 - val_accuracy: 0.6111 - val_loss: 0.9312
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6788 - loss: 0.8543 - val_accuracy: 0.6111 - val_loss: 0.9267
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7087 - loss: 0.8561 - val_accuracy: 0.6111 - val_loss: 0.9202
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6897 - loss: 0.8487 - val_accuracy: 0.6111 - val_loss: 0.9089
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6998 - loss: 0.8735 - val_accuracy: 0.6667 - val_loss: 0.9016
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7046 - loss: 0.8446 - val_accuracy: 0.6667 - val_loss: 0.9022
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7024 - loss: 0.8464 - val_accuracy: 0.6667 - val_loss: 0.9032
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6823 - loss: 0.8558 - val_accuracy: 0.6667 - val_loss: 0.9097
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6426 - loss: 0.8592 - val_accuracy: 0.6667 - val_loss: 0.9144
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6968 - loss: 0.8624 - val_accuracy: 0.6667 - val_loss: 0.9115
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6281 - loss: 0.8504 - val_accuracy: 0.6667 - val_loss: 0.9063
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6953 - loss: 0.8296 - val_accuracy: 0.6667 - val_loss: 0.9045
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7133 - loss: 0.8318 - val_accuracy: 0.6667 - val_loss: 0.9029
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7364 - loss: 0.8081 - val_accuracy: 0.7222 - val_loss: 0.9006
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7206 - loss: 0.8231 - val_accuracy: 0.6667 - val_loss: 0.8985
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7102 - loss: 0.8306 - val_accuracy: 0.7222 - val_loss: 0.8963
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7165 - loss: 0.8118 - val_accuracy: 0.7222 - val_loss: 0.8890
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7087 - loss: 0.8353 - val_accuracy: 0.7222 - val_loss: 0.8725
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7263 - loss: 0.8021 - val_accuracy: 0.7222 - val_loss: 0.8571
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6968 - loss: 0.8113 - val_accuracy: 0.7222 - val_loss: 0.8426
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7016 - loss: 0.8100 - val_accuracy: 0.7222 - val_loss: 0.8302
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6938 - loss: 0.8007 - val_accuracy: 0.7222 - val_loss: 0.8275
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6901 - loss: 0.8231 - val_accuracy: 0.6667 - val_loss: 0.8346
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7046 - loss: 0.8028 - val_accuracy: 0.6667 - val_loss: 0.8455
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6860 - loss: 0.8361 - val_accuracy: 0.6667 - val_loss: 0.8562
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6886 - loss: 0.8095 - val_accuracy: 0.7222 - val_loss: 0.8647
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7169 - loss: 0.8033 - val_accuracy: 0.7222 - val_loss: 0.8636
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6662 - loss: 0.8487 - val_accuracy: 0.7222 - val_loss: 0.8548
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6983 - loss: 0.8076 - val_accuracy: 0.7222 - val_loss: 0.8488
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7382 - loss: 0.7893 - val_accuracy: 0.7222 - val_loss: 0.8437
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6942 - loss: 0.8106 - val_accuracy: 0.7222 - val_loss: 0.8361
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7185 - loss: 0.7832 - val_accuracy: 0.7222 - val_loss: 0.8244
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7211 - loss: 0.7990 - val_accuracy: 0.7222 - val_loss: 0.8135
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6740 - loss: 0.8108 - val_accuracy: 0.7222 - val_loss: 0.8086
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7315 - loss: 0.7709 - val_accuracy: 0.7222 - val_loss: 0.8096
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6870 - loss: 0.8195 - val_accuracy: 0.7222 - val_loss: 0.8139
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7304 - loss: 0.8039 - val_accuracy: 0.6667 - val_loss: 0.8218
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6916 - loss: 0.8213 - val_accuracy: 0.6667 - val_loss: 0.8266
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7046 - loss: 0.7633 - val_accuracy: 0.6667 - val_loss: 0.8219
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7087 - loss: 0.7827 - val_accuracy: 0.7778 - val_loss: 0.8131
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7401 - loss: 0.7679 - val_accuracy: 0.7778 - val_loss: 0.8011
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7547 - loss: 0.7948 - val_accuracy: 0.7778 - val_loss: 0.7945
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7330 - loss: 0.7918 - val_accuracy: 0.7778 - val_loss: 0.7859
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7542 - loss: 0.7812 - val_accuracy: 0.7778 - val_loss: 0.7809
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7505 - loss: 0.7588 - val_accuracy: 0.7222 - val_loss: 0.7803
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7412 - loss: 0.7613 - val_accuracy: 0.7222 - val_loss: 0.7853
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7263 - loss: 0.7521 - val_accuracy: 0.6667 - val_loss: 0.7918
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7169 - loss: 0.7637 - val_accuracy: 0.6667 - val_loss: 0.7974
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7087 - loss: 0.7700 - val_accuracy: 0.6667 - val_loss: 0.7970
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7479 - loss: 0.7577 - val_accuracy: 0.6667 - val_loss: 0.7945
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7267 - loss: 0.7845 - val_accuracy: 0.6667 - val_loss: 0.7941
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7031 - loss: 0.8001 - val_accuracy: 0.6111 - val_loss: 0.7939
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7692 - loss: 0.7363 - val_accuracy: 0.6111 - val_loss: 0.7965
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7102 - loss: 0.7691 - val_accuracy: 0.6667 - val_loss: 0.7957
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7621 - loss: 0.7670 - val_accuracy: 0.7222 - val_loss: 0.7895
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7722 - loss: 0.7396 - val_accuracy: 0.7778 - val_loss: 0.7875
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.7759 - loss: 0.7557 - val_accuracy: 0.8889 - val_loss: 0.7885
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7562 - loss: 0.7670 - val_accuracy: 0.8889 - val_loss: 0.7876
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7670 - loss: 0.7330 - val_accuracy: 0.8333 - val_loss: 0.7866
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7319 - loss: 0.7713 - val_accuracy: 0.8333 - val_loss: 0.7865
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7532 - loss: 0.7574 - val_accuracy: 0.8333 - val_loss: 0.7844
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7143 - loss: 0.7516 - val_accuracy: 0.8333 - val_loss: 0.7773
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7629 - loss: 0.7529 - val_accuracy: 0.7778 - val_loss: 0.7684
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6864 - loss: 0.7493 - val_accuracy: 0.7778 - val_loss: 0.7611
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7367 - loss: 0.7466 - val_accuracy: 0.7778 - val_loss: 0.7594
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7551 - loss: 0.7346 - val_accuracy: 0.7778 - val_loss: 0.7581
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7061 - loss: 0.7790 - val_accuracy: 0.7778 - val_loss: 0.7574
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7759 - loss: 0.7308 - val_accuracy: 0.7778 - val_loss: 0.7576
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7670 - loss: 0.7325 - val_accuracy: 0.7778 - val_loss: 0.7558
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7774 - loss: 0.7135 - val_accuracy: 0.7778 - val_loss: 0.7565
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7718 - loss: 0.7213 - val_accuracy: 0.7778 - val_loss: 0.7573
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7009 - loss: 0.7625 - val_accuracy: 0.6667 - val_loss: 0.7697
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7442 - loss: 0.7385 - val_accuracy: 0.6667 - val_loss: 0.7829
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7479 - loss: 0.7402 - val_accuracy: 0.7222 - val_loss: 0.7910
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7737 - loss: 0.7216 - val_accuracy: 0.7222 - val_loss: 0.7924
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7076 - loss: 0.7594 - val_accuracy: 0.7778 - val_loss: 0.7887
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7521 - loss: 0.7185 - val_accuracy: 0.8333 - val_loss: 0.7879
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7562 - loss: 0.7187 - val_accuracy: 0.8889 - val_loss: 0.7947
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7542 - loss: 0.7075 - val_accuracy: 0.8889 - val_loss: 0.7999
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7416 - loss: 0.7335 - val_accuracy: 0.8889 - val_loss: 0.8047
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7449 - loss: 0.7223 - val_accuracy: 0.8889 - val_loss: 0.8180
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7666 - loss: 0.7163 - val_accuracy: 0.8889 - val_loss: 0.8325
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7319 - loss: 0.7097 - val_accuracy: 0.8889 - val_loss: 0.8371
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7416 - loss: 0.7201 - val_accuracy: 0.8889 - val_loss: 0.8345
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7867 - loss: 0.7306 - val_accuracy: 0.8889 - val_loss: 0.8118
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7846 - loss: 0.6922 - val_accuracy: 0.8889 - val_loss: 0.7807
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7304 - loss: 0.7340 - val_accuracy: 0.8889 - val_loss: 0.7635
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7464 - loss: 0.7359 - val_accuracy: 0.8889 - val_loss: 0.7599
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7976 - loss: 0.6902 - val_accuracy: 0.9444 - val_loss: 0.7546
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7267 - loss: 0.7226 - val_accuracy: 0.8889 - val_loss: 0.7418
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7547 - loss: 0.7089 - val_accuracy: 0.8889 - val_loss: 0.7299
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7200 - loss: 0.7430 - val_accuracy: 0.8889 - val_loss: 0.7164
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7453 - loss: 0.7377 - val_accuracy: 0.9444 - val_loss: 0.7054
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7644 - loss: 0.7032 - val_accuracy: 0.8333 - val_loss: 0.7055
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7378 - loss: 0.7021 - val_accuracy: 0.7778 - val_loss: 0.7078
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7826 - loss: 0.6983 - val_accuracy: 0.7778 - val_loss: 0.7092
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7707 - loss: 0.7070 - val_accuracy: 0.8333 - val_loss: 0.7082
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7547 - loss: 0.7315 - val_accuracy: 0.8333 - val_loss: 0.7045
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7857 - loss: 0.6929 - val_accuracy: 0.8333 - val_loss: 0.7024
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7629 - loss: 0.7025 - val_accuracy: 0.8333 - val_loss: 0.6975
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7427 - loss: 0.6975 - val_accuracy: 0.8333 - val_loss: 0.6935
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7629 - loss: 0.6903 - val_accuracy: 0.8333 - val_loss: 0.6892
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7778 - loss: 0.6778 - val_accuracy: 0.7222 - val_loss: 0.6834
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7722 - loss: 0.6824 - val_accuracy: 0.7778 - val_loss: 0.6776
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7789 - loss: 0.6855 - val_accuracy: 0.8333 - val_loss: 0.6704
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7774 - loss: 0.6872 - val_accuracy: 0.8333 - val_loss: 0.6648
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7677 - loss: 0.7189 - val_accuracy: 0.8889 - val_loss: 0.6628
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7815 - loss: 0.6638 - val_accuracy: 0.8889 - val_loss: 0.6678
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7655 - loss: 0.6888 - val_accuracy: 0.8889 - val_loss: 0.6780
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8017 - loss: 0.7199 - val_accuracy: 0.8889 - val_loss: 0.6902
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8002 - loss: 0.6813 - val_accuracy: 0.8889 - val_loss: 0.7001
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7666 - loss: 0.7049 - val_accuracy: 0.8889 - val_loss: 0.6982
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7334 - loss: 0.6844 - val_accuracy: 0.8889 - val_loss: 0.6909
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8088 - loss: 0.6785 - val_accuracy: 0.8889 - val_loss: 0.6848
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8099 - loss: 0.6690 - val_accuracy: 0.8889 - val_loss: 0.6792
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7939 - loss: 0.6663 - val_accuracy: 0.8333 - val_loss: 0.6726
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7666 - loss: 0.6743 - val_accuracy: 0.8333 - val_loss: 0.6675
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7804 - loss: 0.6779 - val_accuracy: 0.8333 - val_loss: 0.6642
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7841 - loss: 0.6638 - val_accuracy: 0.8333 - val_loss: 0.6574
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7991 - loss: 0.6686 - val_accuracy: 0.7222 - val_loss: 0.6596
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7748 - loss: 0.6900 - val_accuracy: 0.7222 - val_loss: 0.6626
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7991 - loss: 0.6766 - val_accuracy: 0.7222 - val_loss: 0.6559
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7950 - loss: 0.6703 - val_accuracy: 0.8333 - val_loss: 0.6492
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7584 - loss: 0.6964 - val_accuracy: 0.8889 - val_loss: 0.6471
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7748 - loss: 0.6475 - val_accuracy: 0.9444 - val_loss: 0.6430
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7935 - loss: 0.6515 - val_accuracy: 0.9444 - val_loss: 0.6429
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7991 - loss: 0.6616 - val_accuracy: 0.8889 - val_loss: 0.6497
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8084 - loss: 0.6572 - val_accuracy: 0.8889 - val_loss: 0.6605
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8006 - loss: 0.6718 - val_accuracy: 0.8333 - val_loss: 0.6748
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8088 - loss: 0.6332 - val_accuracy: 0.8889 - val_loss: 0.6841
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7965 - loss: 0.6504 - val_accuracy: 0.7778 - val_loss: 0.6981
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8234 - loss: 0.6300 - val_accuracy: 0.7778 - val_loss: 0.7136
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7924 - loss: 0.6370 - val_accuracy: 0.7778 - val_loss: 0.7218
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8229 - loss: 0.6401 - val_accuracy: 0.7778 - val_loss: 0.7075
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7883 - loss: 0.6494 - val_accuracy: 0.8333 - val_loss: 0.6734
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7655 - loss: 0.6606 - val_accuracy: 0.8333 - val_loss: 0.6494
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8084 - loss: 0.6570 - val_accuracy: 0.8333 - val_loss: 0.6412
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7950 - loss: 0.6430 - val_accuracy: 0.8333 - val_loss: 0.6376
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7804 - loss: 0.6777 - val_accuracy: 0.8333 - val_loss: 0.6357
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7789 - loss: 0.6475 - val_accuracy: 0.8333 - val_loss: 0.6346
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8099 - loss: 0.6487 - val_accuracy: 0.8333 - val_loss: 0.6385
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8114 - loss: 0.6245 - val_accuracy: 0.8333 - val_loss: 0.6467
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7991 - loss: 0.6666 - val_accuracy: 0.8333 - val_loss: 0.6559
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7857 - loss: 0.6533 - val_accuracy: 0.8333 - val_loss: 0.6545
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7815 - loss: 0.6560 - val_accuracy: 0.8333 - val_loss: 0.6527
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7722 - loss: 0.6452 - val_accuracy: 0.7778 - val_loss: 0.6645
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7495 - loss: 0.6547 - val_accuracy: 0.7222 - val_loss: 0.6837
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8028 - loss: 0.6382 - val_accuracy: 0.7222 - val_loss: 0.6892
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8249 - loss: 0.6198 - val_accuracy: 0.7222 - val_loss: 0.6952
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7722 - loss: 0.6482 - val_accuracy: 0.6667 - val_loss: 0.7064
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8234 - loss: 0.6187 - val_accuracy: 0.6667 - val_loss: 0.7054
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7887 - loss: 0.6663 - val_accuracy: 0.7222 - val_loss: 0.6920
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8166 - loss: 0.6051 - val_accuracy: 0.7222 - val_loss: 0.6993
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7820 - loss: 0.6669 - val_accuracy: 0.7222 - val_loss: 0.7165
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7599 - loss: 0.6433 - val_accuracy: 0.7222 - val_loss: 0.7249
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7696 - loss: 0.6610 - val_accuracy: 0.7222 - val_loss: 0.7141
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7644 - loss: 0.6362 - val_accuracy: 0.8333 - val_loss: 0.6995
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7950 - loss: 0.6509 - val_accuracy: 0.7778 - val_loss: 0.6851
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7562 - loss: 0.6408 - val_accuracy: 0.7778 - val_loss: 0.6849
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7965 - loss: 0.6341 - val_accuracy: 0.8333 - val_loss: 0.6803
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8110 - loss: 0.6247 - val_accuracy: 0.8889 - val_loss: 0.6682
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8088 - loss: 0.6453 - val_accuracy: 0.8889 - val_loss: 0.6592
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8260 - loss: 0.6197 - val_accuracy: 0.8889 - val_loss: 0.6548
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8125 - loss: 0.6492 - val_accuracy: 0.8889 - val_loss: 0.6419
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7861 - loss: 0.6235 - val_accuracy: 0.8889 - val_loss: 0.6187
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8286 - loss: 0.5936 - val_accuracy: 0.8333 - val_loss: 0.6052
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7722 - loss: 0.6211 - val_accuracy: 0.8333 - val_loss: 0.5951
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8047 - loss: 0.6246 - val_accuracy: 0.8889 - val_loss: 0.5898
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8006 - loss: 0.6181 - val_accuracy: 0.8889 - val_loss: 0.5893
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8383 - loss: 0.6200 - val_accuracy: 0.8889 - val_loss: 0.5907
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8110 - loss: 0.5975 - val_accuracy: 0.8889 - val_loss: 0.5958
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8177 - loss: 0.5936 - val_accuracy: 0.8889 - val_loss: 0.6068
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7924 - loss: 0.6201 - val_accuracy: 0.8889 - val_loss: 0.6200
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8043 - loss: 0.6026 - val_accuracy: 0.8333 - val_loss: 0.6327
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7950 - loss: 0.6210 - val_accuracy: 0.8333 - val_loss: 0.6386
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7995 - loss: 0.6167 - val_accuracy: 0.7222 - val_loss: 0.6410
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8197 - loss: 0.6361 - val_accuracy: 0.6667 - val_loss: 0.6447
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8058 - loss: 0.5955 - val_accuracy: 0.6667 - val_loss: 0.6488
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7924 - loss: 0.6076 - val_accuracy: 0.6667 - val_loss: 0.6487
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7815 - loss: 0.6058 - val_accuracy: 0.6667 - val_loss: 0.6445
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7737 - loss: 0.6139 - val_accuracy: 0.7778 - val_loss: 0.6349
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8121 - loss: 0.6048 - val_accuracy: 0.8889 - val_loss: 0.6285
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8047 - loss: 0.6041 - val_accuracy: 0.8889 - val_loss: 0.6319
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8099 - loss: 0.6093 - val_accuracy: 0.8889 - val_loss: 0.6404
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8084 - loss: 0.6227 - val_accuracy: 0.8889 - val_loss: 0.6489
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8342 - loss: 0.5781 - val_accuracy: 0.8889 - val_loss: 0.6645
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7924 - loss: 0.5925 - val_accuracy: 0.8889 - val_loss: 0.6787
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8140 - loss: 0.5831 - val_accuracy: 0.8333 - val_loss: 0.6784
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8006 - loss: 0.6062 - val_accuracy: 0.8889 - val_loss: 0.6729
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7924 - loss: 0.6147 - val_accuracy: 0.8889 - val_loss: 0.6684
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8058 - loss: 0.5979 - val_accuracy: 0.8889 - val_loss: 0.6549
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8208 - loss: 0.6095 - val_accuracy: 0.8889 - val_loss: 0.6390
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7883 - loss: 0.6106 - val_accuracy: 0.8889 - val_loss: 0.6248
# Epoch 371/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7722 - loss: 0.6199 - val_accuracy: 0.8889 - val_loss: 0.6248
# Epoch 372/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8487 - loss: 0.5830 - val_accuracy: 0.8889 - val_loss: 0.6270
# Epoch 373/1000
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8786 - loss: 0.3834 - val_accuracy: 0.8333 - val_loss: 0.3531
# Epoch 878/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8719 - loss: 0.3487 - val_accuracy: 0.8889 - val_loss: 0.3531
# Epoch 879/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8854 - loss: 0.3627 - val_accuracy: 0.8889 - val_loss: 0.3495
# Epoch 880/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9040 - loss: 0.3501 - val_accuracy: 0.8889 - val_loss: 0.3376
# Epoch 881/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9085 - loss: 0.3492 - val_accuracy: 0.8889 - val_loss: 0.3305
# Epoch 882/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8476 - loss: 0.4001 - val_accuracy: 0.8889 - val_loss: 0.3238
# Epoch 883/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8570 - loss: 0.3595 - val_accuracy: 0.8889 - val_loss: 0.3233
# Epoch 884/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8838 - loss: 0.3625 - val_accuracy: 0.8889 - val_loss: 0.3291
# Epoch 885/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8921 - loss: 0.3612 - val_accuracy: 0.8333 - val_loss: 0.3408
# Epoch 886/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8801 - loss: 0.3692 - val_accuracy: 0.8333 - val_loss: 0.3510
# Epoch 887/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8260 - loss: 0.3783 - val_accuracy: 0.8889 - val_loss: 0.3512
# Epoch 888/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8596 - loss: 0.3858 - val_accuracy: 0.8333 - val_loss: 0.3491
# Epoch 889/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8570 - loss: 0.3698 - val_accuracy: 0.8333 - val_loss: 0.3463
# Epoch 890/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8544 - loss: 0.3761 - val_accuracy: 0.8333 - val_loss: 0.3373
# Epoch 891/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8626 - loss: 0.3582 - val_accuracy: 0.8889 - val_loss: 0.3311
# Epoch 892/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8693 - loss: 0.3659 - val_accuracy: 0.8889 - val_loss: 0.3263
# Epoch 893/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8719 - loss: 0.3730 - val_accuracy: 0.8889 - val_loss: 0.3171
# Epoch 894/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8544 - loss: 0.3684 - val_accuracy: 0.8889 - val_loss: 0.3108
# Epoch 895/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8962 - loss: 0.3503 - val_accuracy: 0.9444 - val_loss: 0.3049
# Epoch 896/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8854 - loss: 0.3696 - val_accuracy: 0.9444 - val_loss: 0.3012
# Epoch 897/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8596 - loss: 0.3752 - val_accuracy: 0.9444 - val_loss: 0.2977
# Epoch 898/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8626 - loss: 0.3594 - val_accuracy: 0.9444 - val_loss: 0.2966
# Epoch 899/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8528 - loss: 0.3780 - val_accuracy: 0.9444 - val_loss: 0.3049
# Epoch 900/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8812 - loss: 0.3600 - val_accuracy: 1.0000 - val_loss: 0.3150
# Epoch 901/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9205 - loss: 0.3465 - val_accuracy: 1.0000 - val_loss: 0.3173
# Epoch 902/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8921 - loss: 0.3704 - val_accuracy: 0.8889 - val_loss: 0.3196
# Epoch 903/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8611 - loss: 0.3522 - val_accuracy: 0.8889 - val_loss: 0.3273
# Epoch 904/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8936 - loss: 0.3558 - val_accuracy: 0.8889 - val_loss: 0.3350
# Epoch 905/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8626 - loss: 0.3462 - val_accuracy: 0.8333 - val_loss: 0.3449
# Epoch 906/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8652 - loss: 0.3388 - val_accuracy: 0.8333 - val_loss: 0.3497
# Epoch 907/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8715 - loss: 0.3598 - val_accuracy: 0.8333 - val_loss: 0.3515
# Epoch 908/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8843 - loss: 0.3714 - val_accuracy: 0.8333 - val_loss: 0.3523
# Epoch 909/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9148 - loss: 0.3353 - val_accuracy: 0.8333 - val_loss: 0.3544
# Epoch 910/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8817 - loss: 0.3406 - val_accuracy: 0.8333 - val_loss: 0.3600
# Epoch 911/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8275 - loss: 0.4038 - val_accuracy: 0.7778 - val_loss: 0.3616
# Epoch 912/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8652 - loss: 0.3520 - val_accuracy: 0.8333 - val_loss: 0.3592
# Epoch 913/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8801 - loss: 0.3546 - val_accuracy: 0.8889 - val_loss: 0.3408
# Epoch 914/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8559 - loss: 0.3512 - val_accuracy: 0.8889 - val_loss: 0.3220
# Epoch 915/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8782 - loss: 0.3475 - val_accuracy: 0.8889 - val_loss: 0.3063
# Epoch 916/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8719 - loss: 0.3749 - val_accuracy: 0.9444 - val_loss: 0.3008
# Epoch 917/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8435 - loss: 0.3972 - val_accuracy: 0.9444 - val_loss: 0.3063
# Epoch 918/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8895 - loss: 0.3734 - val_accuracy: 0.9444 - val_loss: 0.3266
# Epoch 919/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8827 - loss: 0.3305 - val_accuracy: 0.8889 - val_loss: 0.3459
# Epoch 920/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8869 - loss: 0.3690 - val_accuracy: 0.8333 - val_loss: 0.3527
# Epoch 921/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8559 - loss: 0.3752 - val_accuracy: 0.8333 - val_loss: 0.3463
# Epoch 922/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8827 - loss: 0.3709 - val_accuracy: 0.8333 - val_loss: 0.3378
# Epoch 923/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8585 - loss: 0.3532 - val_accuracy: 0.8889 - val_loss: 0.3265
# Epoch 924/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8838 - loss: 0.3577 - val_accuracy: 0.8333 - val_loss: 0.3156
# Epoch 925/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8760 - loss: 0.3750 - val_accuracy: 0.8889 - val_loss: 0.3098
# Epoch 926/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8849 - loss: 0.3499 - val_accuracy: 0.8889 - val_loss: 0.3067
# Epoch 927/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8869 - loss: 0.3620 - val_accuracy: 0.8889 - val_loss: 0.3046
# Epoch 928/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8947 - loss: 0.3472 - val_accuracy: 0.9444 - val_loss: 0.2972
# Epoch 929/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8864 - loss: 0.3770 - val_accuracy: 0.9444 - val_loss: 0.2946
# Epoch 930/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8435 - loss: 0.3900 - val_accuracy: 0.8889 - val_loss: 0.3210
# Epoch 931/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8921 - loss: 0.3217 - val_accuracy: 0.8889 - val_loss: 0.3681
# Epoch 932/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8689 - loss: 0.3759 - val_accuracy: 0.8889 - val_loss: 0.4378
# Epoch 933/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8906 - loss: 0.3539 - val_accuracy: 0.7778 - val_loss: 0.5120
# Epoch 934/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8585 - loss: 0.3866 - val_accuracy: 0.7778 - val_loss: 0.5644
# Epoch 935/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8760 - loss: 0.3584 - val_accuracy: 0.7778 - val_loss: 0.5820
# Epoch 936/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8801 - loss: 0.3517 - val_accuracy: 0.7778 - val_loss: 0.5783
# Epoch 937/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8693 - loss: 0.3667 - val_accuracy: 0.7778 - val_loss: 0.5563
# Epoch 938/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8786 - loss: 0.3535 - val_accuracy: 0.7778 - val_loss: 0.5265
# Epoch 939/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8678 - loss: 0.3690 - val_accuracy: 0.7778 - val_loss: 0.5012
# Epoch 940/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8719 - loss: 0.3505 - val_accuracy: 0.7778 - val_loss: 0.4970
# Epoch 941/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8786 - loss: 0.3601 - val_accuracy: 0.8333 - val_loss: 0.4898
# Epoch 942/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8533 - loss: 0.3844 - val_accuracy: 0.8333 - val_loss: 0.4931
# Epoch 943/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8854 - loss: 0.3597 - val_accuracy: 0.8333 - val_loss: 0.4932
# Epoch 944/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8533 - loss: 0.3858 - val_accuracy: 0.8333 - val_loss: 0.4828
# Epoch 945/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8988 - loss: 0.3541 - val_accuracy: 0.8333 - val_loss: 0.4735
# Epoch 946/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8678 - loss: 0.3509 - val_accuracy: 0.8333 - val_loss: 0.4645
# Epoch 947/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8745 - loss: 0.3608 - val_accuracy: 0.8333 - val_loss: 0.4624
# Epoch 948/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8492 - loss: 0.3507 - val_accuracy: 0.8333 - val_loss: 0.4560
# Epoch 949/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8999 - loss: 0.3364 - val_accuracy: 0.8333 - val_loss: 0.4429
# Epoch 950/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8734 - loss: 0.3451 - val_accuracy: 0.8333 - val_loss: 0.4373
# Epoch 951/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8626 - loss: 0.3457 - val_accuracy: 0.8333 - val_loss: 0.4366
# Epoch 952/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8869 - loss: 0.3535 - val_accuracy: 0.8889 - val_loss: 0.4341
# Epoch 953/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8827 - loss: 0.3770 - val_accuracy: 0.8889 - val_loss: 0.4480
# Epoch 954/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8570 - loss: 0.3662 - val_accuracy: 0.8333 - val_loss: 0.4644
# Epoch 955/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8854 - loss: 0.3587 - val_accuracy: 0.8889 - val_loss: 0.4393
# Epoch 956/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9137 - loss: 0.3586 - val_accuracy: 0.8889 - val_loss: 0.4005
# Epoch 957/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8749 - loss: 0.3416 - val_accuracy: 0.8889 - val_loss: 0.3745
# Epoch 958/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8760 - loss: 0.3522 - val_accuracy: 0.8889 - val_loss: 0.3608
# Epoch 959/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8663 - loss: 0.3481 - val_accuracy: 0.8889 - val_loss: 0.3558
# Epoch 960/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8895 - loss: 0.3239 - val_accuracy: 0.9444 - val_loss: 0.3558
# Epoch 961/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8771 - loss: 0.3440 - val_accuracy: 0.9444 - val_loss: 0.3616
# Epoch 962/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8652 - loss: 0.3360 - val_accuracy: 0.8889 - val_loss: 0.3803
# Epoch 963/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8652 - loss: 0.3763 - val_accuracy: 0.8889 - val_loss: 0.3939
# Epoch 964/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9029 - loss: 0.3565 - val_accuracy: 0.8889 - val_loss: 0.4039
# Epoch 965/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8555 - loss: 0.3597 - val_accuracy: 0.8889 - val_loss: 0.4008
# Epoch 966/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8730 - loss: 0.3756 - val_accuracy: 0.8889 - val_loss: 0.3921
# Epoch 967/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8626 - loss: 0.3432 - val_accuracy: 0.8889 - val_loss: 0.3933
# Epoch 968/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8719 - loss: 0.3385 - val_accuracy: 0.8889 - val_loss: 0.4159
# Epoch 969/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8880 - loss: 0.3376 - val_accuracy: 0.8889 - val_loss: 0.4449
# Epoch 970/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8838 - loss: 0.3352 - val_accuracy: 0.8889 - val_loss: 0.4693
# Epoch 971/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8600 - loss: 0.3542 - val_accuracy: 0.8889 - val_loss: 0.4789
# Epoch 972/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8476 - loss: 0.3593 - val_accuracy: 0.8889 - val_loss: 0.4645
# Epoch 973/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9018 - loss: 0.3373 - val_accuracy: 0.8889 - val_loss: 0.4445
# Epoch 974/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8570 - loss: 0.3644 - val_accuracy: 0.8889 - val_loss: 0.4177
# Epoch 975/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8704 - loss: 0.3600 - val_accuracy: 0.8889 - val_loss: 0.3879
# Epoch 976/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8502 - loss: 0.3847 - val_accuracy: 0.8889 - val_loss: 0.3654
# Epoch 977/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8678 - loss: 0.3425 - val_accuracy: 0.8889 - val_loss: 0.3560
# Epoch 978/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8622 - loss: 0.3594 - val_accuracy: 0.8889 - val_loss: 0.3578
# Epoch 979/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8700 - loss: 0.3902 - val_accuracy: 0.8889 - val_loss: 0.3743
# Epoch 980/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8745 - loss: 0.3424 - val_accuracy: 0.8889 - val_loss: 0.3939
# Epoch 981/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8745 - loss: 0.3230 - val_accuracy: 0.8889 - val_loss: 0.4094
# Epoch 982/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8700 - loss: 0.3678 - val_accuracy: 0.8889 - val_loss: 0.4285
# Epoch 983/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8864 - loss: 0.3755 - val_accuracy: 0.8889 - val_loss: 0.4255
# Epoch 984/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8394 - loss: 0.3733 - val_accuracy: 0.8889 - val_loss: 0.3997
# Epoch 985/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8988 - loss: 0.3540 - val_accuracy: 0.8889 - val_loss: 0.3836
# Epoch 986/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8693 - loss: 0.3728 - val_accuracy: 0.8889 - val_loss: 0.3752
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8626 - loss: 0.3356 - val_accuracy: 0.8889 - val_loss: 0.3698
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8570 - loss: 0.3718 - val_accuracy: 0.8889 - val_loss: 0.3671
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8693 - loss: 0.3431 - val_accuracy: 0.8889 - val_loss: 0.3621
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8704 - loss: 0.3387 - val_accuracy: 0.8333 - val_loss: 0.3760
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9070 - loss: 0.3308 - val_accuracy: 0.8333 - val_loss: 0.3995
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8869 - loss: 0.3534 - val_accuracy: 0.8333 - val_loss: 0.4227
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8353 - loss: 0.3921 - val_accuracy: 0.8333 - val_loss: 0.4324
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8704 - loss: 0.4132 - val_accuracy: 0.8333 - val_loss: 0.3939
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8962 - loss: 0.3388 - val_accuracy: 0.8889 - val_loss: 0.3602
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8626 - loss: 0.3520 - val_accuracy: 0.8889 - val_loss: 0.3433
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8827 - loss: 0.3202 - val_accuracy: 0.8889 - val_loss: 0.3353
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9014 - loss: 0.3400 - val_accuracy: 0.8333 - val_loss: 0.3377
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8988 - loss: 0.3464 - val_accuracy: 0.8889 - val_loss: 0.3548
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8641 - loss: 0.3404 - val_accuracy: 0.8889 - val_loss: 0.3661

# %%
# Evaluate the model

# Load the test data
X_eeg_test, y_test = load_eeg_epochs(EEG_TEST_SET, EEG_CHANNELS, EEG_SAMPLES_PER_EPOCH)
X_hr_test, y_hr_test = load_wearable_epochs(HR_TEST_SET, WEARABLE_SAMPLES_PER_EPOCH)
X_eda_test, y_eda_test = load_wearable_epochs(EDA_TEST_SET, WEARABLE_SAMPLES_PER_EPOCH)

# Assert that y_test, y_hr_test, and y_eda_test are the same
assert np.array_equal(y_test, y_hr_test), "y_test and y_hr_test do not match!"
assert np.array_equal(y_test, y_eda_test), "y_test and y_eda_test do not match!"

# Shuffle the data
X_eeg_test, X_hr_test, X_eda_test, y_test = shuffle(X_eeg_test, X_hr_test, X_eda_test, y_test, random_state=42)

# Align shapes
# X_hr_test shape: (n_test, 250, 1) → reshape to (n_test, 1, 250, 1)
X_hr_test = X_hr_test.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)
# X_eda_test shape: (n_test, 250, 1) → reshape to (n_test, 1, 250, 1)
X_eda_test = X_eda_test.reshape(-1, 1, WEARABLE_SAMPLES_PER_EPOCH, 1)

# Model evaluation
test_loss, test_accuracy = model.evaluate(
    {'eeg_input': X_eeg_test, 'hr_input': X_hr_test, 'eda_input': X_eda_test},
    y_test,
    batch_size=128,
    verbose=1
)
print(f"Test loss: {test_loss:.4f}, Test accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3333 - loss: 2.0731
# Test loss: 2.0731, Test accuracy: 0.3333

# %% [markdown]
# Step 5: Model conversion to TFLite

# %%
# -------------------- Conversion to TFLite --------------------
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # optional quantization
tflite_model = converter.convert()
with open(TFLITE_MODEL,'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\giova\AppData\Local\Temp\tmpc7mlx4v1\assets
# INFO:tensorflow:Assets written to: C:\Users\giova\AppData\Local\Temp\tmpc7mlx4v1\assets
# Saved artifact at 'C:\Users\giova\AppData\Local\Temp\tmpc7mlx4v1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 6, 1000, 1), dtype=tf.float32, name='eeg_input'), TensorSpec(shape=(None, 1, 250, 1), dtype=tf.float32, name='hr_input'), TensorSpec(shape=(None, 1, 250, 1), dtype=tf.float32, name='eda_input')]
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   1585198388976: TensorSpec(shape=(1, 8, 1, 1), dtype=tf.float32, name=None)
#   1585198393728: TensorSpec(shape=(1, 8, 1, 1), dtype=tf.float32, name=None)
#   1585197845312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197848128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197851472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197852528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197854992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197845840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585198384400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197857280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197856752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197855344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197853584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197784000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197786640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197780480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197784880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197785232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197783824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1585197569952: TensorSpec(shape=(), dtype=tf.resource, name=None)
